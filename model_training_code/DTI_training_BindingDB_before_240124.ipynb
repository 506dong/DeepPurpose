# %%
import os
os.chdir('../')
os.getcwd()
# Out:
# 'c:\\Users\\user\\Desktop\\DTI\\DeepPurpose-1'

# %%
from DeepPurpose import utils, dataset
from DeepPurpose import DTI as models
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np

# %%
#### process_BindingDB ####

# Parameter
path = '../Database/BindingDB/BindingDB_All_202310_edit.tsv'
df = None
y = 'IC50'
binary = False
convert_to_log = True
threshold = 30
return_ids = False
ids_condition = 'OR'
harmonize_affinities = None

# loading df (bindingDB)
df = pd.read_csv(path, sep = '\t')

print('Beginning Processing...')
df = df[df['Number of Protein Chains in Target (>1 implies a multichain complex)'] == 1.0]
df = df[df['Ligand SMILES'].notnull()]

idx_str = []
yy = y
if isinstance(y, str):
	yy = [y]
for y in yy:
	if y == 'Kd':
		idx_str.append('Kd (nM)')
	elif y == 'IC50':
		idx_str.append('IC50 (nM)')
	elif y == 'Ki':
		idx_str.append('Ki (nM)')
	elif y == 'EC50':
		idx_str.append('EC50 (nM)')
	else:
		print('select Kd, Ki, IC50 or EC50')

if len(idx_str)==1:
	df_want = df[df[idx_str[0]].notnull()]
else: # select multiple affinity measurements.                 
	# keep rows for which at least one of the columns in the idx_str list is not null
	df_want = df.dropna(thresh=1, subset=idx_str) 
	
df_want = df_want[['BindingDB Reactant_set_id', 'Ligand InChI', 'Ligand SMILES',\
				'PubChem CID', 'UniProt (SwissProt) Primary ID of Target Chain',\
				'BindingDB Target Chain Sequence'] + idx_str]

for y in idx_str:
	df_want[y] = df_want[y].str.replace('>', '')
	df_want[y] = df_want[y].str.replace('<', '')
	df_want[y] = df_want[y].astype(float)

# Harmonize into single label using the mean of existing labels:
df_want['Label'] = df_want[idx_str].mean(axis=1, skipna=True)

df_want.rename(columns={'BindingDB Reactant_set_id':'ID',
						'Ligand SMILES':'SMILES',
						'Ligand InChI':'InChI',
						'PubChem CID':'PubChem_ID',
						'UniProt (SwissProt) Primary ID of Target Chain':'UniProt_ID',
						'BindingDB Target Chain Sequence': 'Target Sequence'},
						inplace=True)

# have at least uniprot or pubchem ID
if ids_condition == 'OR':
	df_want = df_want[df_want.PubChem_ID.notnull() | df_want.UniProt_ID.notnull()]
elif ids_condition == 'AND':
	df_want = df_want[df_want.PubChem_ID.notnull() & df_want.UniProt_ID.notnull()]
else:
	ValueError("ids_condition must be set to 'OR' or 'AND'")

df_want = df_want[df_want.InChI.notnull()]

df_want = df_want[df_want.Label <= 10000000.0]
print('There are ' + str(len(df_want)) + ' drug target pairs.')

if harmonize_affinities is not None:
	df_want = df_want[['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence', 'Label']]
	if harmonize_affinities.lower() == 'max_affinity':
		df_want = df_want.groupby(['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence']).Label.agg(min).reset_index()
	if harmonize_affinities.lower() == 'mean':
		df_want = df_want.groupby(['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence']).Label.agg(np.mean).reset_index()

if binary:
	print('Default binary threshold for the binding affinity scores are 30, you can adjust it by using the "threshold" parameter')
	if isinstance(threshold, Sequence):
		# filter samples with affinity values between the thresholds
		df_want = df_want[(df_want.Label < threshold[0]) | (df_want.Label > threshold[1])]
	else: # single threshold
		threshold = [threshold]
	y = [1 if i else 0 for i in df_want.Label.values < threshold[0]]
else:
	if convert_to_log:
		print('Default set to logspace (nM -> p) for easier regression')
		y = utils.convert_y_unit(df_want.Label.values, 'nM', 'p')
	else:
		y = df_want.Label.values
	
if return_ids:
	X_drug, X_target, y, ID_drug, ID_target = df_want.SMILES.values, df_want['Target Sequence'].values, np.array(y), df_want['PubChem_ID'].values, df_want['UniProt_ID'].values
X_drug, X_target, y = df_want.SMILES.values, df_want['Target Sequence'].values, np.array(y)
# Out:
# Beginning Processing...
# There are 1592671 drug target pairs.
# Default set to logspace (nM -> p) for easier regression

# %%
#### select endcoder ####
drug_encoding, target_encoding = 'CNN', 'CNN'

# %%
#### data_process ####

# parameter
split_method = 'random'
frac = [0.7, 0.1, 0.2]
random_seed = 1
sample_frac = 1
mode = 'DTI'
X_drug_ = None
X_target_ = None

# data_process : dataframe

if random_seed == 'TDC':
	random_seed = 1234
 
#property_prediction_flag = X_target is None
property_prediction_flag, function_prediction_flag, DDI_flag, PPI_flag, DTI_flag = False, False, False, False, False

if (X_drug is not None) and (X_target is not None):
	DTI_flag = True
	if (X_drug is None) or (X_target is None):
		raise AttributeError("Target pair sequence should be in X_target, X_drug")
else:
	raise AttributeError("Please use the correct mode. Currently, we support DTI, DDI, PPI, Drug Property Prediction and Protein Function Prediction...")

if split_method == 'repurposing_VS':
	y = [-1]*len(X_drug) # create temp y for compatitibility

if DTI_flag:
	print('Drug Target Interaction Prediction Mode...')
	if isinstance(X_target, str):
		X_target = [X_target]
	if len(X_target) == 1:
		# one target high throughput screening setting
		X_target = np.tile(X_target, (length_func(X_drug), ))

	df_data = pd.DataFrame(zip(X_drug, X_target, y))
	df_data.rename(columns={0:'SMILES',
							1: 'Target Sequence',
							2: 'Label'}, 
							inplace=True)
	print('in total: ' + str(len(df_data)) + ' drug-target pairs')
 
# data_process : endcoding & splitting

if sample_frac != 1:
	df_data = df_data.sample(frac = sample_frac) #.reset_index(drop = True)
	print('after subsample: ' + str(len(df_data)) + ' data points...') 

if DTI_flag:
	df_data = utils.encode_drug(df_data, drug_encoding)
	df_data = utils.encode_protein(df_data, target_encoding)
# Out:
# Drug Target Interaction Prediction Mode...
# in total: 1592671 drug-target pairs
# encoding drug...
# unique drugs: 770912
# encoding protein...
# unique target sequence: 5735

# %%
# after pre-processing set 불러오기
after_train = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_train.tsv', sep='\t', index_col=0)
after_val = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_val.tsv', sep='\t', index_col=0)
after_test = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_test.tsv', sep='\t', index_col=0)

# %%
after_val['index_val'].values
# Out:
# array([ 520137,    5876,  773576, ...,  253865, 1014785,  758771],
#       dtype=int64)

# %%
# 같은 index를 가지게 split / index 초기화
train = df_data.loc[after_train['index_train'].values, :]
val = df_data.loc[after_val['index_val'].values, :]
test = df_data.loc[after_test['index_test'].values, :]
train, val, test = train.reset_index(drop=True), val.reset_index(drop=True), test.reset_index(drop=True)

# %%
# Model configuration genreration
config = utils.generate_config(drug_encoding = drug_encoding, 
                         target_encoding = target_encoding, 
                         cls_hidden_dims = [1024,1024,512], 
                         train_epoch = 50, 
                         test_every_X_epoch = 10, 
                         LR = 0.001, 
                         batch_size = 256,
                         hidden_dim_drug = 128,
                         cnn_drug_filters = [32,64,96],
                         cnn_drug_kernels = [4,6,8],
                         cnn_target_filters = [32,64,96],
                         cnn_target_kernels = [4,8,12]
                        )

# %%
# Model initialization
model = models.model_initialize(**config)
model

# %%
# Model training
model.train(train, val, test)

# Model saving
model.save_model('./pretrained_model/CNN_CNN_BindingDB_IC50_before/')
# Out:
# Let's use 1 GPU!
# --- Data Preparation ---
# --- Go for Training ---
# Training at Epoch 1 iteration 0 with loss 41.8660. Total time 0.00222 hours
# Training at Epoch 1 iteration 100 with loss 2.08345. Total time 0.02166 hours
# Training at Epoch 1 iteration 200 with loss 2.37071. Total time 0.04083 hours
# Training at Epoch 1 iteration 300 with loss 1.93328. Total time 0.06027 hours
# Training at Epoch 1 iteration 400 with loss 1.69961. Total time 0.07944 hours
# Training at Epoch 1 iteration 500 with loss 1.63595. Total time 0.09861 hours
# Training at Epoch 1 iteration 600 with loss 1.59493. Total time 0.11805 hours
# Training at Epoch 1 iteration 700 with loss 1.64028. Total time 0.13722 hours
# Training at Epoch 1 iteration 800 with loss 1.63981. Total time 0.15666 hours
# Training at Epoch 1 iteration 900 with loss 1.44838. Total time 0.17611 hours
# Training at Epoch 1 iteration 1000 with loss 1.39651. Total time 0.19555 hours
# Training at Epoch 1 iteration 1100 with loss 1.62608. Total time 0.21472 hours
# Training at Epoch 1 iteration 1200 with loss 1.34564. Total time 0.23388 hours
# Training at Epoch 1 iteration 1300 with loss 1.48293. Total time 0.2525 hours
# Training at Epoch 1 iteration 1400 with loss 1.62463. Total time 0.27138 hours
# Training at Epoch 1 iteration 1500 with loss 1.59854. Total time 0.29027 hours
# Training at Epoch 1 iteration 1600 with loss 1.37493. Total time 0.30888 hours
# Training at Epoch 1 iteration 1700 with loss 1.29763. Total time 0.32777 hours
# Training at Epoch 1 iteration 1800 with loss 1.28210. Total time 0.34638 hours
# Training at Epoch 1 iteration 1900 with loss 1.47635. Total time 0.36527 hours
# Training at Epoch 1 iteration 2000 with loss 1.34549. Total time 0.38388 hours
# Training at Epoch 1 iteration 2100 with loss 1.37379. Total time 0.40277 hours
# Training at Epoch 1 iteration 2200 with loss 1.53639. Total time 0.42138 hours
# Training at Epoch 1 iteration 2300 with loss 1.41906. Total time 0.44027 hours
# Training at Epoch 1 iteration 2400 with loss 1.37239. Total time 0.45888 hours
# Training at Epoch 1 iteration 2500 with loss 1.23584. Total time 0.47777 hours
# Training at Epoch 1 iteration 2600 with loss 1.33416. Total time 0.49666 hours
# Training at Epoch 1 iteration 2700 with loss 1.25487. Total time 0.51527 hours
# Training at Epoch 1 iteration 2800 with loss 1.29824. Total time 0.53416 hours
# Training at Epoch 1 iteration 2900 with loss 1.25257. Total time 0.55277 hours
# Training at Epoch 1 iteration 3000 with loss 1.65701. Total time 0.57166 hours
# Training at Epoch 1 iteration 3100 with loss 1.25342. Total time 0.59027 hours
# Training at Epoch 1 iteration 3200 with loss 1.24029. Total time 0.60916 hours
# Training at Epoch 1 iteration 3300 with loss 1.25074. Total time 0.62777 hours
# Training at Epoch 1 iteration 3400 with loss 1.47105. Total time 0.64666 hours
# Training at Epoch 1 iteration 3500 with loss 1.12046. Total time 0.66527 hours
# Training at Epoch 1 iteration 3600 with loss 1.28274. Total time 0.68416 hours
# Training at Epoch 1 iteration 3700 with loss 1.17740. Total time 0.70277 hours
# Training at Epoch 1 iteration 3800 with loss 1.18587. Total time 0.72166 hours
# Training at Epoch 1 iteration 3900 with loss 1.19245. Total time 0.74027 hours
# Training at Epoch 1 iteration 4000 with loss 1.41366. Total time 0.75916 hours
# Training at Epoch 1 iteration 4100 with loss 1.14686. Total time 0.77777 hours
# Training at Epoch 1 iteration 4200 with loss 1.13542. Total time 0.79666 hours
# Training at Epoch 1 iteration 4300 with loss 1.37088. Total time 0.81527 hours
# Validation at Epoch 1 with loss:0.68885, MSE: 1.19858 , Pearson Correlation: 0.67953 with p-value: 0.00E+00 , Concordance Index: 0.74498
# Training at Epoch 2 iteration 0 with loss 1.29468. Total time 0.92416 hours
# Training at Epoch 2 iteration 100 with loss 1.14833. Total time 0.94305 hours
# Training at Epoch 2 iteration 200 with loss 1.17704. Total time 0.96166 hours
# Training at Epoch 2 iteration 300 with loss 1.28024. Total time 0.98055 hours
# Training at Epoch 2 iteration 400 with loss 1.21963. Total time 0.99916 hours
# Training at Epoch 2 iteration 500 with loss 1.74174. Total time 1.01805 hours
# Training at Epoch 2 iteration 600 with loss 1.20320. Total time 1.03666 hours
# Training at Epoch 2 iteration 700 with loss 1.35799. Total time 1.05555 hours
# Training at Epoch 2 iteration 800 with loss 1.25194. Total time 1.07416 hours
# Training at Epoch 2 iteration 900 with loss 1.01251. Total time 1.09305 hours
# Training at Epoch 2 iteration 1000 with loss 1.06373. Total time 1.11166 hours
# Training at Epoch 2 iteration 1100 with loss 1.41138. Total time 1.13055 hours
# Training at Epoch 2 iteration 1200 with loss 1.11811. Total time 1.14916 hours
# Training at Epoch 2 iteration 1300 with loss 1.24463. Total time 1.16805 hours
# Training at Epoch 2 iteration 1400 with loss 1.36245. Total time 1.18666 hours
# Training at Epoch 2 iteration 1500 with loss 1.13991. Total time 1.20555 hours
# Training at Epoch 2 iteration 1600 with loss 2.07559. Total time 1.22416 hours
# Training at Epoch 2 iteration 1700 with loss 1.23350. Total time 1.24305 hours
# Training at Epoch 2 iteration 1800 with loss 1.04740. Total time 1.26166 hours
# Training at Epoch 2 iteration 1900 with loss 1.32392. Total time 1.28055 hours
# Training at Epoch 2 iteration 2000 with loss 1.12837. Total time 1.29916 hours
# Training at Epoch 2 iteration 2100 with loss 1.33861. Total time 1.31805 hours
# Training at Epoch 2 iteration 2200 with loss 1.24994. Total time 1.33666 hours
# Training at Epoch 2 iteration 2300 with loss 1.02903. Total time 1.35555 hours
# Training at Epoch 2 iteration 2400 with loss 1.11834. Total time 1.37416 hours
# Training at Epoch 2 iteration 2500 with loss 1.01547. Total time 1.39277 hours
# Training at Epoch 2 iteration 2600 with loss 1.15699. Total time 1.41166 hours
# Training at Epoch 2 iteration 2700 with loss 0.95799. Total time 1.43027 hours
# Training at Epoch 2 iteration 2800 with loss 1.17993. Total time 1.44916 hours
# Training at Epoch 2 iteration 2900 with loss 1.19108. Total time 1.46777 hours
# Training at Epoch 2 iteration 3000 with loss 1.19557. Total time 1.48666 hours
# Training at Epoch 2 iteration 3100 with loss 1.22923. Total time 1.50527 hours
# Training at Epoch 2 iteration 3200 with loss 1.18414. Total time 1.52416 hours
# Training at Epoch 2 iteration 3300 with loss 1.02713. Total time 1.54277 hours
# Training at Epoch 2 iteration 3400 with loss 1.45403. Total time 1.56166 hours
# Training at Epoch 2 iteration 3500 with loss 0.94857. Total time 1.58027 hours
# Training at Epoch 2 iteration 3600 with loss 1.33150. Total time 1.59916 hours
# Training at Epoch 2 iteration 3700 with loss 1.14862. Total time 1.61777 hours
# Training at Epoch 2 iteration 3800 with loss 1.12517. Total time 1.63666 hours
# Training at Epoch 2 iteration 3900 with loss 1.12325. Total time 1.65527 hours
# Training at Epoch 2 iteration 4000 with loss 1.11042. Total time 1.67388 hours
# Training at Epoch 2 iteration 4100 with loss 1.19030. Total time 1.69277 hours
# Training at Epoch 2 iteration 4200 with loss 1.08504. Total time 1.71138 hours
# Training at Epoch 2 iteration 4300 with loss 0.97506. Total time 1.73027 hours
# Validation at Epoch 2 with loss:1.85948, MSE: 1.09196 , Pearson Correlation: 0.71092 with p-value: 0.00E+00 , Concordance Index: 0.75991
# Training at Epoch 3 iteration 0 with loss 1.11909. Total time 1.83944 hours
# Training at Epoch 3 iteration 100 with loss 0.97559. Total time 1.85805 hours
# Training at Epoch 3 iteration 200 with loss 0.98944. Total time 1.87694 hours
# Training at Epoch 3 iteration 300 with loss 1.02270. Total time 1.89555 hours
# Training at Epoch 3 iteration 400 with loss 1.19470. Total time 1.91444 hours
# Training at Epoch 3 iteration 500 with loss 1.04048. Total time 1.93305 hours
# Training at Epoch 3 iteration 600 with loss 1.12659. Total time 1.95166 hours
# Training at Epoch 3 iteration 700 with loss 1.06103. Total time 1.97055 hours
# Training at Epoch 3 iteration 800 with loss 0.99374. Total time 1.98916 hours
# Training at Epoch 3 iteration 900 with loss 1.11585. Total time 2.00805 hours
# Training at Epoch 3 iteration 1000 with loss 1.06926. Total time 2.02666 hours
# Training at Epoch 3 iteration 1100 with loss 1.00983. Total time 2.04555 hours
# Training at Epoch 3 iteration 1200 with loss 1.08140. Total time 2.06416 hours
# Training at Epoch 3 iteration 1300 with loss 1.18171. Total time 2.08305 hours
# Training at Epoch 3 iteration 1400 with loss 1.12334. Total time 2.10166 hours
# Training at Epoch 3 iteration 1500 with loss 1.15608. Total time 2.12027 hours
# Training at Epoch 3 iteration 1600 with loss 1.10700. Total time 2.13916 hours
# Training at Epoch 3 iteration 1700 with loss 1.05787. Total time 2.15777 hours
# Training at Epoch 3 iteration 1800 with loss 1.17328. Total time 2.17666 hours
# Training at Epoch 3 iteration 1900 with loss 1.16972. Total time 2.19527 hours
# Training at Epoch 3 iteration 2000 with loss 1.06727. Total time 2.21416 hours
# Training at Epoch 3 iteration 2100 with loss 0.99635. Total time 2.23333 hours
# Training at Epoch 3 iteration 2200 with loss 0.99842. Total time 2.25222 hours
# Training at Epoch 3 iteration 2300 with loss 1.05680. Total time 2.27111 hours
# Training at Epoch 3 iteration 2400 with loss 1.42159. Total time 2.29 hours
# Training at Epoch 3 iteration 2500 with loss 1.02933. Total time 2.30888 hours
# Training at Epoch 3 iteration 2600 with loss 0.89737. Total time 2.32777 hours
# Training at Epoch 3 iteration 2700 with loss 1.02241. Total time 2.34694 hours
# Training at Epoch 3 iteration 2800 with loss 0.94167. Total time 2.36583 hours
# Training at Epoch 3 iteration 2900 with loss 1.23809. Total time 2.38472 hours
# Training at Epoch 3 iteration 3000 with loss 0.84432. Total time 2.40361 hours
# Training at Epoch 3 iteration 3100 with loss 1.29378. Total time 2.4225 hours
# Training at Epoch 3 iteration 3200 with loss 1.02541. Total time 2.44166 hours
# Training at Epoch 3 iteration 3300 with loss 1.15245. Total time 2.46055 hours
# Training at Epoch 3 iteration 3400 with loss 1.06632. Total time 2.47944 hours
# Training at Epoch 3 iteration 3500 with loss 1.22233. Total time 2.49833 hours
# Training at Epoch 3 iteration 3600 with loss 1.15447. Total time 2.51722 hours
# Training at Epoch 3 iteration 3700 with loss 1.09986. Total time 2.53611 hours
# Training at Epoch 3 iteration 3800 with loss 1.00303. Total time 2.55527 hours
# Training at Epoch 3 iteration 3900 with loss 1.23187. Total time 2.57416 hours
# Training at Epoch 3 iteration 4000 with loss 0.91092. Total time 2.59305 hours
# Training at Epoch 3 iteration 4100 with loss 0.94463. Total time 2.61194 hours
# Training at Epoch 3 iteration 4200 with loss 1.08088. Total time 2.63083 hours
# Training at Epoch 3 iteration 4300 with loss 1.03801. Total time 2.65 hours
# Validation at Epoch 3 with loss:1.37121, MSE: 1.02775 , Pearson Correlation: 0.73119 with p-value: 0.00E+00 , Concordance Index: 0.77032
# Training at Epoch 4 iteration 0 with loss 0.97470. Total time 2.75916 hours
# Training at Epoch 4 iteration 100 with loss 0.82613. Total time 2.77805 hours
# Training at Epoch 4 iteration 200 with loss 1.14616. Total time 2.79666 hours
# Training at Epoch 4 iteration 300 with loss 1.18323. Total time 2.81555 hours
# Training at Epoch 4 iteration 400 with loss 0.98201. Total time 2.83416 hours
# Training at Epoch 4 iteration 500 with loss 1.68456. Total time 2.85277 hours
# Training at Epoch 4 iteration 600 with loss 1.02996. Total time 2.87194 hours
# Training at Epoch 4 iteration 700 with loss 0.99760. Total time 2.89083 hours
# Training at Epoch 4 iteration 800 with loss 0.90232. Total time 2.90972 hours
# Training at Epoch 4 iteration 900 with loss 1.10281. Total time 2.92861 hours
# Training at Epoch 4 iteration 1000 with loss 1.25831. Total time 2.9475 hours
# Training at Epoch 4 iteration 1100 with loss 0.92690. Total time 2.96638 hours
# Training at Epoch 4 iteration 1200 with loss 0.95053. Total time 2.98555 hours
# Training at Epoch 4 iteration 1300 with loss 0.95716. Total time 3.00444 hours
# Training at Epoch 4 iteration 1400 with loss 0.83107. Total time 3.02333 hours
# Training at Epoch 4 iteration 1500 with loss 1.08658. Total time 3.04222 hours
# Training at Epoch 4 iteration 1600 with loss 0.88417. Total time 3.06111 hours
# Training at Epoch 4 iteration 1700 with loss 1.20465. Total time 3.08 hours
# Training at Epoch 4 iteration 1800 with loss 0.90600. Total time 3.09916 hours
# Training at Epoch 4 iteration 1900 with loss 1.07347. Total time 3.11805 hours
# Training at Epoch 4 iteration 2000 with loss 1.03541. Total time 3.13694 hours
# Training at Epoch 4 iteration 2100 with loss 0.86295. Total time 3.15583 hours
# Training at Epoch 4 iteration 2200 with loss 0.95800. Total time 3.17472 hours
# Training at Epoch 4 iteration 2300 with loss 0.83758. Total time 3.19361 hours
# Training at Epoch 4 iteration 2400 with loss 0.95804. Total time 3.21277 hours
# Training at Epoch 4 iteration 2500 with loss 1.00169. Total time 3.23166 hours
# Training at Epoch 4 iteration 2600 with loss 0.85874. Total time 3.25055 hours
# Training at Epoch 4 iteration 2700 with loss 1.09383. Total time 3.26944 hours
# Training at Epoch 4 iteration 2800 with loss 1.07434. Total time 3.28833 hours
# Training at Epoch 4 iteration 2900 with loss 0.81895. Total time 3.3075 hours
# Training at Epoch 4 iteration 3000 with loss 0.98223. Total time 3.32638 hours
# Training at Epoch 4 iteration 3100 with loss 1.02897. Total time 3.34527 hours
# Training at Epoch 4 iteration 3200 with loss 1.07809. Total time 3.36416 hours
# Training at Epoch 4 iteration 3300 with loss 0.98632. Total time 3.38305 hours
# Training at Epoch 4 iteration 3400 with loss 1.04990. Total time 3.40194 hours
# Training at Epoch 4 iteration 3500 with loss 1.03741. Total time 3.42111 hours
# Training at Epoch 4 iteration 3600 with loss 1.05435. Total time 3.44 hours
# Training at Epoch 4 iteration 3700 with loss 0.98666. Total time 3.45888 hours
# Training at Epoch 4 iteration 3800 with loss 0.95155. Total time 3.47777 hours
# Training at Epoch 4 iteration 3900 with loss 0.99015. Total time 3.49666 hours
# Training at Epoch 4 iteration 4000 with loss 1.15364. Total time 3.51555 hours
# Training at Epoch 4 iteration 4100 with loss 1.06166. Total time 3.53444 hours
# Training at Epoch 4 iteration 4200 with loss 1.06880. Total time 3.55361 hours
# Training at Epoch 4 iteration 4300 with loss 1.16761. Total time 3.5725 hours
# Validation at Epoch 4 with loss:0.85254, MSE: 0.98687 , Pearson Correlation: 0.74331 with p-value: 0.00E+00 , Concordance Index: 0.77644
# Training at Epoch 5 iteration 0 with loss 0.88239. Total time 3.68194 hours
# Training at Epoch 5 iteration 100 with loss 0.88338. Total time 3.70083 hours
# Training at Epoch 5 iteration 200 with loss 0.83169. Total time 3.71972 hours
# Training at Epoch 5 iteration 300 with loss 0.87893. Total time 3.73861 hours
# Training at Epoch 5 iteration 400 with loss 1.08373. Total time 3.7575 hours
# Training at Epoch 5 iteration 500 with loss 0.99390. Total time 3.77638 hours
# Training at Epoch 5 iteration 600 with loss 0.90518. Total time 3.79527 hours
# Training at Epoch 5 iteration 700 with loss 1.03599. Total time 3.81444 hours
# Training at Epoch 5 iteration 800 with loss 1.17252. Total time 3.83333 hours
# Training at Epoch 5 iteration 900 with loss 0.97533. Total time 3.85222 hours
# Training at Epoch 5 iteration 1000 with loss 1.01826. Total time 3.87111 hours
# Training at Epoch 5 iteration 1100 with loss 0.81672. Total time 3.89 hours
# Training at Epoch 5 iteration 1200 with loss 1.15644. Total time 3.90888 hours
# Training at Epoch 5 iteration 1300 with loss 0.90353. Total time 3.92805 hours
# Training at Epoch 5 iteration 1400 with loss 1.00023. Total time 3.94694 hours
# Training at Epoch 5 iteration 1500 with loss 1.15215. Total time 3.96583 hours
# Training at Epoch 5 iteration 1600 with loss 0.85153. Total time 3.98472 hours
# Training at Epoch 5 iteration 1700 with loss 1.27300. Total time 4.00361 hours
# Training at Epoch 5 iteration 1800 with loss 1.03569. Total time 4.0225 hours
# Training at Epoch 5 iteration 1900 with loss 1.49851. Total time 4.04138 hours
# Training at Epoch 5 iteration 2000 with loss 1.04622. Total time 4.06027 hours
# Training at Epoch 5 iteration 2100 with loss 1.14238. Total time 4.07944 hours
# Training at Epoch 5 iteration 2200 with loss 0.96703. Total time 4.09833 hours
# Training at Epoch 5 iteration 2300 with loss 0.95423. Total time 4.11722 hours
# Training at Epoch 5 iteration 2400 with loss 0.95172. Total time 4.13611 hours
# Training at Epoch 5 iteration 2500 with loss 0.93206. Total time 4.155 hours
# Training at Epoch 5 iteration 2600 with loss 1.02965. Total time 4.17388 hours
# Training at Epoch 5 iteration 2700 with loss 1.11444. Total time 4.19305 hours
# Training at Epoch 5 iteration 2800 with loss 0.99372. Total time 4.21194 hours
# Training at Epoch 5 iteration 2900 with loss 0.82613. Total time 4.23083 hours
# Training at Epoch 5 iteration 3000 with loss 0.88817. Total time 4.24972 hours
# Training at Epoch 5 iteration 3100 with loss 0.91751. Total time 4.26861 hours
# Training at Epoch 5 iteration 3200 with loss 0.89063. Total time 4.2875 hours
# Training at Epoch 5 iteration 3300 with loss 0.85319. Total time 4.30638 hours
# Training at Epoch 5 iteration 3400 with loss 0.94357. Total time 4.32527 hours
# Training at Epoch 5 iteration 3500 with loss 1.07321. Total time 4.34444 hours
# Training at Epoch 5 iteration 3600 with loss 0.84285. Total time 4.36333 hours
# Training at Epoch 5 iteration 3700 with loss 0.99208. Total time 4.38222 hours
# Training at Epoch 5 iteration 3800 with loss 1.12796. Total time 4.40111 hours
# Training at Epoch 5 iteration 3900 with loss 1.04978. Total time 4.42 hours
# Training at Epoch 5 iteration 4000 with loss 0.91136. Total time 4.43888 hours
# Training at Epoch 5 iteration 4100 with loss 0.82360. Total time 4.45777 hours
# Training at Epoch 5 iteration 4200 with loss 0.80250. Total time 4.47694 hours
# Training at Epoch 5 iteration 4300 with loss 0.83481. Total time 4.49583 hours
# Validation at Epoch 5 with loss:1.62298, MSE: 0.97008 , Pearson Correlation: 0.75626 with p-value: 0.00E+00 , Concordance Index: 0.78247
# Training at Epoch 6 iteration 0 with loss 0.84746. Total time 4.605 hours
# Training at Epoch 6 iteration 100 with loss 0.92799. Total time 4.62388 hours
# Training at Epoch 6 iteration 200 with loss 0.98180. Total time 4.6425 hours
# Training at Epoch 6 iteration 300 with loss 0.96423. Total time 4.66138 hours
# Training at Epoch 6 iteration 400 with loss 1.14808. Total time 4.68 hours
# Training at Epoch 6 iteration 500 with loss 0.90821. Total time 4.69861 hours
# Training at Epoch 6 iteration 600 with loss 0.97111. Total time 4.7175 hours
# Training at Epoch 6 iteration 700 with loss 1.03649. Total time 4.73611 hours
# Training at Epoch 6 iteration 800 with loss 1.01959. Total time 4.75472 hours
# Training at Epoch 6 iteration 900 with loss 1.00182. Total time 4.77361 hours
# Training at Epoch 6 iteration 1000 with loss 0.92786. Total time 4.79222 hours
# Training at Epoch 6 iteration 1100 with loss 1.02039. Total time 4.81083 hours
# Training at Epoch 6 iteration 1200 with loss 0.92415. Total time 4.82972 hours
# Training at Epoch 6 iteration 1300 with loss 0.94286. Total time 4.84833 hours
# Training at Epoch 6 iteration 1400 with loss 0.99643. Total time 4.86694 hours
# Training at Epoch 6 iteration 1500 with loss 1.00194. Total time 4.88583 hours
# Training at Epoch 6 iteration 1600 with loss 0.96971. Total time 4.90444 hours
# Training at Epoch 6 iteration 1700 with loss 0.78640. Total time 4.92305 hours
# Training at Epoch 6 iteration 1800 with loss 0.85402. Total time 4.94194 hours
# Training at Epoch 6 iteration 1900 with loss 0.90256. Total time 4.96055 hours
# Training at Epoch 6 iteration 2000 with loss 0.79232. Total time 4.97916 hours
# Training at Epoch 6 iteration 2100 with loss 0.87613. Total time 4.99805 hours
# Training at Epoch 6 iteration 2200 with loss 0.86786. Total time 5.01666 hours
# Training at Epoch 6 iteration 2300 with loss 1.02889. Total time 5.03527 hours
# Training at Epoch 6 iteration 2400 with loss 1.11649. Total time 5.05416 hours
# Training at Epoch 6 iteration 2500 with loss 1.00034. Total time 5.07277 hours
# Training at Epoch 6 iteration 2600 with loss 1.02416. Total time 5.09138 hours
# Training at Epoch 6 iteration 2700 with loss 1.22973. Total time 5.11027 hours
# Training at Epoch 6 iteration 2800 with loss 1.03378. Total time 5.12888 hours
# Training at Epoch 6 iteration 2900 with loss 0.99601. Total time 5.1475 hours
# Training at Epoch 6 iteration 3000 with loss 1.11847. Total time 5.16638 hours
# Training at Epoch 6 iteration 3100 with loss 1.12478. Total time 5.185 hours
# Training at Epoch 6 iteration 3200 with loss 0.83634. Total time 5.20361 hours
# Training at Epoch 6 iteration 3300 with loss 0.87422. Total time 5.2225 hours
# Training at Epoch 6 iteration 3400 with loss 0.96740. Total time 5.24111 hours
# Training at Epoch 6 iteration 3500 with loss 0.79933. Total time 5.25972 hours
# Training at Epoch 6 iteration 3600 with loss 1.01725. Total time 5.27861 hours
# Training at Epoch 6 iteration 3700 with loss 0.89889. Total time 5.29722 hours
# Training at Epoch 6 iteration 3800 with loss 0.94674. Total time 5.31583 hours
# Training at Epoch 6 iteration 3900 with loss 0.89251. Total time 5.33472 hours
# Training at Epoch 6 iteration 4000 with loss 0.86717. Total time 5.35333 hours
# Training at Epoch 6 iteration 4100 with loss 1.01728. Total time 5.37194 hours
# Training at Epoch 6 iteration 4200 with loss 0.98485. Total time 5.39083 hours
# Training at Epoch 6 iteration 4300 with loss 0.77450. Total time 5.40944 hours
# Validation at Epoch 6 with loss:1.07562, MSE: 0.96910 , Pearson Correlation: 0.76250 with p-value: 0.00E+00 , Concordance Index: 0.78594
# Training at Epoch 7 iteration 0 with loss 0.86000. Total time 5.51861 hours
# Training at Epoch 7 iteration 100 with loss 0.93804. Total time 5.53722 hours
# Training at Epoch 7 iteration 200 with loss 0.86853. Total time 5.55611 hours
# Training at Epoch 7 iteration 300 with loss 0.94841. Total time 5.57472 hours
# Training at Epoch 7 iteration 400 with loss 0.88901. Total time 5.59333 hours
# Training at Epoch 7 iteration 500 with loss 0.76963. Total time 5.61222 hours
# Training at Epoch 7 iteration 600 with loss 0.85184. Total time 5.63083 hours
# Training at Epoch 7 iteration 700 with loss 1.17501. Total time 5.64944 hours
# Training at Epoch 7 iteration 800 with loss 1.08270. Total time 5.66833 hours
# Training at Epoch 7 iteration 900 with loss 1.01869. Total time 5.68694 hours
# Training at Epoch 7 iteration 1000 with loss 0.78203. Total time 5.70555 hours
# Training at Epoch 7 iteration 1100 with loss 0.74635. Total time 5.72444 hours
# Training at Epoch 7 iteration 1200 with loss 0.91777. Total time 5.74305 hours
# Training at Epoch 7 iteration 1300 with loss 0.94990. Total time 5.76166 hours
# Training at Epoch 7 iteration 1400 with loss 1.00300. Total time 5.78055 hours
# Training at Epoch 7 iteration 1500 with loss 1.03863. Total time 5.79916 hours
# Training at Epoch 7 iteration 1600 with loss 0.82403. Total time 5.81777 hours
# Training at Epoch 7 iteration 1700 with loss 0.88411. Total time 5.83666 hours
# Training at Epoch 7 iteration 1800 with loss 0.97713. Total time 5.85527 hours
# Training at Epoch 7 iteration 1900 with loss 1.04145. Total time 5.87388 hours
# Training at Epoch 7 iteration 2000 with loss 0.85877. Total time 5.89277 hours
# Training at Epoch 7 iteration 2100 with loss 0.95323. Total time 5.91138 hours
# Training at Epoch 7 iteration 2200 with loss 1.03215. Total time 5.93 hours
# Training at Epoch 7 iteration 2300 with loss 0.88447. Total time 5.94888 hours
# Training at Epoch 7 iteration 2400 with loss 0.90097. Total time 5.9675 hours
# Training at Epoch 7 iteration 2500 with loss 1.11018. Total time 5.98611 hours
# Training at Epoch 7 iteration 2600 with loss 1.00622. Total time 6.00472 hours
# Training at Epoch 7 iteration 2700 with loss 1.11588. Total time 6.02361 hours
# Training at Epoch 7 iteration 2800 with loss 0.95769. Total time 6.04222 hours
# Training at Epoch 7 iteration 2900 with loss 0.74966. Total time 6.06083 hours
# Training at Epoch 7 iteration 3000 with loss 0.84867. Total time 6.07972 hours
# Training at Epoch 7 iteration 3100 with loss 0.86879. Total time 6.09833 hours
# Training at Epoch 7 iteration 3200 with loss 1.03022. Total time 6.11694 hours
# Training at Epoch 7 iteration 3300 with loss 1.01081. Total time 6.13583 hours
# Training at Epoch 7 iteration 3400 with loss 0.93265. Total time 6.15444 hours
# Training at Epoch 7 iteration 3500 with loss 0.98790. Total time 6.17305 hours
# Training at Epoch 7 iteration 3600 with loss 0.98527. Total time 6.19194 hours
# Training at Epoch 7 iteration 3700 with loss 0.99694. Total time 6.21055 hours
# Training at Epoch 7 iteration 3800 with loss 0.61704. Total time 6.22916 hours
# Training at Epoch 7 iteration 3900 with loss 0.82819. Total time 6.24805 hours
# Training at Epoch 7 iteration 4000 with loss 0.78794. Total time 6.26666 hours
# Training at Epoch 7 iteration 4100 with loss 1.05748. Total time 6.28527 hours
# Training at Epoch 7 iteration 4200 with loss 0.87174. Total time 6.30416 hours
# Training at Epoch 7 iteration 4300 with loss 0.81227. Total time 6.32277 hours
# Validation at Epoch 7 with loss:1.07734, MSE: 0.92683 , Pearson Correlation: 0.76895 with p-value: 0.00E+00 , Concordance Index: 0.78910
# Training at Epoch 8 iteration 0 with loss 0.99332. Total time 6.43166 hours
# Training at Epoch 8 iteration 100 with loss 0.92606. Total time 6.45055 hours
# Training at Epoch 8 iteration 200 with loss 0.76780. Total time 6.46944 hours
# Training at Epoch 8 iteration 300 with loss 0.80557. Total time 6.48805 hours
# Training at Epoch 8 iteration 400 with loss 0.81128. Total time 6.50666 hours
# Training at Epoch 8 iteration 500 with loss 0.91823. Total time 6.52555 hours
# Training at Epoch 8 iteration 600 with loss 0.93985. Total time 6.54416 hours
# Training at Epoch 8 iteration 700 with loss 0.80554. Total time 6.56277 hours
# Training at Epoch 8 iteration 800 with loss 0.91893. Total time 6.58138 hours
# Training at Epoch 8 iteration 900 with loss 0.78742. Total time 6.60027 hours
# Training at Epoch 8 iteration 1000 with loss 0.83134. Total time 6.61888 hours
# Training at Epoch 8 iteration 1100 with loss 0.93292. Total time 6.6375 hours
# Training at Epoch 8 iteration 1200 with loss 0.90275. Total time 6.65638 hours
# Training at Epoch 8 iteration 1300 with loss 1.02333. Total time 6.675 hours
# Training at Epoch 8 iteration 1400 with loss 0.79699. Total time 6.69361 hours
# Training at Epoch 8 iteration 1500 with loss 0.79934. Total time 6.7125 hours
# Training at Epoch 8 iteration 1600 with loss 0.93142. Total time 6.73111 hours
# Training at Epoch 8 iteration 1700 with loss 0.79445. Total time 6.74972 hours
# Training at Epoch 8 iteration 1800 with loss 0.87071. Total time 6.76861 hours
# Training at Epoch 8 iteration 1900 with loss 0.87814. Total time 6.78722 hours
# Training at Epoch 8 iteration 2000 with loss 0.96997. Total time 6.80583 hours
# Training at Epoch 8 iteration 2100 with loss 0.81218. Total time 6.82472 hours
# Training at Epoch 8 iteration 2200 with loss 0.90847. Total time 6.84333 hours
# Training at Epoch 8 iteration 2300 with loss 1.07732. Total time 6.86194 hours
# Training at Epoch 8 iteration 2400 with loss 0.76500. Total time 6.88083 hours
# Training at Epoch 8 iteration 2500 with loss 0.75540. Total time 6.89944 hours
# Training at Epoch 8 iteration 2600 with loss 1.17850. Total time 6.91805 hours
# Training at Epoch 8 iteration 2700 with loss 0.94858. Total time 6.93694 hours
# Training at Epoch 8 iteration 2800 with loss 0.85261. Total time 6.95555 hours
# Training at Epoch 8 iteration 2900 with loss 0.88151. Total time 6.97416 hours
# Training at Epoch 8 iteration 3000 with loss 0.90338. Total time 6.99305 hours
# Training at Epoch 8 iteration 3100 with loss 0.83991. Total time 7.01166 hours
# Training at Epoch 8 iteration 3200 with loss 0.89244. Total time 7.03027 hours
# Training at Epoch 8 iteration 3300 with loss 0.90915. Total time 7.04916 hours
# Training at Epoch 8 iteration 3400 with loss 0.67805. Total time 7.06777 hours
# Training at Epoch 8 iteration 3500 with loss 0.80341. Total time 7.08638 hours
# Training at Epoch 8 iteration 3600 with loss 0.81725. Total time 7.105 hours
# Training at Epoch 8 iteration 3700 with loss 0.84926. Total time 7.12388 hours
# Training at Epoch 8 iteration 3800 with loss 0.85325. Total time 7.1425 hours
# Training at Epoch 8 iteration 3900 with loss 0.98595. Total time 7.16111 hours
# Training at Epoch 8 iteration 4000 with loss 0.92351. Total time 7.18 hours
# Training at Epoch 8 iteration 4100 with loss 0.85585. Total time 7.19861 hours
# Training at Epoch 8 iteration 4200 with loss 0.79808. Total time 7.21722 hours
# Training at Epoch 8 iteration 4300 with loss 1.02800. Total time 7.23611 hours
# Validation at Epoch 8 with loss:0.93037, MSE: 0.88333 , Pearson Correlation: 0.77402 with p-value: 0.00E+00 , Concordance Index: 0.79178
# Training at Epoch 9 iteration 0 with loss 0.95525. Total time 7.345 hours
# Training at Epoch 9 iteration 100 with loss 0.97144. Total time 7.36388 hours
# Training at Epoch 9 iteration 200 with loss 0.87138. Total time 7.3825 hours
# Training at Epoch 9 iteration 300 with loss 0.89654. Total time 7.40138 hours
# Training at Epoch 9 iteration 400 with loss 0.90975. Total time 7.42 hours
# Training at Epoch 9 iteration 500 with loss 1.08537. Total time 7.43861 hours
# Training at Epoch 9 iteration 600 with loss 0.94283. Total time 7.4575 hours
# Training at Epoch 9 iteration 700 with loss 0.84956. Total time 7.47611 hours
# Training at Epoch 9 iteration 800 with loss 0.76833. Total time 7.49472 hours
# Training at Epoch 9 iteration 900 with loss 1.01024. Total time 7.51361 hours
# Training at Epoch 9 iteration 1000 with loss 0.89997. Total time 7.53222 hours
# Training at Epoch 9 iteration 1100 with loss 0.85249. Total time 7.55083 hours
# Training at Epoch 9 iteration 1200 with loss 0.90706. Total time 7.56944 hours
# Training at Epoch 9 iteration 1300 with loss 0.93465. Total time 7.58833 hours
# Training at Epoch 9 iteration 1400 with loss 0.84754. Total time 7.60694 hours
# Training at Epoch 9 iteration 1500 with loss 0.82008. Total time 7.62555 hours
# Training at Epoch 9 iteration 1600 with loss 0.90438. Total time 7.64444 hours
# Training at Epoch 9 iteration 1700 with loss 0.89459. Total time 7.66305 hours
# Training at Epoch 9 iteration 1800 with loss 0.88510. Total time 7.68166 hours
# Training at Epoch 9 iteration 1900 with loss 0.94967. Total time 7.70055 hours
# Training at Epoch 9 iteration 2000 with loss 0.62912. Total time 7.71916 hours
# Training at Epoch 9 iteration 2100 with loss 0.75826. Total time 7.73777 hours
# Training at Epoch 9 iteration 2200 with loss 0.88869. Total time 7.75666 hours
# Training at Epoch 9 iteration 2300 with loss 0.91103. Total time 7.77527 hours
# Training at Epoch 9 iteration 2400 with loss 0.95021. Total time 7.79388 hours
# Training at Epoch 9 iteration 2500 with loss 0.64579. Total time 7.81277 hours
# Training at Epoch 9 iteration 2600 with loss 0.70216. Total time 7.83138 hours
# Training at Epoch 9 iteration 2700 with loss 1.04635. Total time 7.85 hours
# Training at Epoch 9 iteration 2800 with loss 0.79416. Total time 7.86861 hours
# Training at Epoch 9 iteration 2900 with loss 0.88600. Total time 7.8875 hours
# Training at Epoch 9 iteration 3000 with loss 0.76810. Total time 7.90611 hours
# Training at Epoch 9 iteration 3100 with loss 0.90769. Total time 7.925 hours
# Training at Epoch 9 iteration 3200 with loss 0.88282. Total time 7.94361 hours
# Training at Epoch 9 iteration 3300 with loss 0.92147. Total time 7.9625 hours
# Training at Epoch 9 iteration 3400 with loss 0.95307. Total time 7.98111 hours
# Training at Epoch 9 iteration 3500 with loss 0.95369. Total time 7.99972 hours
# Training at Epoch 9 iteration 3600 with loss 0.76610. Total time 8.01833 hours
# Training at Epoch 9 iteration 3700 with loss 0.79797. Total time 8.03722 hours
# Training at Epoch 9 iteration 3800 with loss 0.79005. Total time 8.05583 hours
# Training at Epoch 9 iteration 3900 with loss 0.89159. Total time 8.07444 hours
# Training at Epoch 9 iteration 4000 with loss 0.75103. Total time 8.09305 hours
# Training at Epoch 9 iteration 4100 with loss 0.80825. Total time 8.11166 hours
# Training at Epoch 9 iteration 4200 with loss 0.94457. Total time 8.13055 hours
# Training at Epoch 9 iteration 4300 with loss 0.83303. Total time 8.14916 hours
# Validation at Epoch 9 with loss:0.89773, MSE: 0.88322 , Pearson Correlation: 0.77694 with p-value: 0.00E+00 , Concordance Index: 0.79343
# Training at Epoch 10 iteration 0 with loss 0.78442. Total time 8.25944 hours
# Training at Epoch 10 iteration 100 with loss 0.75684. Total time 8.27805 hours
# Training at Epoch 10 iteration 200 with loss 0.95526. Total time 8.29694 hours
# Training at Epoch 10 iteration 300 with loss 0.86297. Total time 8.31555 hours
# Training at Epoch 10 iteration 400 with loss 0.97923. Total time 8.33444 hours
# Training at Epoch 10 iteration 500 with loss 0.97836. Total time 8.35305 hours
# Training at Epoch 10 iteration 600 with loss 0.79077. Total time 8.37166 hours
# Training at Epoch 10 iteration 700 with loss 0.79724. Total time 8.39027 hours
# Training at Epoch 10 iteration 800 with loss 0.89352. Total time 8.40916 hours
# Training at Epoch 10 iteration 900 with loss 0.76118. Total time 8.42777 hours
# Training at Epoch 10 iteration 1000 with loss 0.91275. Total time 8.44638 hours
# Training at Epoch 10 iteration 1100 with loss 1.02119. Total time 8.465 hours
# Training at Epoch 10 iteration 1200 with loss 0.74320. Total time 8.48388 hours
# Training at Epoch 10 iteration 1300 with loss 0.77264. Total time 8.5025 hours
# Training at Epoch 10 iteration 1400 with loss 0.82053. Total time 8.52111 hours
# Training at Epoch 10 iteration 1500 with loss 0.69694. Total time 8.53972 hours
# Training at Epoch 10 iteration 1600 with loss 0.79304. Total time 8.55861 hours
# Training at Epoch 10 iteration 1700 with loss 0.69775. Total time 8.57722 hours
# Training at Epoch 10 iteration 1800 with loss 1.28309. Total time 8.59583 hours
# Training at Epoch 10 iteration 1900 with loss 0.82721. Total time 8.61444 hours
# Training at Epoch 10 iteration 2000 with loss 0.76752. Total time 8.63333 hours
# Training at Epoch 10 iteration 2100 with loss 0.74634. Total time 8.65194 hours
# Training at Epoch 10 iteration 2200 with loss 0.85874. Total time 8.67055 hours
# Training at Epoch 10 iteration 2300 with loss 0.91081. Total time 8.68916 hours
# Training at Epoch 10 iteration 2400 with loss 0.75885. Total time 8.70805 hours
# Training at Epoch 10 iteration 2500 with loss 0.73875. Total time 8.72666 hours
# Training at Epoch 10 iteration 2600 with loss 0.85500. Total time 8.74527 hours
# Training at Epoch 10 iteration 2700 with loss 0.86741. Total time 8.76388 hours
# Training at Epoch 10 iteration 2800 with loss 0.82950. Total time 8.7825 hours
# Training at Epoch 10 iteration 2900 with loss 0.89445. Total time 8.80138 hours
# Training at Epoch 10 iteration 3000 with loss 0.66277. Total time 8.82 hours
# Training at Epoch 10 iteration 3100 with loss 0.81455. Total time 8.83861 hours
# Training at Epoch 10 iteration 3200 with loss 0.81121. Total time 8.85722 hours
# Training at Epoch 10 iteration 3300 with loss 0.74749. Total time 8.87611 hours
# Training at Epoch 10 iteration 3400 with loss 0.97109. Total time 8.89472 hours
# Training at Epoch 10 iteration 3500 with loss 0.83486. Total time 8.91333 hours
# Training at Epoch 10 iteration 3600 with loss 0.81104. Total time 8.93222 hours
# Training at Epoch 10 iteration 3700 with loss 0.84056. Total time 8.95083 hours
# Training at Epoch 10 iteration 3800 with loss 0.96887. Total time 8.96944 hours
# Training at Epoch 10 iteration 3900 with loss 0.95621. Total time 8.98805 hours
# Training at Epoch 10 iteration 4000 with loss 1.00183. Total time 9.00694 hours
# Training at Epoch 10 iteration 4100 with loss 0.73544. Total time 9.02555 hours
# Training at Epoch 10 iteration 4200 with loss 0.98762. Total time 9.04416 hours
# Training at Epoch 10 iteration 4300 with loss 0.96342. Total time 9.06305 hours
# Validation at Epoch 10 with loss:0.41834, MSE: 0.85930 , Pearson Correlation: 0.78081 with p-value: 0.00E+00 , Concordance Index: 0.79532
# Training at Epoch 11 iteration 0 with loss 0.89291. Total time 9.17194 hours
# Training at Epoch 11 iteration 100 with loss 0.75664. Total time 9.19055 hours
# Training at Epoch 11 iteration 200 with loss 0.82631. Total time 9.20944 hours
# Training at Epoch 11 iteration 300 with loss 0.88824. Total time 9.22805 hours
# Training at Epoch 11 iteration 400 with loss 0.75817. Total time 9.24694 hours
# Training at Epoch 11 iteration 500 with loss 0.93996. Total time 9.26555 hours
# Training at Epoch 11 iteration 600 with loss 0.88121. Total time 9.28444 hours
# Training at Epoch 11 iteration 700 with loss 0.93125. Total time 9.30333 hours
# Training at Epoch 11 iteration 800 with loss 0.78234. Total time 9.32222 hours
# Training at Epoch 11 iteration 900 with loss 0.79691. Total time 9.34111 hours
# Training at Epoch 11 iteration 1000 with loss 0.93520. Total time 9.36 hours
# Training at Epoch 11 iteration 1100 with loss 0.71659. Total time 9.37888 hours
# Training at Epoch 11 iteration 1200 with loss 0.81185. Total time 9.39777 hours
# Training at Epoch 11 iteration 1300 with loss 0.80291. Total time 9.41666 hours
# Training at Epoch 11 iteration 1400 with loss 0.80133. Total time 9.43555 hours
# Training at Epoch 11 iteration 1500 with loss 0.81598. Total time 9.45444 hours
# Training at Epoch 11 iteration 1600 with loss 1.00395. Total time 9.47333 hours
# Training at Epoch 11 iteration 1700 with loss 0.76913. Total time 9.49222 hours
# Training at Epoch 11 iteration 1800 with loss 0.89867. Total time 9.51111 hours
# Training at Epoch 11 iteration 1900 with loss 0.83462. Total time 9.53 hours
# Training at Epoch 11 iteration 2000 with loss 0.80955. Total time 9.54888 hours
# Training at Epoch 11 iteration 2100 with loss 0.83167. Total time 9.56777 hours
# Training at Epoch 11 iteration 2200 with loss 0.70323. Total time 9.58666 hours
# Training at Epoch 11 iteration 2300 with loss 0.86810. Total time 9.60555 hours
# Training at Epoch 11 iteration 2400 with loss 0.83509. Total time 9.62444 hours
# Training at Epoch 11 iteration 2500 with loss 0.85901. Total time 9.64333 hours
# Training at Epoch 11 iteration 2600 with loss 1.49151. Total time 9.66222 hours
# Training at Epoch 11 iteration 2700 with loss 0.79901. Total time 9.68083 hours
# Training at Epoch 11 iteration 2800 with loss 0.71927. Total time 9.69972 hours
# Training at Epoch 11 iteration 2900 with loss 0.61947. Total time 9.71861 hours
# Training at Epoch 11 iteration 3000 with loss 0.84089. Total time 9.7375 hours
# Training at Epoch 11 iteration 3100 with loss 0.77766. Total time 9.75638 hours
# Training at Epoch 11 iteration 3200 with loss 0.77182. Total time 9.77527 hours
# Training at Epoch 11 iteration 3300 with loss 0.74694. Total time 9.79416 hours
# Training at Epoch 11 iteration 3400 with loss 0.72292. Total time 9.81305 hours
# Training at Epoch 11 iteration 3500 with loss 0.63802. Total time 9.83194 hours
# Training at Epoch 11 iteration 3600 with loss 0.95903. Total time 9.85083 hours
# Training at Epoch 11 iteration 3700 with loss 0.81215. Total time 9.86972 hours
# Training at Epoch 11 iteration 3800 with loss 0.87014. Total time 9.88861 hours
# Training at Epoch 11 iteration 3900 with loss 0.82867. Total time 9.9075 hours
# Training at Epoch 11 iteration 4000 with loss 0.78636. Total time 9.92638 hours
# Training at Epoch 11 iteration 4100 with loss 0.84751. Total time 9.94527 hours
# Training at Epoch 11 iteration 4200 with loss 0.80679. Total time 9.96416 hours
# Training at Epoch 11 iteration 4300 with loss 0.91372. Total time 9.98305 hours
# Validation at Epoch 11 with loss:0.87965, MSE: 0.84403 , Pearson Correlation: 0.78549 with p-value: 0.00E+00 , Concordance Index: 0.79798
# Training at Epoch 12 iteration 0 with loss 0.71418. Total time 10.0919 hours
# Training at Epoch 12 iteration 100 with loss 0.79602. Total time 10.1108 hours
# Training at Epoch 12 iteration 200 with loss 0.70720. Total time 10.1297 hours
# Training at Epoch 12 iteration 300 with loss 0.76485. Total time 10.1483 hours
# Training at Epoch 12 iteration 400 with loss 0.76770. Total time 10.1669 hours
# Training at Epoch 12 iteration 500 with loss 0.88973. Total time 10.1858 hours
# Training at Epoch 12 iteration 600 with loss 0.69015. Total time 10.2047 hours
# Training at Epoch 12 iteration 700 with loss 0.89645. Total time 10.2236 hours
# Training at Epoch 12 iteration 800 with loss 0.68396. Total time 10.2425 hours
# Training at Epoch 12 iteration 900 with loss 0.76754. Total time 10.2613 hours
# Training at Epoch 12 iteration 1000 with loss 0.80579. Total time 10.2802 hours
# Training at Epoch 12 iteration 1100 with loss 0.77607. Total time 10.2991 hours
# Training at Epoch 12 iteration 1200 with loss 1.41963. Total time 10.3180 hours
# Training at Epoch 12 iteration 1300 with loss 0.88932. Total time 10.3369 hours
# Training at Epoch 12 iteration 1400 with loss 0.83613. Total time 10.3558 hours
# Training at Epoch 12 iteration 1500 with loss 0.81722. Total time 10.3747 hours
# Training at Epoch 12 iteration 1600 with loss 0.84798. Total time 10.3936 hours
# Training at Epoch 12 iteration 1700 with loss 0.87726. Total time 10.4122 hours
# Training at Epoch 12 iteration 1800 with loss 0.80885. Total time 10.4311 hours
# Training at Epoch 12 iteration 1900 with loss 0.75628. Total time 10.45 hours
# Training at Epoch 12 iteration 2000 with loss 0.72518. Total time 10.4688 hours
# Training at Epoch 12 iteration 2100 with loss 0.97672. Total time 10.4877 hours
# Training at Epoch 12 iteration 2200 with loss 1.00976. Total time 10.5066 hours
# Training at Epoch 12 iteration 2300 with loss 0.84330. Total time 10.5255 hours
# Training at Epoch 12 iteration 2400 with loss 0.99474. Total time 10.5444 hours
# Training at Epoch 12 iteration 2500 with loss 1.41667. Total time 10.5633 hours
# Training at Epoch 12 iteration 2600 with loss 0.87234. Total time 10.5822 hours
# Training at Epoch 12 iteration 2700 with loss 0.91510. Total time 10.6011 hours
# Training at Epoch 12 iteration 2800 with loss 0.80876. Total time 10.62 hours
# Training at Epoch 12 iteration 2900 with loss 0.67160. Total time 10.6388 hours
# Training at Epoch 12 iteration 3000 with loss 0.83574. Total time 10.6577 hours
# Training at Epoch 12 iteration 3100 with loss 0.74780. Total time 10.6766 hours
# Training at Epoch 12 iteration 3200 with loss 0.80916. Total time 10.6955 hours
# Training at Epoch 12 iteration 3300 with loss 0.86453. Total time 10.7144 hours
# Training at Epoch 12 iteration 3400 with loss 0.84634. Total time 10.7330 hours
# Training at Epoch 12 iteration 3500 with loss 0.87746. Total time 10.7519 hours
# Training at Epoch 12 iteration 3600 with loss 0.73485. Total time 10.7708 hours
# Training at Epoch 12 iteration 3700 with loss 1.23799. Total time 10.7897 hours
# Training at Epoch 12 iteration 3800 with loss 0.81616. Total time 10.8086 hours
# Training at Epoch 12 iteration 3900 with loss 0.68390. Total time 10.8275 hours
# Training at Epoch 12 iteration 4000 with loss 0.84265. Total time 10.8463 hours
# Training at Epoch 12 iteration 4100 with loss 0.73740. Total time 10.8652 hours
# Training at Epoch 12 iteration 4200 with loss 0.77714. Total time 10.8841 hours
# Training at Epoch 12 iteration 4300 with loss 0.83209. Total time 10.9030 hours
# Validation at Epoch 12 with loss:0.85453, MSE: 0.83251 , Pearson Correlation: 0.78923 with p-value: 0.00E+00 , Concordance Index: 0.79974
# Training at Epoch 13 iteration 0 with loss 0.80667. Total time 11.0133 hours
# Training at Epoch 13 iteration 100 with loss 0.76747. Total time 11.0319 hours
# Training at Epoch 13 iteration 200 with loss 0.88567. Total time 11.0508 hours
# Training at Epoch 13 iteration 300 with loss 0.83464. Total time 11.0694 hours
# Training at Epoch 13 iteration 400 with loss 0.82437. Total time 11.0880 hours
# Training at Epoch 13 iteration 500 with loss 0.81015. Total time 11.1069 hours
# Training at Epoch 13 iteration 600 with loss 0.67813. Total time 11.1258 hours
# Training at Epoch 13 iteration 700 with loss 0.89420. Total time 11.1447 hours
# Training at Epoch 13 iteration 800 with loss 0.74540. Total time 11.1636 hours
# Training at Epoch 13 iteration 900 with loss 0.77196. Total time 11.1825 hours
# Training at Epoch 13 iteration 1000 with loss 0.74410. Total time 11.2013 hours
# Training at Epoch 13 iteration 1100 with loss 0.77178. Total time 11.2202 hours
# Training at Epoch 13 iteration 1200 with loss 0.76099. Total time 11.2388 hours
# Training at Epoch 13 iteration 1300 with loss 0.77858. Total time 11.2577 hours
# Training at Epoch 13 iteration 1400 with loss 0.78972. Total time 11.2766 hours
# Training at Epoch 13 iteration 1500 with loss 0.76461. Total time 11.2955 hours
# Training at Epoch 13 iteration 1600 with loss 0.94170. Total time 11.3144 hours
# Training at Epoch 13 iteration 1700 with loss 0.87223. Total time 11.3333 hours
# Training at Epoch 13 iteration 1800 with loss 0.73292. Total time 11.3522 hours
# Training at Epoch 13 iteration 1900 with loss 0.68117. Total time 11.3711 hours
# Training at Epoch 13 iteration 2000 with loss 0.75629. Total time 11.39 hours
# Training at Epoch 13 iteration 2100 with loss 0.91673. Total time 11.4088 hours
# Training at Epoch 13 iteration 2200 with loss 0.89494. Total time 11.4277 hours
# Training at Epoch 13 iteration 2300 with loss 0.70041. Total time 11.4463 hours
# Training at Epoch 13 iteration 2400 with loss 1.07787. Total time 11.4652 hours
# Training at Epoch 13 iteration 2500 with loss 0.73142. Total time 11.4841 hours
# Training at Epoch 13 iteration 2600 with loss 0.73542. Total time 11.5030 hours
# Training at Epoch 13 iteration 2700 with loss 0.75028. Total time 11.5219 hours
# Training at Epoch 13 iteration 2800 with loss 0.62544. Total time 11.5408 hours
# Training at Epoch 13 iteration 2900 with loss 0.79224. Total time 11.5597 hours
# Training at Epoch 13 iteration 3000 with loss 0.61686. Total time 11.5786 hours
# Training at Epoch 13 iteration 3100 with loss 0.74844. Total time 11.5975 hours
# Training at Epoch 13 iteration 3200 with loss 0.96980. Total time 11.6161 hours
# Training at Epoch 13 iteration 3300 with loss 0.78079. Total time 11.635 hours
# Training at Epoch 13 iteration 3400 with loss 0.78127. Total time 11.6538 hours
# Training at Epoch 13 iteration 3500 with loss 0.89084. Total time 11.6727 hours
# Training at Epoch 13 iteration 3600 with loss 0.73848. Total time 11.6916 hours
# Training at Epoch 13 iteration 3700 with loss 0.71917. Total time 11.7105 hours
# Training at Epoch 13 iteration 3800 with loss 0.87924. Total time 11.7294 hours
# Training at Epoch 13 iteration 3900 with loss 0.76602. Total time 11.7483 hours
# Training at Epoch 13 iteration 4000 with loss 0.82431. Total time 11.7672 hours
# Training at Epoch 13 iteration 4100 with loss 0.85798. Total time 11.7861 hours
# Training at Epoch 13 iteration 4200 with loss 0.69319. Total time 11.805 hours
# Training at Epoch 13 iteration 4300 with loss 0.86402. Total time 11.8238 hours
# Validation at Epoch 13 with loss:0.77675, MSE: 0.83517 , Pearson Correlation: 0.78857 with p-value: 0.00E+00 , Concordance Index: 0.79993
# Training at Epoch 14 iteration 0 with loss 0.75095. Total time 11.9330 hours
# Training at Epoch 14 iteration 100 with loss 0.71283. Total time 11.9516 hours
# Training at Epoch 14 iteration 200 with loss 0.73058. Total time 11.9705 hours
# Training at Epoch 14 iteration 300 with loss 0.75019. Total time 11.9891 hours
# Training at Epoch 14 iteration 400 with loss 0.64251. Total time 12.0077 hours
# Training at Epoch 14 iteration 500 with loss 0.71119. Total time 12.0266 hours
# Training at Epoch 14 iteration 600 with loss 0.75266. Total time 12.0455 hours
# Training at Epoch 14 iteration 700 with loss 0.88226. Total time 12.0644 hours
# Training at Epoch 14 iteration 800 with loss 0.87108. Total time 12.0833 hours
# Training at Epoch 14 iteration 900 with loss 0.83738. Total time 12.1022 hours
# Training at Epoch 14 iteration 1000 with loss 0.78969. Total time 12.1211 hours
# Training at Epoch 14 iteration 1100 with loss 0.77209. Total time 12.14 hours
# Training at Epoch 14 iteration 1200 with loss 0.58662. Total time 12.1588 hours
# ...
# Training at Epoch 46 iteration 3100 with loss 0.68982. Total time 41.3347 hours
# Training at Epoch 46 iteration 3200 with loss 0.74947. Total time 41.3533 hours
# Training at Epoch 46 iteration 3300 with loss 0.66143. Total time 41.3719 hours
# Training at Epoch 46 iteration 3400 with loss 0.65682. Total time 41.3905 hours
# Training at Epoch 46 iteration 3500 with loss 0.65109. Total time 41.4091 hours
# Training at Epoch 46 iteration 3600 with loss 0.78598. Total time 41.4277 hours
# Training at Epoch 46 iteration 3700 with loss 0.59958. Total time 41.4463 hours
# Training at Epoch 46 iteration 3800 with loss 0.69440. Total time 41.465 hours
# Training at Epoch 46 iteration 3900 with loss 0.63630. Total time 41.4836 hours
# Training at Epoch 46 iteration 4000 with loss 0.75663. Total time 41.5022 hours
# Training at Epoch 46 iteration 4100 with loss 0.85655. Total time 41.5208 hours
# Training at Epoch 46 iteration 4200 with loss 0.71178. Total time 41.5394 hours
# Training at Epoch 46 iteration 4300 with loss 0.68059. Total time 41.5577 hours
# Validation at Epoch 46 with loss:0.81065, MSE: 0.74450 , Pearson Correlation: 0.81706 with p-value: 0.00E+00 , Concordance Index: 0.81527
# Training at Epoch 47 iteration 0 with loss 0.75663. Total time 41.6688 hours
# Training at Epoch 47 iteration 100 with loss 0.69879. Total time 41.6875 hours
# Training at Epoch 47 iteration 200 with loss 0.64802. Total time 41.7061 hours
# Training at Epoch 47 iteration 300 with loss 0.71146. Total time 41.7247 hours
# Training at Epoch 47 iteration 400 with loss 0.65517. Total time 41.7433 hours
# Training at Epoch 47 iteration 500 with loss 0.68434. Total time 41.7613 hours
# Training at Epoch 47 iteration 600 with loss 0.63694. Total time 41.78 hours
# Training at Epoch 47 iteration 700 with loss 0.56441. Total time 41.7983 hours
# Training at Epoch 47 iteration 800 with loss 0.60283. Total time 41.8169 hours
# Training at Epoch 47 iteration 900 with loss 0.73562. Total time 41.8352 hours
# Training at Epoch 47 iteration 1000 with loss 0.69161. Total time 41.8536 hours
# Training at Epoch 47 iteration 1100 with loss 0.56595. Total time 41.8719 hours
# Training at Epoch 47 iteration 1200 with loss 0.70812. Total time 41.8902 hours
# Training at Epoch 47 iteration 1300 with loss 0.75377. Total time 41.9083 hours
# Training at Epoch 47 iteration 1400 with loss 0.55427. Total time 41.9266 hours
# Training at Epoch 47 iteration 1500 with loss 0.64255. Total time 41.945 hours
# Training at Epoch 47 iteration 1600 with loss 0.72351. Total time 41.9630 hours
# Training at Epoch 47 iteration 1700 with loss 0.62211. Total time 41.9813 hours
# Training at Epoch 47 iteration 1800 with loss 0.67734. Total time 41.9994 hours
# Training at Epoch 47 iteration 1900 with loss 0.61055. Total time 42.0177 hours
# Training at Epoch 47 iteration 2000 with loss 0.62783. Total time 42.0358 hours
# Training at Epoch 47 iteration 2100 with loss 0.78418. Total time 42.0541 hours
# Training at Epoch 47 iteration 2200 with loss 0.68828. Total time 42.0722 hours
# Training at Epoch 47 iteration 2300 with loss 0.80675. Total time 42.0902 hours
# Training at Epoch 47 iteration 2400 with loss 0.59814. Total time 42.1086 hours
# Training at Epoch 47 iteration 2500 with loss 0.64088. Total time 42.1266 hours
# Training at Epoch 47 iteration 2600 with loss 0.69718. Total time 42.1447 hours
# Training at Epoch 47 iteration 2700 with loss 0.68502. Total time 42.1630 hours
# Training at Epoch 47 iteration 2800 with loss 0.61712. Total time 42.1811 hours
# Training at Epoch 47 iteration 2900 with loss 0.70018. Total time 42.1994 hours
# Training at Epoch 47 iteration 3000 with loss 0.71009. Total time 42.2175 hours
# Training at Epoch 47 iteration 3100 with loss 0.52097. Total time 42.2355 hours
# Training at Epoch 47 iteration 3200 with loss 0.66146. Total time 42.2538 hours
# Training at Epoch 47 iteration 3300 with loss 0.75336. Total time 42.2719 hours
# Training at Epoch 47 iteration 3400 with loss 0.67356. Total time 42.2902 hours
# Training at Epoch 47 iteration 3500 with loss 0.60391. Total time 42.3083 hours
# Training at Epoch 47 iteration 3600 with loss 0.47935. Total time 42.3266 hours
# Training at Epoch 47 iteration 3700 with loss 0.63027. Total time 42.3447 hours
# Training at Epoch 47 iteration 3800 with loss 0.64856. Total time 42.3630 hours
# Training at Epoch 47 iteration 3900 with loss 0.61894. Total time 42.3816 hours
# Training at Epoch 47 iteration 4000 with loss 0.61693. Total time 42.4 hours
# Training at Epoch 47 iteration 4100 with loss 0.58939. Total time 42.4180 hours
# Training at Epoch 47 iteration 4200 with loss 0.69206. Total time 42.4363 hours
# Training at Epoch 47 iteration 4300 with loss 0.52247. Total time 42.4544 hours
# Validation at Epoch 47 with loss:0.65173, MSE: 0.72905 , Pearson Correlation: 0.81793 with p-value: 0.00E+00 , Concordance Index: 0.81600
# Training at Epoch 48 iteration 0 with loss 0.70041. Total time 42.5636 hours
# Training at Epoch 48 iteration 100 with loss 0.73662. Total time 42.5819 hours
# Training at Epoch 48 iteration 200 with loss 0.73270. Total time 42.6002 hours
# Training at Epoch 48 iteration 300 with loss 0.60751. Total time 42.6183 hours
# Training at Epoch 48 iteration 400 with loss 0.78481. Total time 42.6366 hours
# Training at Epoch 48 iteration 500 with loss 0.56866. Total time 42.6547 hours
# Training at Epoch 48 iteration 600 with loss 0.64406. Total time 42.6730 hours
# Training at Epoch 48 iteration 700 with loss 0.71090. Total time 42.6911 hours
# Training at Epoch 48 iteration 800 with loss 0.70378. Total time 42.7094 hours
# Training at Epoch 48 iteration 900 with loss 0.52787. Total time 42.7275 hours
# Training at Epoch 48 iteration 1000 with loss 0.65024. Total time 42.7455 hours
# Training at Epoch 48 iteration 1100 with loss 0.63529. Total time 42.7638 hours
# Training at Epoch 48 iteration 1200 with loss 0.63845. Total time 42.7819 hours
# Training at Epoch 48 iteration 1300 with loss 0.66670. Total time 42.8002 hours
# Training at Epoch 48 iteration 1400 with loss 0.61367. Total time 42.8183 hours
# Training at Epoch 48 iteration 1500 with loss 0.57976. Total time 42.8366 hours
# Training at Epoch 48 iteration 1600 with loss 0.78175. Total time 42.8547 hours
# Training at Epoch 48 iteration 1700 with loss 0.84043. Total time 42.8727 hours
# Training at Epoch 48 iteration 1800 with loss 0.74106. Total time 42.8911 hours
# Training at Epoch 48 iteration 1900 with loss 0.59083. Total time 42.9091 hours
# Training at Epoch 48 iteration 2000 with loss 0.76803. Total time 42.9275 hours
# Training at Epoch 48 iteration 2100 with loss 0.62210. Total time 42.9455 hours
# Training at Epoch 48 iteration 2200 with loss 0.69521. Total time 42.9638 hours
# Training at Epoch 48 iteration 2300 with loss 0.50775. Total time 42.9819 hours
# Training at Epoch 48 iteration 2400 with loss 0.77304. Total time 43.0002 hours
# Training at Epoch 48 iteration 2500 with loss 0.72304. Total time 43.0183 hours
# Training at Epoch 48 iteration 2600 with loss 0.77036. Total time 43.0363 hours
# Training at Epoch 48 iteration 2700 with loss 0.79340. Total time 43.0547 hours
# Training at Epoch 48 iteration 2800 with loss 0.62209. Total time 43.0727 hours
# Training at Epoch 48 iteration 2900 with loss 0.61646. Total time 43.0911 hours
# Training at Epoch 48 iteration 3000 with loss 0.69244. Total time 43.1091 hours
# Training at Epoch 48 iteration 3100 with loss 0.52154. Total time 43.1275 hours
# Training at Epoch 48 iteration 3200 with loss 0.59849. Total time 43.1455 hours
# Training at Epoch 48 iteration 3300 with loss 0.63893. Total time 43.1636 hours
# Training at Epoch 48 iteration 3400 with loss 0.60090. Total time 43.1819 hours
# Training at Epoch 48 iteration 3500 with loss 0.65269. Total time 43.2 hours
# Training at Epoch 48 iteration 3600 with loss 0.53213. Total time 43.2183 hours
# Training at Epoch 48 iteration 3700 with loss 0.58630. Total time 43.2363 hours
# Training at Epoch 48 iteration 3800 with loss 0.64962. Total time 43.2547 hours
# Training at Epoch 48 iteration 3900 with loss 0.72719. Total time 43.2727 hours
# Training at Epoch 48 iteration 4000 with loss 0.54875. Total time 43.2911 hours
# Training at Epoch 48 iteration 4100 with loss 0.63589. Total time 43.3091 hours
# Training at Epoch 48 iteration 4200 with loss 0.66934. Total time 43.3272 hours
# Training at Epoch 48 iteration 4300 with loss 0.64705. Total time 43.3455 hours
# Validation at Epoch 48 with loss:0.74964, MSE: 0.74942 , Pearson Correlation: 0.81596 with p-value: 0.00E+00 , Concordance Index: 0.81523
# Training at Epoch 49 iteration 0 with loss 0.56675. Total time 43.4547 hours
# Training at Epoch 49 iteration 100 with loss 0.49814. Total time 43.4741 hours
# Training at Epoch 49 iteration 200 with loss 0.72763. Total time 43.4927 hours
# Training at Epoch 49 iteration 300 with loss 0.65843. Total time 43.5111 hours
# Training at Epoch 49 iteration 400 with loss 0.55547. Total time 43.5294 hours
# Training at Epoch 49 iteration 500 with loss 0.57183. Total time 43.5488 hours
# Training at Epoch 49 iteration 600 with loss 0.54688. Total time 43.5680 hours
# Training at Epoch 49 iteration 700 with loss 0.63709. Total time 43.5869 hours
# Training at Epoch 49 iteration 800 with loss 0.67902. Total time 43.6058 hours
# Training at Epoch 49 iteration 900 with loss 0.60426. Total time 43.6255 hours
# Training at Epoch 49 iteration 1000 with loss 0.57347. Total time 43.6452 hours
# Training at Epoch 49 iteration 1100 with loss 0.63345. Total time 43.6647 hours
# Training at Epoch 49 iteration 1200 with loss 0.67775. Total time 43.6838 hours
# Training at Epoch 49 iteration 1300 with loss 0.70586. Total time 43.7030 hours
# Training at Epoch 49 iteration 1400 with loss 0.55747. Total time 43.7219 hours
# Training at Epoch 49 iteration 1500 with loss 0.66396. Total time 43.7405 hours
# Training at Epoch 49 iteration 1600 with loss 0.59026. Total time 43.7594 hours
# Training at Epoch 49 iteration 1700 with loss 0.80764. Total time 43.7783 hours
# Training at Epoch 49 iteration 1800 with loss 0.71959. Total time 43.7972 hours
# Training at Epoch 49 iteration 1900 with loss 0.63100. Total time 43.8158 hours
# Training at Epoch 49 iteration 2000 with loss 0.78497. Total time 43.8347 hours
# Training at Epoch 49 iteration 2100 with loss 0.60978. Total time 43.8533 hours
# Training at Epoch 49 iteration 2200 with loss 0.55648. Total time 43.8722 hours
# Training at Epoch 49 iteration 2300 with loss 0.79528. Total time 43.8911 hours
# Training at Epoch 49 iteration 2400 with loss 0.78116. Total time 43.9097 hours
# Training at Epoch 49 iteration 2500 with loss 0.55527. Total time 43.9286 hours
# Training at Epoch 49 iteration 2600 with loss 0.74675. Total time 43.9475 hours
# Training at Epoch 49 iteration 2700 with loss 0.54725. Total time 43.9663 hours
# Training at Epoch 49 iteration 2800 with loss 0.55531. Total time 43.9861 hours
# Training at Epoch 49 iteration 2900 with loss 0.77181. Total time 44.0058 hours
# Training at Epoch 49 iteration 3000 with loss 0.62819. Total time 44.0255 hours
# Training at Epoch 49 iteration 3100 with loss 0.62492. Total time 44.0444 hours
# Training at Epoch 49 iteration 3200 with loss 0.71595. Total time 44.0636 hours
# Training at Epoch 49 iteration 3300 with loss 0.64160. Total time 44.0827 hours
# Training at Epoch 49 iteration 3400 with loss 0.62643. Total time 44.1019 hours
# Training at Epoch 49 iteration 3500 with loss 0.67516. Total time 44.1211 hours
# Training at Epoch 49 iteration 3600 with loss 0.65875. Total time 44.1402 hours
# Training at Epoch 49 iteration 3700 with loss 0.54804. Total time 44.1591 hours
# Training at Epoch 49 iteration 3800 with loss 0.58657. Total time 44.1777 hours
# Training at Epoch 49 iteration 3900 with loss 0.85607. Total time 44.1963 hours
# Training at Epoch 49 iteration 4000 with loss 0.57627. Total time 44.215 hours
# Training at Epoch 49 iteration 4100 with loss 0.75614. Total time 44.2336 hours
# Training at Epoch 49 iteration 4200 with loss 0.65455. Total time 44.2522 hours
# Training at Epoch 49 iteration 4300 with loss 0.71158. Total time 44.2708 hours
# Validation at Epoch 49 with loss:0.91433, MSE: 0.74134 , Pearson Correlation: 0.81564 with p-value: 0.00E+00 , Concordance Index: 0.81521
# Training at Epoch 50 iteration 0 with loss 0.61690. Total time 44.3797 hours
# Training at Epoch 50 iteration 100 with loss 0.76008. Total time 44.3986 hours
# Training at Epoch 50 iteration 200 with loss 0.66164. Total time 44.4172 hours
# Training at Epoch 50 iteration 300 with loss 0.61043. Total time 44.4358 hours
# Training at Epoch 50 iteration 400 with loss 0.61084. Total time 44.4544 hours
# Training at Epoch 50 iteration 500 with loss 0.64359. Total time 44.4730 hours
# Training at Epoch 50 iteration 600 with loss 0.65584. Total time 44.4916 hours
# Training at Epoch 50 iteration 700 with loss 0.68877. Total time 44.5108 hours
# Training at Epoch 50 iteration 800 with loss 0.48010. Total time 44.5302 hours
# Training at Epoch 50 iteration 900 with loss 0.60495. Total time 44.5497 hours
# Training at Epoch 50 iteration 1000 with loss 0.69786. Total time 44.5694 hours
# Training at Epoch 50 iteration 1100 with loss 0.58656. Total time 44.5891 hours
# Training at Epoch 50 iteration 1200 with loss 0.60809. Total time 44.6088 hours
# Training at Epoch 50 iteration 1300 with loss 0.70302. Total time 44.6283 hours
# Training at Epoch 50 iteration 1400 with loss 0.67754. Total time 44.6477 hours
# Training at Epoch 50 iteration 1500 with loss 0.60115. Total time 44.6669 hours
# Training at Epoch 50 iteration 1600 with loss 0.58470. Total time 44.6861 hours
# Training at Epoch 50 iteration 1700 with loss 0.58510. Total time 44.7055 hours
# Training at Epoch 50 iteration 1800 with loss 0.63573. Total time 44.725 hours
# Training at Epoch 50 iteration 1900 with loss 0.74265. Total time 44.7441 hours
# Training at Epoch 50 iteration 2000 with loss 0.64539. Total time 44.7636 hours
# Training at Epoch 50 iteration 2100 with loss 0.62555. Total time 44.7827 hours
# Training at Epoch 50 iteration 2200 with loss 0.58919. Total time 44.8022 hours
# Training at Epoch 50 iteration 2300 with loss 0.59552. Total time 44.8216 hours
# Training at Epoch 50 iteration 2400 with loss 0.69345. Total time 44.8411 hours
# Training at Epoch 50 iteration 2500 with loss 0.88939. Total time 44.8605 hours
# Training at Epoch 50 iteration 2600 with loss 0.58907. Total time 44.8797 hours
# Training at Epoch 50 iteration 2700 with loss 0.55707. Total time 44.8994 hours
# Training at Epoch 50 iteration 2800 with loss 0.56096. Total time 44.9191 hours
# Training at Epoch 50 iteration 2900 with loss 0.70511. Total time 44.9388 hours
# Training at Epoch 50 iteration 3000 with loss 0.66491. Total time 44.9586 hours
# Training at Epoch 50 iteration 3100 with loss 0.75807. Total time 44.9783 hours
# Training at Epoch 50 iteration 3200 with loss 0.80514. Total time 44.9980 hours
# Training at Epoch 50 iteration 3300 with loss 0.67523. Total time 45.0172 hours
# Training at Epoch 50 iteration 3400 with loss 0.50794. Total time 45.0363 hours
# Training at Epoch 50 iteration 3500 with loss 0.71302. Total time 45.0558 hours
# Training at Epoch 50 iteration 3600 with loss 0.59708. Total time 45.075 hours
# Training at Epoch 50 iteration 3700 with loss 0.67074. Total time 45.0944 hours
# Training at Epoch 50 iteration 3800 with loss 0.68880. Total time 45.1138 hours
# Training at Epoch 50 iteration 3900 with loss 0.63528. Total time 45.1330 hours
# Training at Epoch 50 iteration 4000 with loss 0.68906. Total time 45.1525 hours
# Training at Epoch 50 iteration 4100 with loss 0.58431. Total time 45.1722 hours
# Training at Epoch 50 iteration 4200 with loss 0.59850. Total time 45.1919 hours
# Training at Epoch 50 iteration 4300 with loss 0.61878. Total time 45.2119 hours
# Validation at Epoch 50 with loss:0.79645, MSE: 0.74021 , Pearson Correlation: 0.81569 with p-value: 0.00E+00 , Concordance Index: 0.81458
# --- Go for Testing ---
# Testing MSE: 0.7267286823458796 , Pearson Correlation: 0.8186250048810337 with p-value: 0.00E+00 , Concordance Index: 0.8157398855538804
# --- Training Finished ---

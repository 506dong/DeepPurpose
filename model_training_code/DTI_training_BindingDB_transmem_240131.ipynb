# %%
import os
os.chdir('../')
os.getcwd()
# Out:
# 'c:\\Users\\user\\Desktop\\DTI\\DeepPurpose-1'

# %%
from DeepPurpose import utils, dataset
from DeepPurpose import DTI as models
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np

# %%
#### process_BindingDB ####

# Parameter
path = '../Database/BindingDB/BindingDB_edit_ver2_240125.tsv'
df = None
y = 'IC50'
binary = False
convert_to_log = True
threshold = 30
return_ids = False
ids_condition = 'OR'
harmonize_affinities = None

# loading df (bindingDB)
df = pd.read_csv(path, sep = '\t')

print('Beginning Processing...')
df = df[df['Number of Protein Chains in Target (>1 implies a multichain complex)'] == 1.0]
df = df[df['Ligand SMILES'].notnull()]

idx_str = []
yy = y
if isinstance(y, str):
	yy = [y]
for y in yy:
	if y == 'Kd':
		idx_str.append('Kd (nM)')
	elif y == 'IC50':
		idx_str.append('IC50 (nM)')
	elif y == 'Ki':
		idx_str.append('Ki (nM)')
	elif y == 'EC50':
		idx_str.append('EC50 (nM)')
	else:
		print('select Kd, Ki, IC50 or EC50')

if len(idx_str)==1:
	df_want = df[df[idx_str[0]].notnull()]
else: # select multiple affinity measurements.                 
	# keep rows for which at least one of the columns in the idx_str list is not null
	df_want = df.dropna(thresh=1, subset=idx_str) 
	
df_want = df_want[['BindingDB Reactant_set_id', 'Ligand InChI', 'Ligand SMILES',\
				'PubChem CID', 'UniProt (SwissProt) Primary ID of Target Chain',\
				'modified_transmem'] + idx_str] # BindingDB Target Chain Sequence

for y in idx_str:
	df_want[y] = df_want[y].str.replace('>', '')
	df_want[y] = df_want[y].str.replace('<', '')
	df_want[y] = df_want[y].astype(float)

# Harmonize into single label using the mean of existing labels:
df_want['Label'] = df_want[idx_str].mean(axis=1, skipna=True)

df_want.rename(columns={'BindingDB Reactant_set_id':'ID',
						'Ligand SMILES':'SMILES',
						'Ligand InChI':'InChI',
						'PubChem CID':'PubChem_ID',
						'UniProt (SwissProt) Primary ID of Target Chain':'UniProt_ID',
						'modified_transmem': 'Target Sequence'}, # BindingDB Target Chain Sequence
						inplace=True)

# have at least uniprot or pubchem ID
if ids_condition == 'OR':
	df_want = df_want[df_want.PubChem_ID.notnull() | df_want.UniProt_ID.notnull()]
elif ids_condition == 'AND':
	df_want = df_want[df_want.PubChem_ID.notnull() & df_want.UniProt_ID.notnull()]
else:
	ValueError("ids_condition must be set to 'OR' or 'AND'")

df_want = df_want[df_want.InChI.notnull()]

df_want = df_want[df_want.Label <= 10000000.0]
print('There are ' + str(len(df_want)) + ' drug target pairs.')

if harmonize_affinities is not None:
	df_want = df_want[['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence', 'Label']]
	if harmonize_affinities.lower() == 'max_affinity':
		df_want = df_want.groupby(['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence']).Label.agg(min).reset_index()
	if harmonize_affinities.lower() == 'mean':
		df_want = df_want.groupby(['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence']).Label.agg(np.mean).reset_index()

if binary:
	print('Default binary threshold for the binding affinity scores are 30, you can adjust it by using the "threshold" parameter')
	if isinstance(threshold, Sequence):
		# filter samples with affinity values between the thresholds
		df_want = df_want[(df_want.Label < threshold[0]) | (df_want.Label > threshold[1])]
	else: # single threshold
		threshold = [threshold]
	y = [1 if i else 0 for i in df_want.Label.values < threshold[0]]
else:
	if convert_to_log:
		print('Default set to logspace (nM -> p) for easier regression')
		y = utils.convert_y_unit(df_want.Label.values, 'nM', 'p')
	else:
		y = df_want.Label.values
	
if return_ids:
	X_drug, X_target, y, ID_drug, ID_target = df_want.SMILES.values, df_want['Target Sequence'].values, np.array(y), df_want['PubChem_ID'].values, df_want['UniProt_ID'].values
X_drug, X_target, y = df_want.SMILES.values, df_want['Target Sequence'].values, np.array(y)
# Out:
# Beginning Processing...
# There are 1592671 drug target pairs.
# Default set to logspace (nM -> p) for easier regression

# %%
#### select endcoder ####
drug_encoding, target_encoding = 'CNN', 'CNN'

# %%
#### data_process ####

# parameter
split_method = 'random'
frac = [0.7, 0.1, 0.2]
random_seed = 1
sample_frac = 1
mode = 'DTI'
X_drug_ = None
X_target_ = None

# data_process : dataframe

if random_seed == 'TDC':
	random_seed = 1234
 
#property_prediction_flag = X_target is None
property_prediction_flag, function_prediction_flag, DDI_flag, PPI_flag, DTI_flag = False, False, False, False, False

if (X_drug is not None) and (X_target is not None):
	DTI_flag = True
	if (X_drug is None) or (X_target is None):
		raise AttributeError("Target pair sequence should be in X_target, X_drug")
else:
	raise AttributeError("Please use the correct mode. Currently, we support DTI, DDI, PPI, Drug Property Prediction and Protein Function Prediction...")

if split_method == 'repurposing_VS':
	y = [-1]*len(X_drug) # create temp y for compatitibility

if DTI_flag:
	print('Drug Target Interaction Prediction Mode...')
	if isinstance(X_target, str):
		X_target = [X_target]
	if len(X_target) == 1:
		# one target high throughput screening setting
		X_target = np.tile(X_target, (length_func(X_drug), ))

	df_data = pd.DataFrame(zip(X_drug, X_target, y))
	df_data.rename(columns={0:'SMILES',
							1: 'Target Sequence',
							2: 'Label'}, 
							inplace=True)
	print('in total: ' + str(len(df_data)) + ' drug-target pairs')
 
# data_process : endcoding & splitting

if sample_frac != 1:
	df_data = df_data.sample(frac = sample_frac) #.reset_index(drop = True)
	print('after subsample: ' + str(len(df_data)) + ' data points...') 

if DTI_flag:
	df_data = utils.encode_drug(df_data, drug_encoding)
	df_data = utils.encode_protein(df_data, target_encoding)
# Out:
# Drug Target Interaction Prediction Mode...
# in total: 1592671 drug-target pairs
# encoding drug...
# unique drugs: 770912
# encoding protein...
# unique target sequence: 5734

# %%
# after pre-processing set 불러오기
after_train = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_train.tsv', sep='\t', index_col=0)
after_val = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_val.tsv', sep='\t', index_col=0)
after_test = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_test.tsv', sep='\t', index_col=0)

# %%
after_val['index_val'].values
# Out:
# array([ 520137,    5876,  773576, ...,  253865, 1014785,  758771],
#       dtype=int64)

# %%
# 같은 index를 가지게 split / index 초기화
train = df_data.loc[after_train['index_train'].values, :]
val = df_data.loc[after_val['index_val'].values, :]
test = df_data.loc[after_test['index_test'].values, :]
train, val, test = train.reset_index(drop=True), val.reset_index(drop=True), test.reset_index(drop=True)

# %%
# Model configuration genreration
config = utils.generate_config(drug_encoding = drug_encoding, 
                         target_encoding = target_encoding, 
                         cls_hidden_dims = [1024,1024,512], 
                         train_epoch = 50, 
                         test_every_X_epoch = 10, 
                         LR = 0.001, 
                         batch_size = 256,
                         hidden_dim_drug = 128,
                         cnn_drug_filters = [32,64,96],
                         cnn_drug_kernels = [4,6,8],
                         cnn_target_filters = [32,64,96],
                         cnn_target_kernels = [4,8,12]
                        )

# %%
# Model initialization
model = models.model_initialize(**config)
model

# %%
# Model training
model.train(train, val, test)

# Model saving
model.save_model('./pretrained_model/CNN_CNN_BindingDB_IC50_transmem/')
# Out:
# Let's use 1 GPU!
# --- Data Preparation ---
# --- Go for Training ---
# Training at Epoch 1 iteration 0 with loss 41.8658. Total time 0.00277 hours
# Training at Epoch 1 iteration 100 with loss 2.07929. Total time 0.02138 hours
# Training at Epoch 1 iteration 200 with loss 2.35228. Total time 0.03972 hours
# Training at Epoch 1 iteration 300 with loss 1.91903. Total time 0.05833 hours
# Training at Epoch 1 iteration 400 with loss 1.60800. Total time 0.0775 hours
# Training at Epoch 1 iteration 500 with loss 1.62952. Total time 0.10083 hours
# Training at Epoch 1 iteration 600 with loss 1.65166. Total time 0.12611 hours
# Training at Epoch 1 iteration 700 with loss 1.60413. Total time 0.15138 hours
# Training at Epoch 1 iteration 800 with loss 1.55731. Total time 0.17583 hours
# Training at Epoch 1 iteration 900 with loss 1.41258. Total time 0.20055 hours
# Training at Epoch 1 iteration 1000 with loss 1.43061. Total time 0.225 hours
# Training at Epoch 1 iteration 1100 with loss 1.70673. Total time 0.24972 hours
# Training at Epoch 1 iteration 1200 with loss 1.31326. Total time 0.27416 hours
# Training at Epoch 1 iteration 1300 with loss 1.56052. Total time 0.29833 hours
# Training at Epoch 1 iteration 1400 with loss 1.57946. Total time 0.32194 hours
# Training at Epoch 1 iteration 1500 with loss 1.62185. Total time 0.345 hours
# Training at Epoch 1 iteration 1600 with loss 1.36183. Total time 0.36833 hours
# Training at Epoch 1 iteration 1700 with loss 1.26321. Total time 0.39138 hours
# Training at Epoch 1 iteration 1800 with loss 1.34193. Total time 0.41472 hours
# Training at Epoch 1 iteration 1900 with loss 1.54189. Total time 0.43777 hours
# Training at Epoch 1 iteration 2000 with loss 1.30895. Total time 0.46083 hours
# Training at Epoch 1 iteration 2100 with loss 1.42555. Total time 0.48388 hours
# Training at Epoch 1 iteration 2200 with loss 1.49273. Total time 0.50694 hours
# Training at Epoch 1 iteration 2300 with loss 1.48425. Total time 0.52972 hours
# Training at Epoch 1 iteration 2400 with loss 1.37915. Total time 0.55277 hours
# Training at Epoch 1 iteration 2500 with loss 1.30150. Total time 0.57583 hours
# Training at Epoch 1 iteration 2600 with loss 1.36935. Total time 0.59888 hours
# Training at Epoch 1 iteration 2700 with loss 1.21112. Total time 0.62194 hours
# Training at Epoch 1 iteration 2800 with loss 1.26851. Total time 0.64472 hours
# Training at Epoch 1 iteration 2900 with loss 1.27428. Total time 0.66777 hours
# Training at Epoch 1 iteration 3000 with loss 1.72946. Total time 0.69083 hours
# Training at Epoch 1 iteration 3100 with loss 1.20090. Total time 0.71361 hours
# Training at Epoch 1 iteration 3200 with loss 1.19832. Total time 0.73666 hours
# Training at Epoch 1 iteration 3300 with loss 1.25563. Total time 0.75944 hours
# Training at Epoch 1 iteration 3400 with loss 1.38863. Total time 0.78222 hours
# Training at Epoch 1 iteration 3500 with loss 1.11440. Total time 0.805 hours
# Training at Epoch 1 iteration 3600 with loss 1.28627. Total time 0.82777 hours
# Training at Epoch 1 iteration 3700 with loss 1.24589. Total time 0.85055 hours
# Training at Epoch 1 iteration 3800 with loss 1.23263. Total time 0.87305 hours
# Training at Epoch 1 iteration 3900 with loss 1.23914. Total time 0.89583 hours
# Training at Epoch 1 iteration 4000 with loss 1.43769. Total time 0.91833 hours
# Training at Epoch 1 iteration 4100 with loss 1.11297. Total time 0.94083 hours
# Training at Epoch 1 iteration 4200 with loss 1.14028. Total time 0.96361 hours
# Training at Epoch 1 iteration 4300 with loss 1.33438. Total time 0.98611 hours
# Validation at Epoch 1 with loss:0.64675, MSE: 1.19123 , Pearson Correlation: 0.67871 with p-value: 0.00E+00 , Concordance Index: 0.74489
# Training at Epoch 2 iteration 0 with loss 1.26620. Total time 1.10972 hours
# Training at Epoch 2 iteration 100 with loss 1.13258. Total time 1.12861 hours
# Training at Epoch 2 iteration 200 with loss 1.17514. Total time 1.14694 hours
# Training at Epoch 2 iteration 300 with loss 1.17112. Total time 1.165 hours
# Training at Epoch 2 iteration 400 with loss 1.26934. Total time 1.18361 hours
# Training at Epoch 2 iteration 500 with loss 1.81584. Total time 1.20194 hours
# Training at Epoch 2 iteration 600 with loss 1.30977. Total time 1.22055 hours
# Training at Epoch 2 iteration 700 with loss 1.34323. Total time 1.23888 hours
# Training at Epoch 2 iteration 800 with loss 1.22293. Total time 1.2575 hours
# Training at Epoch 2 iteration 900 with loss 1.04874. Total time 1.27611 hours
# Training at Epoch 2 iteration 1000 with loss 0.99951. Total time 1.29472 hours
# Training at Epoch 2 iteration 1100 with loss 1.21873. Total time 1.31305 hours
# Training at Epoch 2 iteration 1200 with loss 1.21516. Total time 1.33138 hours
# Training at Epoch 2 iteration 1300 with loss 1.24149. Total time 1.34972 hours
# Training at Epoch 2 iteration 1400 with loss 1.38593. Total time 1.36805 hours
# Training at Epoch 2 iteration 1500 with loss 1.11276. Total time 1.38666 hours
# Training at Epoch 2 iteration 1600 with loss 2.04347. Total time 1.405 hours
# Training at Epoch 2 iteration 1700 with loss 1.32298. Total time 1.42333 hours
# Training at Epoch 2 iteration 1800 with loss 1.10494. Total time 1.44166 hours
# Training at Epoch 2 iteration 1900 with loss 1.33222. Total time 1.46 hours
# Training at Epoch 2 iteration 2000 with loss 1.09960. Total time 1.47861 hours
# Training at Epoch 2 iteration 2100 with loss 1.38621. Total time 1.49694 hours
# Training at Epoch 2 iteration 2200 with loss 1.18722. Total time 1.51527 hours
# Training at Epoch 2 iteration 2300 with loss 1.00529. Total time 1.53388 hours
# Training at Epoch 2 iteration 2400 with loss 1.16247. Total time 1.55222 hours
# Training at Epoch 2 iteration 2500 with loss 0.96382. Total time 1.57055 hours
# Training at Epoch 2 iteration 2600 with loss 1.12095. Total time 1.58888 hours
# Training at Epoch 2 iteration 2700 with loss 0.88264. Total time 1.60722 hours
# Training at Epoch 2 iteration 2800 with loss 1.18833. Total time 1.62583 hours
# Training at Epoch 2 iteration 2900 with loss 1.21482. Total time 1.64416 hours
# Training at Epoch 2 iteration 3000 with loss 1.30385. Total time 1.6625 hours
# Training at Epoch 2 iteration 3100 with loss 1.33914. Total time 1.68083 hours
# Training at Epoch 2 iteration 3200 with loss 1.19987. Total time 1.69916 hours
# Training at Epoch 2 iteration 3300 with loss 1.08808. Total time 1.7175 hours
# Training at Epoch 2 iteration 3400 with loss 1.38859. Total time 1.73583 hours
# Training at Epoch 2 iteration 3500 with loss 1.02253. Total time 1.75444 hours
# Training at Epoch 2 iteration 3600 with loss 1.34683. Total time 1.77305 hours
# Training at Epoch 2 iteration 3700 with loss 1.09609. Total time 1.79166 hours
# Training at Epoch 2 iteration 3800 with loss 1.12838. Total time 1.8125 hours
# Training at Epoch 2 iteration 3900 with loss 1.02168. Total time 1.83666 hours
# Training at Epoch 2 iteration 4000 with loss 1.09709. Total time 1.86111 hours
# Training at Epoch 2 iteration 4100 with loss 1.08822. Total time 1.88527 hours
# Training at Epoch 2 iteration 4200 with loss 1.12491. Total time 1.90972 hours
# Training at Epoch 2 iteration 4300 with loss 0.94282. Total time 1.93388 hours
# Validation at Epoch 2 with loss:1.92994, MSE: 1.08784 , Pearson Correlation: 0.71286 with p-value: 0.00E+00 , Concordance Index: 0.76101
# Training at Epoch 3 iteration 0 with loss 1.03036. Total time 2.07083 hours
# Training at Epoch 3 iteration 100 with loss 0.97680. Total time 2.09555 hours
# Training at Epoch 3 iteration 200 with loss 1.01945. Total time 2.11972 hours
# Training at Epoch 3 iteration 300 with loss 1.02012. Total time 2.14388 hours
# Training at Epoch 3 iteration 400 with loss 1.13008. Total time 2.16805 hours
# Training at Epoch 3 iteration 500 with loss 0.93414. Total time 2.19194 hours
# Training at Epoch 3 iteration 600 with loss 1.13212. Total time 2.21638 hours
# Training at Epoch 3 iteration 700 with loss 0.97363. Total time 2.24166 hours
# Training at Epoch 3 iteration 800 with loss 1.00256. Total time 2.26666 hours
# Training at Epoch 3 iteration 900 with loss 1.04829. Total time 2.29111 hours
# Training at Epoch 3 iteration 1000 with loss 1.19246. Total time 2.31611 hours
# Training at Epoch 3 iteration 1100 with loss 0.92338. Total time 2.34083 hours
# Training at Epoch 3 iteration 1200 with loss 1.07726. Total time 2.36555 hours
# Training at Epoch 3 iteration 1300 with loss 1.15044. Total time 2.39 hours
# Training at Epoch 3 iteration 1400 with loss 1.12966. Total time 2.41472 hours
# Training at Epoch 3 iteration 1500 with loss 1.00554. Total time 2.43916 hours
# Training at Epoch 3 iteration 1600 with loss 1.21967. Total time 2.46388 hours
# Training at Epoch 3 iteration 1700 with loss 1.04999. Total time 2.48861 hours
# Training at Epoch 3 iteration 1800 with loss 1.13839. Total time 2.51333 hours
# Training at Epoch 3 iteration 1900 with loss 1.11487. Total time 2.53694 hours
# Training at Epoch 3 iteration 2000 with loss 0.92017. Total time 2.56 hours
# Training at Epoch 3 iteration 2100 with loss 1.08487. Total time 2.58305 hours
# Training at Epoch 3 iteration 2200 with loss 1.02835. Total time 2.60583 hours
# Training at Epoch 3 iteration 2300 with loss 1.11428. Total time 2.62861 hours
# Training at Epoch 3 iteration 2400 with loss 1.46329. Total time 2.65166 hours
# Training at Epoch 3 iteration 2500 with loss 1.08387. Total time 2.67444 hours
# Training at Epoch 3 iteration 2600 with loss 1.00731. Total time 2.6975 hours
# Training at Epoch 3 iteration 2700 with loss 1.10160. Total time 2.72055 hours
# Training at Epoch 3 iteration 2800 with loss 1.01673. Total time 2.74305 hours
# Training at Epoch 3 iteration 2900 with loss 1.12960. Total time 2.76555 hours
# Training at Epoch 3 iteration 3000 with loss 0.84334. Total time 2.78805 hours
# Training at Epoch 3 iteration 3100 with loss 1.17465. Total time 2.81083 hours
# Training at Epoch 3 iteration 3200 with loss 0.98318. Total time 2.83333 hours
# Training at Epoch 3 iteration 3300 with loss 1.07796. Total time 2.855 hours
# Training at Epoch 3 iteration 3400 with loss 1.10485. Total time 2.87361 hours
# Training at Epoch 3 iteration 3500 with loss 1.26707. Total time 2.89222 hours
# Training at Epoch 3 iteration 3600 with loss 1.20308. Total time 2.91111 hours
# Training at Epoch 3 iteration 3700 with loss 1.11775. Total time 2.92972 hours
# Training at Epoch 3 iteration 3800 with loss 0.98886. Total time 2.94944 hours
# Training at Epoch 3 iteration 3900 with loss 1.25175. Total time 2.97361 hours
# Training at Epoch 3 iteration 4000 with loss 1.00770. Total time 2.99777 hours
# Training at Epoch 3 iteration 4100 with loss 0.93079. Total time 3.02194 hours
# Training at Epoch 3 iteration 4200 with loss 1.09895. Total time 3.04611 hours
# Training at Epoch 3 iteration 4300 with loss 1.01243. Total time 3.07055 hours
# Validation at Epoch 3 with loss:1.28138, MSE: 1.02596 , Pearson Correlation: 0.73201 with p-value: 0.00E+00 , Concordance Index: 0.77036
# Training at Epoch 4 iteration 0 with loss 0.96598. Total time 3.20111 hours
# Training at Epoch 4 iteration 100 with loss 0.83935. Total time 3.22472 hours
# Training at Epoch 4 iteration 200 with loss 1.14849. Total time 3.24805 hours
# Training at Epoch 4 iteration 300 with loss 1.25782. Total time 3.27166 hours
# Training at Epoch 4 iteration 400 with loss 0.95120. Total time 3.29527 hours
# Training at Epoch 4 iteration 500 with loss 1.62712. Total time 3.31888 hours
# Training at Epoch 4 iteration 600 with loss 1.04554. Total time 3.3425 hours
# Training at Epoch 4 iteration 700 with loss 0.97301. Total time 3.36611 hours
# Training at Epoch 4 iteration 800 with loss 0.98053. Total time 3.38972 hours
# Training at Epoch 4 iteration 900 with loss 1.21494. Total time 3.41333 hours
# Training at Epoch 4 iteration 1000 with loss 1.25648. Total time 3.43666 hours
# Training at Epoch 4 iteration 1100 with loss 0.86926. Total time 3.46027 hours
# Training at Epoch 4 iteration 1200 with loss 1.03899. Total time 3.48361 hours
# Training at Epoch 4 iteration 1300 with loss 0.88388. Total time 3.50722 hours
# Training at Epoch 4 iteration 1400 with loss 0.90607. Total time 3.53055 hours
# Training at Epoch 4 iteration 1500 with loss 1.03811. Total time 3.55388 hours
# Training at Epoch 4 iteration 1600 with loss 0.92946. Total time 3.57722 hours
# Training at Epoch 4 iteration 1700 with loss 1.12005. Total time 3.60055 hours
# Training at Epoch 4 iteration 1800 with loss 0.88733. Total time 3.62388 hours
# Training at Epoch 4 iteration 1900 with loss 1.03816. Total time 3.64722 hours
# Training at Epoch 4 iteration 2000 with loss 1.03566. Total time 3.67027 hours
# Training at Epoch 4 iteration 2100 with loss 0.96122. Total time 3.69361 hours
# Training at Epoch 4 iteration 2200 with loss 1.01427. Total time 3.71666 hours
# Training at Epoch 4 iteration 2300 with loss 0.92658. Total time 3.74 hours
# Training at Epoch 4 iteration 2400 with loss 0.95285. Total time 3.76305 hours
# Training at Epoch 4 iteration 2500 with loss 0.92131. Total time 3.78611 hours
# Training at Epoch 4 iteration 2600 with loss 0.92918. Total time 3.80916 hours
# Training at Epoch 4 iteration 2700 with loss 0.97772. Total time 3.83222 hours
# Training at Epoch 4 iteration 2800 with loss 1.06719. Total time 3.85527 hours
# Training at Epoch 4 iteration 2900 with loss 0.91893. Total time 3.87833 hours
# Training at Epoch 4 iteration 3000 with loss 1.05959. Total time 3.90138 hours
# Training at Epoch 4 iteration 3100 with loss 0.98734. Total time 3.92416 hours
# Training at Epoch 4 iteration 3200 with loss 1.07562. Total time 3.94722 hours
# Training at Epoch 4 iteration 3300 with loss 1.12306. Total time 3.97027 hours
# Training at Epoch 4 iteration 3400 with loss 1.02804. Total time 3.99111 hours
# Training at Epoch 4 iteration 3500 with loss 1.07200. Total time 4.00972 hours
# Training at Epoch 4 iteration 3600 with loss 0.97948. Total time 4.02805 hours
# Training at Epoch 4 iteration 3700 with loss 0.96235. Total time 4.04638 hours
# Training at Epoch 4 iteration 3800 with loss 0.90192. Total time 4.06472 hours
# Training at Epoch 4 iteration 3900 with loss 0.97520. Total time 4.08305 hours
# Training at Epoch 4 iteration 4000 with loss 1.23416. Total time 4.10166 hours
# Training at Epoch 4 iteration 4100 with loss 1.13566. Total time 4.12 hours
# Training at Epoch 4 iteration 4200 with loss 1.03991. Total time 4.13833 hours
# Training at Epoch 4 iteration 4300 with loss 1.07043. Total time 4.15666 hours
# Validation at Epoch 4 with loss:0.90800, MSE: 0.98534 , Pearson Correlation: 0.74528 with p-value: 0.00E+00 , Concordance Index: 0.77689
# Training at Epoch 5 iteration 0 with loss 0.90192. Total time 4.26694 hours
# Training at Epoch 5 iteration 100 with loss 0.85474. Total time 4.28527 hours
# Training at Epoch 5 iteration 200 with loss 0.89662. Total time 4.30361 hours
# Training at Epoch 5 iteration 300 with loss 0.95555. Total time 4.32194 hours
# Training at Epoch 5 iteration 400 with loss 0.96877. Total time 4.34027 hours
# Training at Epoch 5 iteration 500 with loss 0.97757. Total time 4.35861 hours
# Training at Epoch 5 iteration 600 with loss 1.02888. Total time 4.37694 hours
# Training at Epoch 5 iteration 700 with loss 1.11484. Total time 4.39527 hours
# Training at Epoch 5 iteration 800 with loss 1.12974. Total time 4.41361 hours
# Training at Epoch 5 iteration 900 with loss 1.06408. Total time 4.43194 hours
# Training at Epoch 5 iteration 1000 with loss 1.03202. Total time 4.45055 hours
# Training at Epoch 5 iteration 1100 with loss 0.88161. Total time 4.46888 hours
# Training at Epoch 5 iteration 1200 with loss 1.15053. Total time 4.48722 hours
# Training at Epoch 5 iteration 1300 with loss 0.89305. Total time 4.50555 hours
# Training at Epoch 5 iteration 1400 with loss 1.02592. Total time 4.52361 hours
# Training at Epoch 5 iteration 1500 with loss 1.24314. Total time 4.54194 hours
# Training at Epoch 5 iteration 1600 with loss 0.90033. Total time 4.56027 hours
# Training at Epoch 5 iteration 1700 with loss 1.20967. Total time 4.57861 hours
# Training at Epoch 5 iteration 1800 with loss 1.11105. Total time 4.59666 hours
# Training at Epoch 5 iteration 1900 with loss 1.52407. Total time 4.615 hours
# Training at Epoch 5 iteration 2000 with loss 1.06986. Total time 4.63333 hours
# Training at Epoch 5 iteration 2100 with loss 1.14748. Total time 4.65138 hours
# Training at Epoch 5 iteration 2200 with loss 1.01425. Total time 4.66972 hours
# Training at Epoch 5 iteration 2300 with loss 0.95477. Total time 4.68805 hours
# Training at Epoch 5 iteration 2400 with loss 1.04249. Total time 4.70638 hours
# Training at Epoch 5 iteration 2500 with loss 0.99182. Total time 4.72444 hours
# Training at Epoch 5 iteration 2600 with loss 1.03154. Total time 4.74277 hours
# Training at Epoch 5 iteration 2700 with loss 1.04966. Total time 4.76111 hours
# Training at Epoch 5 iteration 2800 with loss 0.93774. Total time 4.77944 hours
# Training at Epoch 5 iteration 2900 with loss 0.78372. Total time 4.7975 hours
# Training at Epoch 5 iteration 3000 with loss 0.85519. Total time 4.81583 hours
# Training at Epoch 5 iteration 3100 with loss 0.99523. Total time 4.83416 hours
# Training at Epoch 5 iteration 3200 with loss 0.88827. Total time 4.8525 hours
# Training at Epoch 5 iteration 3300 with loss 0.83579. Total time 4.87055 hours
# Training at Epoch 5 iteration 3400 with loss 0.87978. Total time 4.88888 hours
# Training at Epoch 5 iteration 3500 with loss 1.00834. Total time 4.90722 hours
# Training at Epoch 5 iteration 3600 with loss 0.83670. Total time 4.92527 hours
# Training at Epoch 5 iteration 3700 with loss 1.05108. Total time 4.94361 hours
# Training at Epoch 5 iteration 3800 with loss 1.13986. Total time 4.96194 hours
# Training at Epoch 5 iteration 3900 with loss 1.01201. Total time 4.98027 hours
# Training at Epoch 5 iteration 4000 with loss 0.91732. Total time 4.99833 hours
# Training at Epoch 5 iteration 4100 with loss 0.87105. Total time 5.01666 hours
# Training at Epoch 5 iteration 4200 with loss 0.78859. Total time 5.035 hours
# Training at Epoch 5 iteration 4300 with loss 0.87143. Total time 5.05333 hours
# Validation at Epoch 5 with loss:1.96919, MSE: 0.96331 , Pearson Correlation: 0.75646 with p-value: 0.00E+00 , Concordance Index: 0.78261
# Training at Epoch 6 iteration 0 with loss 0.85183. Total time 5.16444 hours
# Training at Epoch 6 iteration 100 with loss 0.96133. Total time 5.18277 hours
# Training at Epoch 6 iteration 200 with loss 1.06914. Total time 5.20083 hours
# Training at Epoch 6 iteration 300 with loss 1.00588. Total time 5.21916 hours
# Training at Epoch 6 iteration 400 with loss 1.10724. Total time 5.2375 hours
# Training at Epoch 6 iteration 500 with loss 0.88131. Total time 5.25583 hours
# Training at Epoch 6 iteration 600 with loss 0.91365. Total time 5.27416 hours
# Training at Epoch 6 iteration 700 with loss 1.06481. Total time 5.2925 hours
# Training at Epoch 6 iteration 800 with loss 1.09616. Total time 5.31083 hours
# Training at Epoch 6 iteration 900 with loss 0.96446. Total time 5.32916 hours
# Training at Epoch 6 iteration 1000 with loss 0.88873. Total time 5.3475 hours
# Training at Epoch 6 iteration 1100 with loss 0.97927. Total time 5.36583 hours
# Training at Epoch 6 iteration 1200 with loss 1.04636. Total time 5.38444 hours
# Training at Epoch 6 iteration 1300 with loss 0.91059. Total time 5.40277 hours
# Training at Epoch 6 iteration 1400 with loss 0.92188. Total time 5.42111 hours
# Training at Epoch 6 iteration 1500 with loss 0.99375. Total time 5.43944 hours
# Training at Epoch 6 iteration 1600 with loss 1.02217. Total time 5.45777 hours
# Training at Epoch 6 iteration 1700 with loss 0.89102. Total time 5.47611 hours
# Training at Epoch 6 iteration 1800 with loss 0.85227. Total time 5.49444 hours
# Training at Epoch 6 iteration 1900 with loss 0.83891. Total time 5.51277 hours
# Training at Epoch 6 iteration 2000 with loss 0.76056. Total time 5.53111 hours
# Training at Epoch 6 iteration 2100 with loss 0.80814. Total time 5.54944 hours
# Training at Epoch 6 iteration 2200 with loss 0.82620. Total time 5.56777 hours
# Training at Epoch 6 iteration 2300 with loss 1.07882. Total time 5.58611 hours
# Training at Epoch 6 iteration 2400 with loss 0.98799. Total time 5.60444 hours
# Training at Epoch 6 iteration 2500 with loss 0.98814. Total time 5.62277 hours
# Training at Epoch 6 iteration 2600 with loss 0.94354. Total time 5.64111 hours
# Training at Epoch 6 iteration 2700 with loss 1.18532. Total time 5.65944 hours
# Training at Epoch 6 iteration 2800 with loss 0.99691. Total time 5.67777 hours
# Training at Epoch 6 iteration 2900 with loss 1.06286. Total time 5.69611 hours
# Training at Epoch 6 iteration 3000 with loss 1.04766. Total time 5.71444 hours
# Training at Epoch 6 iteration 3100 with loss 1.08861. Total time 5.73277 hours
# Training at Epoch 6 iteration 3200 with loss 0.88980. Total time 5.75111 hours
# Training at Epoch 6 iteration 3300 with loss 0.79165. Total time 5.76944 hours
# Training at Epoch 6 iteration 3400 with loss 0.97764. Total time 5.78805 hours
# Training at Epoch 6 iteration 3500 with loss 0.79040. Total time 5.80638 hours
# Training at Epoch 6 iteration 3600 with loss 1.01268. Total time 5.82472 hours
# Training at Epoch 6 iteration 3700 with loss 1.02441. Total time 5.84305 hours
# Training at Epoch 6 iteration 3800 with loss 0.83958. Total time 5.86138 hours
# Training at Epoch 6 iteration 3900 with loss 1.01118. Total time 5.87972 hours
# Training at Epoch 6 iteration 4000 with loss 0.83413. Total time 5.89805 hours
# Training at Epoch 6 iteration 4100 with loss 1.01366. Total time 5.91638 hours
# Training at Epoch 6 iteration 4200 with loss 1.04232. Total time 5.93472 hours
# Training at Epoch 6 iteration 4300 with loss 0.83400. Total time 5.95305 hours
# Validation at Epoch 6 with loss:1.04298, MSE: 0.94392 , Pearson Correlation: 0.76272 with p-value: 0.00E+00 , Concordance Index: 0.78602
# Training at Epoch 7 iteration 0 with loss 0.89176. Total time 6.06416 hours
# Training at Epoch 7 iteration 100 with loss 1.02557. Total time 6.0825 hours
# Training at Epoch 7 iteration 200 with loss 0.91722. Total time 6.10055 hours
# Training at Epoch 7 iteration 300 with loss 0.90557. Total time 6.11888 hours
# Training at Epoch 7 iteration 400 with loss 0.93463. Total time 6.13722 hours
# Training at Epoch 7 iteration 500 with loss 0.75292. Total time 6.15555 hours
# Training at Epoch 7 iteration 600 with loss 0.85012. Total time 6.17416 hours
# Training at Epoch 7 iteration 700 with loss 1.09281. Total time 6.1925 hours
# Training at Epoch 7 iteration 800 with loss 1.05082. Total time 6.21083 hours
# Training at Epoch 7 iteration 900 with loss 0.99240. Total time 6.22916 hours
# Training at Epoch 7 iteration 1000 with loss 0.82005. Total time 6.2475 hours
# Training at Epoch 7 iteration 1100 with loss 0.88813. Total time 6.26583 hours
# Training at Epoch 7 iteration 1200 with loss 0.96828. Total time 6.28416 hours
# Training at Epoch 7 iteration 1300 with loss 0.90054. Total time 6.3025 hours
# Training at Epoch 7 iteration 1400 with loss 0.93053. Total time 6.32083 hours
# Training at Epoch 7 iteration 1500 with loss 1.05365. Total time 6.33916 hours
# Training at Epoch 7 iteration 1600 with loss 0.81240. Total time 6.3575 hours
# Training at Epoch 7 iteration 1700 with loss 0.90358. Total time 6.37583 hours
# Training at Epoch 7 iteration 1800 with loss 0.92475. Total time 6.39416 hours
# Training at Epoch 7 iteration 1900 with loss 0.94336. Total time 6.4125 hours
# Training at Epoch 7 iteration 2000 with loss 0.80208. Total time 6.43083 hours
# Training at Epoch 7 iteration 2100 with loss 0.97353. Total time 6.44916 hours
# Training at Epoch 7 iteration 2200 with loss 1.01355. Total time 6.4675 hours
# Training at Epoch 7 iteration 2300 with loss 0.88133. Total time 6.48583 hours
# Training at Epoch 7 iteration 2400 with loss 0.96995. Total time 6.50416 hours
# Training at Epoch 7 iteration 2500 with loss 1.09094. Total time 6.5225 hours
# Training at Epoch 7 iteration 2600 with loss 0.93133. Total time 6.54083 hours
# Training at Epoch 7 iteration 2700 with loss 0.99198. Total time 6.55916 hours
# Training at Epoch 7 iteration 2800 with loss 0.91767. Total time 6.5775 hours
# Training at Epoch 7 iteration 2900 with loss 0.74472. Total time 6.59611 hours
# Training at Epoch 7 iteration 3000 with loss 1.01035. Total time 6.61444 hours
# Training at Epoch 7 iteration 3100 with loss 0.89235. Total time 6.63277 hours
# Training at Epoch 7 iteration 3200 with loss 1.11550. Total time 6.65111 hours
# Training at Epoch 7 iteration 3300 with loss 1.04373. Total time 6.66944 hours
# Training at Epoch 7 iteration 3400 with loss 0.92950. Total time 6.68777 hours
# Training at Epoch 7 iteration 3500 with loss 0.90571. Total time 6.70611 hours
# Training at Epoch 7 iteration 3600 with loss 0.89740. Total time 6.72444 hours
# Training at Epoch 7 iteration 3700 with loss 0.91285. Total time 6.74277 hours
# Training at Epoch 7 iteration 3800 with loss 0.59684. Total time 6.76111 hours
# Training at Epoch 7 iteration 3900 with loss 0.83604. Total time 6.77944 hours
# Training at Epoch 7 iteration 4000 with loss 0.70772. Total time 6.79777 hours
# Training at Epoch 7 iteration 4100 with loss 1.02347. Total time 6.81611 hours
# Training at Epoch 7 iteration 4200 with loss 0.91501. Total time 6.83444 hours
# Training at Epoch 7 iteration 4300 with loss 0.82076. Total time 6.85277 hours
# Validation at Epoch 7 with loss:0.98397, MSE: 0.93725 , Pearson Correlation: 0.76575 with p-value: 0.00E+00 , Concordance Index: 0.78718
# Training at Epoch 8 iteration 0 with loss 0.99943. Total time 6.96277 hours
# Training at Epoch 8 iteration 100 with loss 0.90585. Total time 6.98111 hours
# Training at Epoch 8 iteration 200 with loss 0.78360. Total time 6.99944 hours
# Training at Epoch 8 iteration 300 with loss 0.78705. Total time 7.01777 hours
# Training at Epoch 8 iteration 400 with loss 0.92749. Total time 7.03611 hours
# Training at Epoch 8 iteration 500 with loss 1.04021. Total time 7.05444 hours
# Training at Epoch 8 iteration 600 with loss 0.88044. Total time 7.07277 hours
# Training at Epoch 8 iteration 700 with loss 0.83433. Total time 7.09111 hours
# Training at Epoch 8 iteration 800 with loss 0.96547. Total time 7.10944 hours
# Training at Epoch 8 iteration 900 with loss 0.69569. Total time 7.12777 hours
# Training at Epoch 8 iteration 1000 with loss 0.93471. Total time 7.14611 hours
# Training at Epoch 8 iteration 1100 with loss 0.86752. Total time 7.16444 hours
# Training at Epoch 8 iteration 1200 with loss 0.86258. Total time 7.18277 hours
# Training at Epoch 8 iteration 1300 with loss 1.04339. Total time 7.20111 hours
# Training at Epoch 8 iteration 1400 with loss 0.77786. Total time 7.21944 hours
# Training at Epoch 8 iteration 1500 with loss 0.76441. Total time 7.23777 hours
# Training at Epoch 8 iteration 1600 with loss 0.91145. Total time 7.25611 hours
# Training at Epoch 8 iteration 1700 with loss 0.72677. Total time 7.27444 hours
# Training at Epoch 8 iteration 1800 with loss 0.95424. Total time 7.29277 hours
# Training at Epoch 8 iteration 1900 with loss 0.80759. Total time 7.31111 hours
# Training at Epoch 8 iteration 2000 with loss 0.86453. Total time 7.32944 hours
# Training at Epoch 8 iteration 2100 with loss 0.88599. Total time 7.34777 hours
# Training at Epoch 8 iteration 2200 with loss 0.92855. Total time 7.36611 hours
# Training at Epoch 8 iteration 2300 with loss 1.13565. Total time 7.38444 hours
# Training at Epoch 8 iteration 2400 with loss 0.70774. Total time 7.40277 hours
# Training at Epoch 8 iteration 2500 with loss 0.81372. Total time 7.42111 hours
# Training at Epoch 8 iteration 2600 with loss 1.23430. Total time 7.43944 hours
# Training at Epoch 8 iteration 2700 with loss 0.96335. Total time 7.45777 hours
# Training at Epoch 8 iteration 2800 with loss 0.78965. Total time 7.47611 hours
# Training at Epoch 8 iteration 2900 with loss 0.95258. Total time 7.49444 hours
# Training at Epoch 8 iteration 3000 with loss 0.94765. Total time 7.51277 hours
# Training at Epoch 8 iteration 3100 with loss 0.82947. Total time 7.53111 hours
# Training at Epoch 8 iteration 3200 with loss 0.83078. Total time 7.54944 hours
# Training at Epoch 8 iteration 3300 with loss 0.90822. Total time 7.56777 hours
# Training at Epoch 8 iteration 3400 with loss 0.76518. Total time 7.58638 hours
# Training at Epoch 8 iteration 3500 with loss 0.83282. Total time 7.60472 hours
# Training at Epoch 8 iteration 3600 with loss 0.82043. Total time 7.62305 hours
# Training at Epoch 8 iteration 3700 with loss 0.73886. Total time 7.64138 hours
# Training at Epoch 8 iteration 3800 with loss 0.83276. Total time 7.65972 hours
# Training at Epoch 8 iteration 3900 with loss 1.07885. Total time 7.67805 hours
# Training at Epoch 8 iteration 4000 with loss 0.85613. Total time 7.69638 hours
# Training at Epoch 8 iteration 4100 with loss 0.80389. Total time 7.71472 hours
# Training at Epoch 8 iteration 4200 with loss 0.76550. Total time 7.73305 hours
# Training at Epoch 8 iteration 4300 with loss 0.85638. Total time 7.75138 hours
# Validation at Epoch 8 with loss:0.89748, MSE: 0.88871 , Pearson Correlation: 0.77262 with p-value: 0.00E+00 , Concordance Index: 0.79124
# Training at Epoch 9 iteration 0 with loss 0.85966. Total time 7.8625 hours
# Training at Epoch 9 iteration 100 with loss 0.94880. Total time 7.88083 hours
# Training at Epoch 9 iteration 200 with loss 0.87532. Total time 7.89888 hours
# Training at Epoch 9 iteration 300 with loss 0.98222. Total time 7.91722 hours
# Training at Epoch 9 iteration 400 with loss 0.84648. Total time 7.93555 hours
# Training at Epoch 9 iteration 500 with loss 1.08534. Total time 7.95388 hours
# Training at Epoch 9 iteration 600 with loss 0.98925. Total time 7.97222 hours
# Training at Epoch 9 iteration 700 with loss 0.75366. Total time 7.99083 hours
# Training at Epoch 9 iteration 800 with loss 0.80373. Total time 8.00916 hours
# Training at Epoch 9 iteration 900 with loss 0.96159. Total time 8.0275 hours
# Training at Epoch 9 iteration 1000 with loss 0.82417. Total time 8.04583 hours
# Training at Epoch 9 iteration 1100 with loss 0.90540. Total time 8.06416 hours
# Training at Epoch 9 iteration 1200 with loss 0.91506. Total time 8.0825 hours
# Training at Epoch 9 iteration 1300 with loss 0.91933. Total time 8.10083 hours
# Training at Epoch 9 iteration 1400 with loss 0.90369. Total time 8.11916 hours
# Training at Epoch 9 iteration 1500 with loss 0.90021. Total time 8.1375 hours
# Training at Epoch 9 iteration 1600 with loss 0.94714. Total time 8.15583 hours
# Training at Epoch 9 iteration 1700 with loss 0.90838. Total time 8.17416 hours
# Training at Epoch 9 iteration 1800 with loss 0.79610. Total time 8.1925 hours
# Training at Epoch 9 iteration 1900 with loss 0.93247. Total time 8.21083 hours
# Training at Epoch 9 iteration 2000 with loss 0.66203. Total time 8.22916 hours
# Training at Epoch 9 iteration 2100 with loss 0.85065. Total time 8.2475 hours
# Training at Epoch 9 iteration 2200 with loss 0.85545. Total time 8.26583 hours
# Training at Epoch 9 iteration 2300 with loss 1.04239. Total time 8.28416 hours
# Training at Epoch 9 iteration 2400 with loss 0.83775. Total time 8.3025 hours
# Training at Epoch 9 iteration 2500 with loss 0.72760. Total time 8.32083 hours
# Training at Epoch 9 iteration 2600 with loss 0.67204. Total time 8.33916 hours
# Training at Epoch 9 iteration 2700 with loss 1.00816. Total time 8.3575 hours
# Training at Epoch 9 iteration 2800 with loss 0.79145. Total time 8.37583 hours
# Training at Epoch 9 iteration 2900 with loss 0.74943. Total time 8.39416 hours
# Training at Epoch 9 iteration 3000 with loss 0.72624. Total time 8.4125 hours
# Training at Epoch 9 iteration 3100 with loss 0.88089. Total time 8.43083 hours
# Training at Epoch 9 iteration 3200 with loss 1.00848. Total time 8.44916 hours
# Training at Epoch 9 iteration 3300 with loss 1.04125. Total time 8.46777 hours
# Training at Epoch 9 iteration 3400 with loss 0.95240. Total time 8.48611 hours
# Training at Epoch 9 iteration 3500 with loss 0.96845. Total time 8.50444 hours
# Training at Epoch 9 iteration 3600 with loss 0.90129. Total time 8.52277 hours
# Training at Epoch 9 iteration 3700 with loss 0.74544. Total time 8.54111 hours
# Training at Epoch 9 iteration 3800 with loss 0.73742. Total time 8.55944 hours
# Training at Epoch 9 iteration 3900 with loss 0.89038. Total time 8.57777 hours
# Training at Epoch 9 iteration 4000 with loss 0.78315. Total time 8.59611 hours
# Training at Epoch 9 iteration 4100 with loss 0.83834. Total time 8.61444 hours
# Training at Epoch 9 iteration 4200 with loss 0.87757. Total time 8.63277 hours
# Training at Epoch 9 iteration 4300 with loss 0.77888. Total time 8.65111 hours
# Validation at Epoch 9 with loss:0.93782, MSE: 0.88033 , Pearson Correlation: 0.77639 with p-value: 0.00E+00 , Concordance Index: 0.79278
# Training at Epoch 10 iteration 0 with loss 0.73213. Total time 8.76222 hours
# Training at Epoch 10 iteration 100 with loss 0.77942. Total time 8.78027 hours
# Training at Epoch 10 iteration 200 with loss 0.90030. Total time 8.79861 hours
# Training at Epoch 10 iteration 300 with loss 0.83294. Total time 8.81694 hours
# Training at Epoch 10 iteration 400 with loss 0.94483. Total time 8.83527 hours
# Training at Epoch 10 iteration 500 with loss 0.93581. Total time 8.85361 hours
# Training at Epoch 10 iteration 600 with loss 0.78910. Total time 8.87194 hours
# Training at Epoch 10 iteration 700 with loss 0.85373. Total time 8.89027 hours
# Training at Epoch 10 iteration 800 with loss 0.89124. Total time 8.90861 hours
# Training at Epoch 10 iteration 900 with loss 0.83146. Total time 8.92694 hours
# Training at Epoch 10 iteration 1000 with loss 0.97206. Total time 8.94527 hours
# Training at Epoch 10 iteration 1100 with loss 1.01013. Total time 8.96361 hours
# Training at Epoch 10 iteration 1200 with loss 0.78141. Total time 8.98194 hours
# Training at Epoch 10 iteration 1300 with loss 0.83278. Total time 9.00027 hours
# Training at Epoch 10 iteration 1400 with loss 0.73490. Total time 9.01861 hours
# Training at Epoch 10 iteration 1500 with loss 0.72617. Total time 9.03694 hours
# Training at Epoch 10 iteration 1600 with loss 0.79155. Total time 9.05527 hours
# Training at Epoch 10 iteration 1700 with loss 0.71736. Total time 9.07361 hours
# Training at Epoch 10 iteration 1800 with loss 1.24464. Total time 9.09194 hours
# Training at Epoch 10 iteration 1900 with loss 0.82246. Total time 9.11027 hours
# Training at Epoch 10 iteration 2000 with loss 0.78984. Total time 9.12861 hours
# Training at Epoch 10 iteration 2100 with loss 0.71503. Total time 9.14694 hours
# Training at Epoch 10 iteration 2200 with loss 0.84792. Total time 9.16527 hours
# Training at Epoch 10 iteration 2300 with loss 0.93055. Total time 9.18361 hours
# Training at Epoch 10 iteration 2400 with loss 0.82903. Total time 9.20194 hours
# Training at Epoch 10 iteration 2500 with loss 0.78734. Total time 9.22027 hours
# Training at Epoch 10 iteration 2600 with loss 0.91317. Total time 9.23861 hours
# Training at Epoch 10 iteration 2700 with loss 0.91757. Total time 9.25694 hours
# Training at Epoch 10 iteration 2800 with loss 0.79708. Total time 9.27527 hours
# Training at Epoch 10 iteration 2900 with loss 0.87040. Total time 9.29361 hours
# Training at Epoch 10 iteration 3000 with loss 0.68022. Total time 9.31194 hours
# Training at Epoch 10 iteration 3100 with loss 0.79767. Total time 9.33027 hours
# Training at Epoch 10 iteration 3200 with loss 0.84193. Total time 9.34861 hours
# Training at Epoch 10 iteration 3300 with loss 0.73517. Total time 9.36694 hours
# Training at Epoch 10 iteration 3400 with loss 0.94137. Total time 9.38527 hours
# Training at Epoch 10 iteration 3500 with loss 0.87800. Total time 9.40361 hours
# Training at Epoch 10 iteration 3600 with loss 0.81782. Total time 9.42194 hours
# Training at Epoch 10 iteration 3700 with loss 0.91479. Total time 9.44027 hours
# Training at Epoch 10 iteration 3800 with loss 0.98055. Total time 9.45861 hours
# Training at Epoch 10 iteration 3900 with loss 0.90262. Total time 9.47694 hours
# Training at Epoch 10 iteration 4000 with loss 0.93280. Total time 9.49527 hours
# Training at Epoch 10 iteration 4100 with loss 0.80481. Total time 9.51388 hours
# Training at Epoch 10 iteration 4200 with loss 0.87883. Total time 9.53222 hours
# Training at Epoch 10 iteration 4300 with loss 1.05147. Total time 9.55055 hours
# Validation at Epoch 10 with loss:0.60895, MSE: 0.87034 , Pearson Correlation: 0.77753 with p-value: 0.00E+00 , Concordance Index: 0.79327
# Training at Epoch 11 iteration 0 with loss 0.82995. Total time 9.66083 hours
# Training at Epoch 11 iteration 100 with loss 0.84390. Total time 9.67916 hours
# Training at Epoch 11 iteration 200 with loss 0.77228. Total time 9.69722 hours
# Training at Epoch 11 iteration 300 with loss 0.91183. Total time 9.71555 hours
# Training at Epoch 11 iteration 400 with loss 0.82179. Total time 9.73388 hours
# Training at Epoch 11 iteration 500 with loss 0.91882. Total time 9.75222 hours
# Training at Epoch 11 iteration 600 with loss 0.86640. Total time 9.77055 hours
# Training at Epoch 11 iteration 700 with loss 0.91310. Total time 9.78916 hours
# Training at Epoch 11 iteration 800 with loss 0.79559. Total time 9.80722 hours
# Training at Epoch 11 iteration 900 with loss 0.75245. Total time 9.82583 hours
# Training at Epoch 11 iteration 1000 with loss 0.97022. Total time 9.84416 hours
# Training at Epoch 11 iteration 1100 with loss 0.69906. Total time 9.8625 hours
# Training at Epoch 11 iteration 1200 with loss 0.82967. Total time 9.88083 hours
# Training at Epoch 11 iteration 1300 with loss 0.78719. Total time 9.89916 hours
# Training at Epoch 11 iteration 1400 with loss 0.87776. Total time 9.9175 hours
# Training at Epoch 11 iteration 1500 with loss 0.86346. Total time 9.93583 hours
# Training at Epoch 11 iteration 1600 with loss 0.94688. Total time 9.95416 hours
# Training at Epoch 11 iteration 1700 with loss 0.69891. Total time 9.9725 hours
# Training at Epoch 11 iteration 1800 with loss 0.85637. Total time 9.99083 hours
# Training at Epoch 11 iteration 1900 with loss 0.85195. Total time 10.0091 hours
# Training at Epoch 11 iteration 2000 with loss 0.77601. Total time 10.0275 hours
# Training at Epoch 11 iteration 2100 with loss 0.83363. Total time 10.0458 hours
# Training at Epoch 11 iteration 2200 with loss 0.90361. Total time 10.0641 hours
# Training at Epoch 11 iteration 2300 with loss 0.93684. Total time 10.0825 hours
# Training at Epoch 11 iteration 2400 with loss 0.91224. Total time 10.1008 hours
# Training at Epoch 11 iteration 2500 with loss 0.82409. Total time 10.1191 hours
# Training at Epoch 11 iteration 2600 with loss 1.40574. Total time 10.1375 hours
# Training at Epoch 11 iteration 2700 with loss 0.84633. Total time 10.1558 hours
# Training at Epoch 11 iteration 2800 with loss 0.77942. Total time 10.1741 hours
# Training at Epoch 11 iteration 2900 with loss 0.67373. Total time 10.1925 hours
# Training at Epoch 11 iteration 3000 with loss 0.78522. Total time 10.2108 hours
# Training at Epoch 11 iteration 3100 with loss 0.72665. Total time 10.2291 hours
# Training at Epoch 11 iteration 3200 with loss 0.75456. Total time 10.2475 hours
# Training at Epoch 11 iteration 3300 with loss 0.72491. Total time 10.2658 hours
# Training at Epoch 11 iteration 3400 with loss 0.80717. Total time 10.2841 hours
# Training at Epoch 11 iteration 3500 with loss 0.71755. Total time 10.3025 hours
# Training at Epoch 11 iteration 3600 with loss 0.91872. Total time 10.3208 hours
# Training at Epoch 11 iteration 3700 with loss 0.83852. Total time 10.3391 hours
# Training at Epoch 11 iteration 3800 with loss 0.78671. Total time 10.3575 hours
# Training at Epoch 11 iteration 3900 with loss 0.80131. Total time 10.3758 hours
# Training at Epoch 11 iteration 4000 with loss 0.73284. Total time 10.3941 hours
# Training at Epoch 11 iteration 4100 with loss 0.83839. Total time 10.4125 hours
# Training at Epoch 11 iteration 4200 with loss 0.72559. Total time 10.4311 hours
# Training at Epoch 11 iteration 4300 with loss 0.96169. Total time 10.4494 hours
# Validation at Epoch 11 with loss:1.25338, MSE: 0.86015 , Pearson Correlation: 0.78229 with p-value: 0.00E+00 , Concordance Index: 0.79682
# Training at Epoch 12 iteration 0 with loss 0.73106. Total time 10.5602 hours
# Training at Epoch 12 iteration 100 with loss 0.78004. Total time 10.5786 hours
# Training at Epoch 12 iteration 200 with loss 0.74272. Total time 10.5969 hours
# Training at Epoch 12 iteration 300 with loss 0.76192. Total time 10.6152 hours
# Training at Epoch 12 iteration 400 with loss 0.88012. Total time 10.6336 hours
# Training at Epoch 12 iteration 500 with loss 0.94489. Total time 10.6519 hours
# Training at Epoch 12 iteration 600 with loss 0.75325. Total time 10.6702 hours
# Training at Epoch 12 iteration 700 with loss 0.94918. Total time 10.6886 hours
# Training at Epoch 12 iteration 800 with loss 0.62366. Total time 10.7069 hours
# Training at Epoch 12 iteration 900 with loss 0.69031. Total time 10.7252 hours
# Training at Epoch 12 iteration 1000 with loss 0.85277. Total time 10.7436 hours
# Training at Epoch 12 iteration 1100 with loss 0.67172. Total time 10.7619 hours
# Training at Epoch 12 iteration 1200 with loss 1.41363. Total time 10.7802 hours
# Training at Epoch 12 iteration 1300 with loss 0.91189. Total time 10.7986 hours
# Training at Epoch 12 iteration 1400 with loss 0.85924. Total time 10.8169 hours
# Training at Epoch 12 iteration 1500 with loss 0.87659. Total time 10.8352 hours
# Training at Epoch 12 iteration 1600 with loss 0.72172. Total time 10.8536 hours
# Training at Epoch 12 iteration 1700 with loss 0.99623. Total time 10.8725 hours
# Training at Epoch 12 iteration 1800 with loss 0.81780. Total time 10.8908 hours
# Training at Epoch 12 iteration 1900 with loss 0.80774. Total time 10.9091 hours
# Training at Epoch 12 iteration 2000 with loss 0.72932. Total time 10.9275 hours
# Training at Epoch 12 iteration 2100 with loss 0.95924. Total time 10.9458 hours
# Training at Epoch 12 iteration 2200 with loss 0.96335. Total time 10.9641 hours
# Training at Epoch 12 iteration 2300 with loss 0.83349. Total time 10.9825 hours
# Training at Epoch 12 iteration 2400 with loss 0.98211. Total time 11.0008 hours
# Training at Epoch 12 iteration 2500 with loss 1.40838. Total time 11.0191 hours
# Training at Epoch 12 iteration 2600 with loss 1.02548. Total time 11.0375 hours
# Training at Epoch 12 iteration 2700 with loss 0.86793. Total time 11.0558 hours
# Training at Epoch 12 iteration 2800 with loss 0.80847. Total time 11.0741 hours
# Training at Epoch 12 iteration 2900 with loss 0.74217. Total time 11.0925 hours
# Training at Epoch 12 iteration 3000 with loss 0.77806. Total time 11.1108 hours
# Training at Epoch 12 iteration 3100 with loss 0.78115. Total time 11.1291 hours
# Training at Epoch 12 iteration 3200 with loss 0.72954. Total time 11.1475 hours
# Training at Epoch 12 iteration 3300 with loss 0.81039. Total time 11.1658 hours
# Training at Epoch 12 iteration 3400 with loss 0.91673. Total time 11.1841 hours
# Training at Epoch 12 iteration 3500 with loss 0.86015. Total time 11.2025 hours
# Training at Epoch 12 iteration 3600 with loss 0.84782. Total time 11.2208 hours
# Training at Epoch 12 iteration 3700 with loss 1.22287. Total time 11.2391 hours
# Training at Epoch 12 iteration 3800 with loss 0.71873. Total time 11.2575 hours
# Training at Epoch 12 iteration 3900 with loss 0.76923. Total time 11.2758 hours
# Training at Epoch 12 iteration 4000 with loss 0.91804. Total time 11.2941 hours
# Training at Epoch 12 iteration 4100 with loss 0.70846. Total time 11.3125 hours
# Training at Epoch 12 iteration 4200 with loss 0.88420. Total time 11.3308 hours
# Training at Epoch 12 iteration 4300 with loss 0.76799. Total time 11.3491 hours
# Validation at Epoch 12 with loss:0.99612, MSE: 0.84561 , Pearson Correlation: 0.78590 with p-value: 0.00E+00 , Concordance Index: 0.79836
# Training at Epoch 13 iteration 0 with loss 0.78370. Total time 11.4594 hours
# Training at Epoch 13 iteration 100 with loss 0.72435. Total time 11.4777 hours
# Training at Epoch 13 iteration 200 with loss 0.84288. Total time 11.4958 hours
# Training at Epoch 13 iteration 300 with loss 0.82669. Total time 11.5141 hours
# Training at Epoch 13 iteration 400 with loss 0.86505. Total time 11.5325 hours
# Training at Epoch 13 iteration 500 with loss 0.83940. Total time 11.5508 hours
# Training at Epoch 13 iteration 600 with loss 0.70975. Total time 11.5691 hours
# Training at Epoch 13 iteration 700 with loss 0.86559. Total time 11.5875 hours
# Training at Epoch 13 iteration 800 with loss 0.79870. Total time 11.6058 hours
# Training at Epoch 13 iteration 900 with loss 0.83727. Total time 11.6241 hours
# Training at Epoch 13 iteration 1000 with loss 0.77745. Total time 11.6425 hours
# Training at Epoch 13 iteration 1100 with loss 0.76779. Total time 11.6608 hours
# Training at Epoch 13 iteration 1200 with loss 0.69259. Total time 11.6791 hours
# Training at Epoch 13 iteration 1300 with loss 0.79518. Total time 11.6975 hours
# Training at Epoch 13 iteration 1400 with loss 0.80822. Total time 11.7158 hours
# Training at Epoch 13 iteration 1500 with loss 0.69504. Total time 11.7341 hours
# Training at Epoch 13 iteration 1600 with loss 0.86966. Total time 11.7525 hours
# Training at Epoch 13 iteration 1700 with loss 0.86723. Total time 11.7708 hours
# Training at Epoch 13 iteration 1800 with loss 0.88271. Total time 11.7891 hours
# Training at Epoch 13 iteration 1900 with loss 0.68753. Total time 11.8075 hours
# Training at Epoch 13 iteration 2000 with loss 0.75002. Total time 11.8258 hours
# Training at Epoch 13 iteration 2100 with loss 0.80647. Total time 11.8441 hours
# Training at Epoch 13 iteration 2200 with loss 0.89239. Total time 11.8625 hours
# Training at Epoch 13 iteration 2300 with loss 0.77301. Total time 11.8808 hours
# Training at Epoch 13 iteration 2400 with loss 0.92810. Total time 11.8991 hours
# Training at Epoch 13 iteration 2500 with loss 0.69462. Total time 11.9175 hours
# Training at Epoch 13 iteration 2600 with loss 0.71318. Total time 11.9358 hours
# Training at Epoch 13 iteration 2700 with loss 0.67060. Total time 11.9544 hours
# Training at Epoch 13 iteration 2800 with loss 0.65589. Total time 11.9727 hours
# Training at Epoch 13 iteration 2900 with loss 0.74237. Total time 11.9911 hours
# Training at Epoch 13 iteration 3000 with loss 0.60477. Total time 12.0094 hours
# Training at Epoch 13 iteration 3100 with loss 0.78084. Total time 12.0277 hours
# Training at Epoch 13 iteration 3200 with loss 0.93810. Total time 12.0461 hours
# Training at Epoch 13 iteration 3300 with loss 0.81197. Total time 12.0644 hours
# Training at Epoch 13 iteration 3400 with loss 0.82741. Total time 12.0827 hours
# Training at Epoch 13 iteration 3500 with loss 0.77342. Total time 12.1011 hours
# Training at Epoch 13 iteration 3600 with loss 0.73594. Total time 12.1194 hours
# Training at Epoch 13 iteration 3700 with loss 0.73831. Total time 12.1377 hours
# Training at Epoch 13 iteration 3800 with loss 0.87679. Total time 12.1561 hours
# Training at Epoch 13 iteration 3900 with loss 0.80116. Total time 12.1744 hours
# Training at Epoch 13 iteration 4000 with loss 0.88803. Total time 12.1927 hours
# Training at Epoch 13 iteration 4100 with loss 0.82353. Total time 12.2111 hours
# Training at Epoch 13 iteration 4200 with loss 0.63773. Total time 12.2294 hours
# Training at Epoch 13 iteration 4300 with loss 0.76512. Total time 12.2477 hours
# Validation at Epoch 13 with loss:0.99625, MSE: 0.83664 , Pearson Correlation: 0.78742 with p-value: 0.00E+00 , Concordance Index: 0.79852
# Training at Epoch 14 iteration 0 with loss 0.77273. Total time 12.3591 hours
# Training at Epoch 14 iteration 100 with loss 0.83986. Total time 12.3775 hours
# Training at Epoch 14 iteration 200 with loss 0.68757. Total time 12.3955 hours
# Training at Epoch 14 iteration 300 with loss 0.85366. Total time 12.4138 hours
# Training at Epoch 14 iteration 400 with loss 0.78896. Total time 12.4322 hours
# Training at Epoch 14 iteration 500 with loss 0.72854. Total time 12.4505 hours
# Training at Epoch 14 iteration 600 with loss 0.86708. Total time 12.4688 hours
# Training at Epoch 14 iteration 700 with loss 0.90160. Total time 12.4872 hours
# Training at Epoch 14 iteration 800 with loss 0.82609. Total time 12.5058 hours
# Training at Epoch 14 iteration 900 with loss 0.84028. Total time 12.5241 hours
# Training at Epoch 14 iteration 1000 with loss 0.84767. Total time 12.5425 hours
# Training at Epoch 14 iteration 1100 with loss 0.81408. Total time 12.5608 hours
# ...
# Training at Epoch 46 iteration 3100 with loss 0.69605. Total time 42.2058 hours
# Training at Epoch 46 iteration 3200 with loss 0.73842. Total time 42.2247 hours
# Training at Epoch 46 iteration 3300 with loss 0.68642. Total time 42.2433 hours
# Training at Epoch 46 iteration 3400 with loss 0.70472. Total time 42.2625 hours
# Training at Epoch 46 iteration 3500 with loss 0.60661. Total time 42.2813 hours
# Training at Epoch 46 iteration 3600 with loss 0.74070. Total time 42.3 hours
# Training at Epoch 46 iteration 3700 with loss 0.58337. Total time 42.3183 hours
# Training at Epoch 46 iteration 3800 with loss 0.70897. Total time 42.3366 hours
# Training at Epoch 46 iteration 3900 with loss 0.67109. Total time 42.355 hours
# Training at Epoch 46 iteration 4000 with loss 0.65659. Total time 42.3730 hours
# Training at Epoch 46 iteration 4100 with loss 0.80731. Total time 42.3913 hours
# Training at Epoch 46 iteration 4200 with loss 0.65404. Total time 42.4094 hours
# Training at Epoch 46 iteration 4300 with loss 0.66164. Total time 42.4277 hours
# Validation at Epoch 46 with loss:0.77662, MSE: 0.75356 , Pearson Correlation: 0.81408 with p-value: 0.00E+00 , Concordance Index: 0.81361
# Training at Epoch 47 iteration 0 with loss 0.70690. Total time 42.5425 hours
# Training at Epoch 47 iteration 100 with loss 0.61315. Total time 42.5622 hours
# Training at Epoch 47 iteration 200 with loss 0.64803. Total time 42.5819 hours
# Training at Epoch 47 iteration 300 with loss 0.65923. Total time 42.6013 hours
# Training at Epoch 47 iteration 400 with loss 0.67277. Total time 42.6211 hours
# Training at Epoch 47 iteration 500 with loss 0.74157. Total time 42.6405 hours
# Training at Epoch 47 iteration 600 with loss 0.72402. Total time 42.6602 hours
# Training at Epoch 47 iteration 700 with loss 0.53693. Total time 42.6797 hours
# Training at Epoch 47 iteration 800 with loss 0.61532. Total time 42.6994 hours
# Training at Epoch 47 iteration 900 with loss 0.81023. Total time 42.7186 hours
# Training at Epoch 47 iteration 1000 with loss 0.77132. Total time 42.7375 hours
# Training at Epoch 47 iteration 1100 with loss 0.58523. Total time 42.7569 hours
# Training at Epoch 47 iteration 1200 with loss 0.75071. Total time 42.7761 hours
# Training at Epoch 47 iteration 1300 with loss 0.82463. Total time 42.7955 hours
# Training at Epoch 47 iteration 1400 with loss 0.53721. Total time 42.8147 hours
# Training at Epoch 47 iteration 1500 with loss 0.61179. Total time 42.8338 hours
# Training at Epoch 47 iteration 1600 with loss 0.72450. Total time 42.8530 hours
# Training at Epoch 47 iteration 1700 with loss 0.62118. Total time 42.8722 hours
# Training at Epoch 47 iteration 1800 with loss 0.63426. Total time 42.8913 hours
# Training at Epoch 47 iteration 1900 with loss 0.60651. Total time 42.9105 hours
# Training at Epoch 47 iteration 2000 with loss 0.65219. Total time 42.9294 hours
# Training at Epoch 47 iteration 2100 with loss 0.68331. Total time 42.9480 hours
# Training at Epoch 47 iteration 2200 with loss 0.66965. Total time 42.9666 hours
# Training at Epoch 47 iteration 2300 with loss 0.74401. Total time 42.9852 hours
# Training at Epoch 47 iteration 2400 with loss 0.50556. Total time 43.0041 hours
# Training at Epoch 47 iteration 2500 with loss 0.57135. Total time 43.0227 hours
# Training at Epoch 47 iteration 2600 with loss 0.59780. Total time 43.0413 hours
# Training at Epoch 47 iteration 2700 with loss 0.65318. Total time 43.0602 hours
# Training at Epoch 47 iteration 2800 with loss 0.66442. Total time 43.0788 hours
# Training at Epoch 47 iteration 2900 with loss 0.58381. Total time 43.0975 hours
# Training at Epoch 47 iteration 3000 with loss 0.70628. Total time 43.1163 hours
# Training at Epoch 47 iteration 3100 with loss 0.65137. Total time 43.135 hours
# Training at Epoch 47 iteration 3200 with loss 0.74912. Total time 43.1536 hours
# Training at Epoch 47 iteration 3300 with loss 0.65501. Total time 43.1725 hours
# Training at Epoch 47 iteration 3400 with loss 0.61301. Total time 43.1911 hours
# Training at Epoch 47 iteration 3500 with loss 0.63461. Total time 43.2097 hours
# Training at Epoch 47 iteration 3600 with loss 0.55449. Total time 43.2286 hours
# Training at Epoch 47 iteration 3700 with loss 0.69780. Total time 43.2472 hours
# Training at Epoch 47 iteration 3800 with loss 0.62399. Total time 43.2658 hours
# Training at Epoch 47 iteration 3900 with loss 0.62173. Total time 43.2847 hours
# Training at Epoch 47 iteration 4000 with loss 0.68173. Total time 43.3033 hours
# Training at Epoch 47 iteration 4100 with loss 0.65663. Total time 43.3219 hours
# Training at Epoch 47 iteration 4200 with loss 0.65947. Total time 43.3408 hours
# Training at Epoch 47 iteration 4300 with loss 0.54127. Total time 43.3594 hours
# Validation at Epoch 47 with loss:0.78697, MSE: 0.74773 , Pearson Correlation: 0.81441 with p-value: 0.00E+00 , Concordance Index: 0.81434
# Training at Epoch 48 iteration 0 with loss 0.71143. Total time 43.4744 hours
# Training at Epoch 48 iteration 100 with loss 0.75242. Total time 43.4933 hours
# Training at Epoch 48 iteration 200 with loss 0.66767. Total time 43.5122 hours
# Training at Epoch 48 iteration 300 with loss 0.58365. Total time 43.5308 hours
# Training at Epoch 48 iteration 400 with loss 0.82033. Total time 43.5497 hours
# Training at Epoch 48 iteration 500 with loss 0.57244. Total time 43.5683 hours
# Training at Epoch 48 iteration 600 with loss 0.68088. Total time 43.5869 hours
# Training at Epoch 48 iteration 700 with loss 0.68622. Total time 43.6058 hours
# Training at Epoch 48 iteration 800 with loss 0.71103. Total time 43.6244 hours
# Training at Epoch 48 iteration 900 with loss 0.55823. Total time 43.6433 hours
# Training at Epoch 48 iteration 1000 with loss 0.68874. Total time 43.6619 hours
# Training at Epoch 48 iteration 1100 with loss 0.67890. Total time 43.6808 hours
# Training at Epoch 48 iteration 1200 with loss 0.62803. Total time 43.6994 hours
# Training at Epoch 48 iteration 1300 with loss 0.73703. Total time 43.7180 hours
# Training at Epoch 48 iteration 1400 with loss 0.63393. Total time 43.7369 hours
# Training at Epoch 48 iteration 1500 with loss 0.55387. Total time 43.7555 hours
# Training at Epoch 48 iteration 1600 with loss 0.79529. Total time 43.7744 hours
# Training at Epoch 48 iteration 1700 with loss 0.72206. Total time 43.7941 hours
# Training at Epoch 48 iteration 1800 with loss 0.72741. Total time 43.8136 hours
# Training at Epoch 48 iteration 1900 with loss 0.59640. Total time 43.8330 hours
# Training at Epoch 48 iteration 2000 with loss 0.80197. Total time 43.8522 hours
# Training at Epoch 48 iteration 2100 with loss 0.58477. Total time 43.8716 hours
# Training at Epoch 48 iteration 2200 with loss 0.61397. Total time 43.8905 hours
# Training at Epoch 48 iteration 2300 with loss 0.49401. Total time 43.9097 hours
# Training at Epoch 48 iteration 2400 with loss 0.66493. Total time 43.9286 hours
# Training at Epoch 48 iteration 2500 with loss 0.76425. Total time 43.9475 hours
# Training at Epoch 48 iteration 2600 with loss 0.73627. Total time 43.9663 hours
# Training at Epoch 48 iteration 2700 with loss 0.86002. Total time 43.9855 hours
# Training at Epoch 48 iteration 2800 with loss 0.75521. Total time 44.0047 hours
# Training at Epoch 48 iteration 2900 with loss 0.67159. Total time 44.0236 hours
# Training at Epoch 48 iteration 3000 with loss 0.75661. Total time 44.0427 hours
# Training at Epoch 48 iteration 3100 with loss 0.56792. Total time 44.0622 hours
# Training at Epoch 48 iteration 3200 with loss 0.60379. Total time 44.0816 hours
# Training at Epoch 48 iteration 3300 with loss 0.64833. Total time 44.1008 hours
# Training at Epoch 48 iteration 3400 with loss 0.59715. Total time 44.1202 hours
# Training at Epoch 48 iteration 3500 with loss 0.62001. Total time 44.1388 hours
# Training at Epoch 48 iteration 3600 with loss 0.56687. Total time 44.1575 hours
# Training at Epoch 48 iteration 3700 with loss 0.62262. Total time 44.1758 hours
# Training at Epoch 48 iteration 3800 with loss 0.71449. Total time 44.1944 hours
# Training at Epoch 48 iteration 3900 with loss 0.76391. Total time 44.2130 hours
# Training at Epoch 48 iteration 4000 with loss 0.64053. Total time 44.2313 hours
# Training at Epoch 48 iteration 4100 with loss 0.62262. Total time 44.25 hours
# Training at Epoch 48 iteration 4200 with loss 0.67383. Total time 44.2686 hours
# Training at Epoch 48 iteration 4300 with loss 0.63765. Total time 44.2869 hours
# Validation at Epoch 48 with loss:0.50312, MSE: 0.74644 , Pearson Correlation: 0.81576 with p-value: 0.00E+00 , Concordance Index: 0.81477
# Training at Epoch 49 iteration 0 with loss 0.59495. Total time 44.3994 hours
# Training at Epoch 49 iteration 100 with loss 0.53044. Total time 44.4180 hours
# Training at Epoch 49 iteration 200 with loss 0.74848. Total time 44.4366 hours
# Training at Epoch 49 iteration 300 with loss 0.66333. Total time 44.4561 hours
# Training at Epoch 49 iteration 400 with loss 0.60414. Total time 44.4755 hours
# Training at Epoch 49 iteration 500 with loss 0.66124. Total time 44.4955 hours
# Training at Epoch 49 iteration 600 with loss 0.57284. Total time 44.5152 hours
# Training at Epoch 49 iteration 700 with loss 0.69496. Total time 44.5344 hours
# Training at Epoch 49 iteration 800 with loss 0.61666. Total time 44.5544 hours
# Training at Epoch 49 iteration 900 with loss 0.66521. Total time 44.5741 hours
# Training at Epoch 49 iteration 1000 with loss 0.68788. Total time 44.5930 hours
# Training at Epoch 49 iteration 1100 with loss 0.65165. Total time 44.6122 hours
# Training at Epoch 49 iteration 1200 with loss 0.77825. Total time 44.6311 hours
# Training at Epoch 49 iteration 1300 with loss 0.68566. Total time 44.65 hours
# Training at Epoch 49 iteration 1400 with loss 0.65432. Total time 44.6702 hours
# Training at Epoch 49 iteration 1500 with loss 0.69645. Total time 44.6902 hours
# Training at Epoch 49 iteration 1600 with loss 0.65223. Total time 44.7097 hours
# Training at Epoch 49 iteration 1700 with loss 0.72883. Total time 44.7286 hours
# Training at Epoch 49 iteration 1800 with loss 0.64815. Total time 44.7475 hours
# Training at Epoch 49 iteration 1900 with loss 0.63596. Total time 44.7661 hours
# Training at Epoch 49 iteration 2000 with loss 0.71227. Total time 44.7847 hours
# Training at Epoch 49 iteration 2100 with loss 0.61149. Total time 44.8033 hours
# Training at Epoch 49 iteration 2200 with loss 0.59476. Total time 44.8216 hours
# Training at Epoch 49 iteration 2300 with loss 0.64994. Total time 44.84 hours
# Training at Epoch 49 iteration 2400 with loss 0.58802. Total time 44.8583 hours
# Training at Epoch 49 iteration 2500 with loss 0.62944. Total time 44.8766 hours
# Training at Epoch 49 iteration 2600 with loss 0.64988. Total time 44.8952 hours
# Training at Epoch 49 iteration 2700 with loss 0.68112. Total time 44.9138 hours
# Training at Epoch 49 iteration 2800 with loss 0.72868. Total time 44.9325 hours
# Training at Epoch 49 iteration 2900 with loss 0.73406. Total time 44.9511 hours
# Training at Epoch 49 iteration 3000 with loss 0.59220. Total time 44.9697 hours
# Training at Epoch 49 iteration 3100 with loss 0.72764. Total time 44.9880 hours
# Training at Epoch 49 iteration 3200 with loss 0.79767. Total time 45.0063 hours
# Training at Epoch 49 iteration 3300 with loss 0.73745. Total time 45.0247 hours
# Training at Epoch 49 iteration 3400 with loss 0.57319. Total time 45.0433 hours
# Training at Epoch 49 iteration 3500 with loss 0.76274. Total time 45.0619 hours
# Training at Epoch 49 iteration 3600 with loss 0.65834. Total time 45.0802 hours
# Training at Epoch 49 iteration 3700 with loss 0.56998. Total time 45.0986 hours
# Training at Epoch 49 iteration 3800 with loss 0.60855. Total time 45.1172 hours
# Training at Epoch 49 iteration 3900 with loss 0.87375. Total time 45.1355 hours
# Training at Epoch 49 iteration 4000 with loss 0.65781. Total time 45.1541 hours
# Training at Epoch 49 iteration 4100 with loss 0.74380. Total time 45.1727 hours
# Training at Epoch 49 iteration 4200 with loss 0.63323. Total time 45.1911 hours
# Training at Epoch 49 iteration 4300 with loss 0.72436. Total time 45.2097 hours
# Validation at Epoch 49 with loss:0.88762, MSE: 0.75327 , Pearson Correlation: 0.81511 with p-value: 0.00E+00 , Concordance Index: 0.81441
# Training at Epoch 50 iteration 0 with loss 0.66041. Total time 45.3247 hours
# Training at Epoch 50 iteration 100 with loss 0.67309. Total time 45.3433 hours
# Training at Epoch 50 iteration 200 with loss 0.67264. Total time 45.3619 hours
# Training at Epoch 50 iteration 300 with loss 0.55051. Total time 45.3802 hours
# Training at Epoch 50 iteration 400 with loss 0.64037. Total time 45.3986 hours
# Training at Epoch 50 iteration 500 with loss 0.70010. Total time 45.4169 hours
# Training at Epoch 50 iteration 600 with loss 0.69000. Total time 45.4355 hours
# Training at Epoch 50 iteration 700 with loss 0.62366. Total time 45.4541 hours
# Training at Epoch 50 iteration 800 with loss 0.57277. Total time 45.4725 hours
# Training at Epoch 50 iteration 900 with loss 0.62726. Total time 45.4911 hours
# Training at Epoch 50 iteration 1000 with loss 0.61612. Total time 45.5094 hours
# Training at Epoch 50 iteration 1100 with loss 0.67883. Total time 45.5277 hours
# Training at Epoch 50 iteration 1200 with loss 0.63368. Total time 45.5463 hours
# Training at Epoch 50 iteration 1300 with loss 0.64492. Total time 45.565 hours
# Training at Epoch 50 iteration 1400 with loss 0.60487. Total time 45.5836 hours
# Training at Epoch 50 iteration 1500 with loss 0.61492. Total time 45.6019 hours
# Training at Epoch 50 iteration 1600 with loss 0.58303. Total time 45.6216 hours
# Training at Epoch 50 iteration 1700 with loss 0.66081. Total time 45.6408 hours
# Training at Epoch 50 iteration 1800 with loss 0.57431. Total time 45.6597 hours
# Training at Epoch 50 iteration 1900 with loss 0.75646. Total time 45.6791 hours
# Training at Epoch 50 iteration 2000 with loss 0.65444. Total time 45.6983 hours
# Training at Epoch 50 iteration 2100 with loss 0.67566. Total time 45.7175 hours
# Training at Epoch 50 iteration 2200 with loss 0.57553. Total time 45.7363 hours
# Training at Epoch 50 iteration 2300 with loss 0.63545. Total time 45.755 hours
# Training at Epoch 50 iteration 2400 with loss 0.65408. Total time 45.7736 hours
# Training at Epoch 50 iteration 2500 with loss 0.88218. Total time 45.7922 hours
# Training at Epoch 50 iteration 2600 with loss 0.67241. Total time 45.8108 hours
# Training at Epoch 50 iteration 2700 with loss 0.60989. Total time 45.8294 hours
# Training at Epoch 50 iteration 2800 with loss 0.59243. Total time 45.8480 hours
# Training at Epoch 50 iteration 2900 with loss 0.70575. Total time 45.8666 hours
# Training at Epoch 50 iteration 3000 with loss 0.65915. Total time 45.8852 hours
# Training at Epoch 50 iteration 3100 with loss 0.99613. Total time 45.9038 hours
# Training at Epoch 50 iteration 3200 with loss 1.20024. Total time 45.9225 hours
# Training at Epoch 50 iteration 3300 with loss 0.66057. Total time 45.9408 hours
# Training at Epoch 50 iteration 3400 with loss 0.52849. Total time 45.9594 hours
# Training at Epoch 50 iteration 3500 with loss 0.74643. Total time 45.9777 hours
# Training at Epoch 50 iteration 3600 with loss 0.53769. Total time 45.9961 hours
# Training at Epoch 50 iteration 3700 with loss 0.53981. Total time 46.0147 hours
# Training at Epoch 50 iteration 3800 with loss 0.70807. Total time 46.0336 hours
# Training at Epoch 50 iteration 3900 with loss 0.67145. Total time 46.0572 hours
# Training at Epoch 50 iteration 4000 with loss 0.71621. Total time 46.0825 hours
# Training at Epoch 50 iteration 4100 with loss 0.54096. Total time 46.1080 hours
# Training at Epoch 50 iteration 4200 with loss 0.67526. Total time 46.1333 hours
# Training at Epoch 50 iteration 4300 with loss 0.69396. Total time 46.1586 hours
# Validation at Epoch 50 with loss:0.68108, MSE: 0.74801 , Pearson Correlation: 0.81253 with p-value: 0.00E+00 , Concordance Index: 0.81307
# --- Go for Testing ---
# Testing MSE: 0.7363067276210117 , Pearson Correlation: 0.8170898057099689 with p-value: 0.00E+00 , Concordance Index: 0.8150875297923895
# --- Training Finished ---

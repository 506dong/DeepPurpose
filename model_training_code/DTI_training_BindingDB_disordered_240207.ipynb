# %%
import os
os.chdir('../')
os.getcwd()
# Out:
# 'c:\\Users\\user\\Desktop\\DTI\\DeepPurpose-1'

# %%
from DeepPurpose import utils, dataset
from DeepPurpose import DTI as models
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np

# %%
#### process_BindingDB ####

# Parameter
path = '../Database/BindingDB/BindingDB_edit_ver2_240125.tsv'
df = None
y = 'IC50'
binary = False
convert_to_log = True
threshold = 30
return_ids = False
ids_condition = 'OR'
harmonize_affinities = None

# loading df (bindingDB)
df = pd.read_csv(path, sep = '\t')

print('Beginning Processing...')
df = df[df['Number of Protein Chains in Target (>1 implies a multichain complex)'] == 1.0]
df = df[df['Ligand SMILES'].notnull()]

idx_str = []
yy = y
if isinstance(y, str):
	yy = [y]
for y in yy:
	if y == 'Kd':
		idx_str.append('Kd (nM)')
	elif y == 'IC50':
		idx_str.append('IC50 (nM)')
	elif y == 'Ki':
		idx_str.append('Ki (nM)')
	elif y == 'EC50':
		idx_str.append('EC50 (nM)')
	else:
		print('select Kd, Ki, IC50 or EC50')

if len(idx_str)==1:
	df_want = df[df[idx_str[0]].notnull()]
else: # select multiple affinity measurements.                 
	# keep rows for which at least one of the columns in the idx_str list is not null
	df_want = df.dropna(thresh=1, subset=idx_str) 
	
df_want = df_want[['BindingDB Reactant_set_id', 'Ligand InChI', 'Ligand SMILES',\
				'PubChem CID', 'UniProt (SwissProt) Primary ID of Target Chain',\
				'modified_disordered'] + idx_str] # BindingDB Target Chain Sequence

for y in idx_str:
	df_want[y] = df_want[y].str.replace('>', '')
	df_want[y] = df_want[y].str.replace('<', '')
	df_want[y] = df_want[y].astype(float)

# Harmonize into single label using the mean of existing labels:
df_want['Label'] = df_want[idx_str].mean(axis=1, skipna=True)

df_want.rename(columns={'BindingDB Reactant_set_id':'ID',
						'Ligand SMILES':'SMILES',
						'Ligand InChI':'InChI',
						'PubChem CID':'PubChem_ID',
						'UniProt (SwissProt) Primary ID of Target Chain':'UniProt_ID',
						'modified_disordered': 'Target Sequence'}, # BindingDB Target Chain Sequence
						inplace=True)

# have at least uniprot or pubchem ID
if ids_condition == 'OR':
	df_want = df_want[df_want.PubChem_ID.notnull() | df_want.UniProt_ID.notnull()]
elif ids_condition == 'AND':
	df_want = df_want[df_want.PubChem_ID.notnull() & df_want.UniProt_ID.notnull()]
else:
	ValueError("ids_condition must be set to 'OR' or 'AND'")

df_want = df_want[df_want.InChI.notnull()]

df_want = df_want[df_want.Label <= 10000000.0]
print('There are ' + str(len(df_want)) + ' drug target pairs.')

if harmonize_affinities is not None:
	df_want = df_want[['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence', 'Label']]
	if harmonize_affinities.lower() == 'max_affinity':
		df_want = df_want.groupby(['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence']).Label.agg(min).reset_index()
	if harmonize_affinities.lower() == 'mean':
		df_want = df_want.groupby(['PubChem_ID', 'SMILES', 'UniProt_ID', 'Target Sequence']).Label.agg(np.mean).reset_index()

if binary:
	print('Default binary threshold for the binding affinity scores are 30, you can adjust it by using the "threshold" parameter')
	if isinstance(threshold, Sequence):
		# filter samples with affinity values between the thresholds
		df_want = df_want[(df_want.Label < threshold[0]) | (df_want.Label > threshold[1])]
	else: # single threshold
		threshold = [threshold]
	y = [1 if i else 0 for i in df_want.Label.values < threshold[0]]
else:
	if convert_to_log:
		print('Default set to logspace (nM -> p) for easier regression')
		y = utils.convert_y_unit(df_want.Label.values, 'nM', 'p')
	else:
		y = df_want.Label.values
	
if return_ids:
	X_drug, X_target, y, ID_drug, ID_target = df_want.SMILES.values, df_want['Target Sequence'].values, np.array(y), df_want['PubChem_ID'].values, df_want['UniProt_ID'].values
X_drug, X_target, y = df_want.SMILES.values, df_want['Target Sequence'].values, np.array(y)
# Out:
# Beginning Processing...
# There are 1592671 drug target pairs.
# Default set to logspace (nM -> p) for easier regression

# %%
#### select endcoder ####
drug_encoding, target_encoding = 'CNN', 'CNN'

# %%
#### data_process ####

# parameter
split_method = 'random'
frac = [0.7, 0.1, 0.2]
random_seed = 1
sample_frac = 1
mode = 'DTI'
X_drug_ = None
X_target_ = None

# data_process : dataframe

if random_seed == 'TDC':
	random_seed = 1234
 
#property_prediction_flag = X_target is None
property_prediction_flag, function_prediction_flag, DDI_flag, PPI_flag, DTI_flag = False, False, False, False, False

if (X_drug is not None) and (X_target is not None):
	DTI_flag = True
	if (X_drug is None) or (X_target is None):
		raise AttributeError("Target pair sequence should be in X_target, X_drug")
else:
	raise AttributeError("Please use the correct mode. Currently, we support DTI, DDI, PPI, Drug Property Prediction and Protein Function Prediction...")

if split_method == 'repurposing_VS':
	y = [-1]*len(X_drug) # create temp y for compatitibility

if DTI_flag:
	print('Drug Target Interaction Prediction Mode...')
	if isinstance(X_target, str):
		X_target = [X_target]
	if len(X_target) == 1:
		# one target high throughput screening setting
		X_target = np.tile(X_target, (length_func(X_drug), ))

	df_data = pd.DataFrame(zip(X_drug, X_target, y))
	df_data.rename(columns={0:'SMILES',
							1: 'Target Sequence',
							2: 'Label'}, 
							inplace=True)
	print('in total: ' + str(len(df_data)) + ' drug-target pairs')
 
# data_process : endcoding & splitting

if sample_frac != 1:
	df_data = df_data.sample(frac = sample_frac) #.reset_index(drop = True)
	print('after subsample: ' + str(len(df_data)) + ' data points...') 

if DTI_flag:
	df_data = utils.encode_drug(df_data, drug_encoding)
	df_data = utils.encode_protein(df_data, target_encoding)
# Out:
# Drug Target Interaction Prediction Mode...
# in total: 1592671 drug-target pairs
# encoding drug...
# unique drugs: 770912
# encoding protein...
# unique target sequence: 5055

# %%
# after pre-processing set 불러오기
after_train = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_train.tsv', sep='\t', index_col=0)
after_val = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_val.tsv', sep='\t', index_col=0)
after_test = pd.read_csv('C:\\Users\\user\\Desktop\\DTI\\Database\\BindingDB\\BindingDB_index_test.tsv', sep='\t', index_col=0)

# %%
after_val['index_val'].values
# Out:
# array([ 520137,    5876,  773576, ...,  253865, 1014785,  758771],
#       dtype=int64)

# %%
# 같은 index를 가지게 split / index 초기화
train = df_data.loc[after_train['index_train'].values, :]
val = df_data.loc[after_val['index_val'].values, :]
test = df_data.loc[after_test['index_test'].values, :]
train, val, test = train.reset_index(drop=True), val.reset_index(drop=True), test.reset_index(drop=True)

# %%
# Model configuration genreration
config = utils.generate_config(drug_encoding = drug_encoding, 
                         target_encoding = target_encoding, 
                         cls_hidden_dims = [1024,1024,512], 
                         train_epoch = 50, 
                         test_every_X_epoch = 10, 
                         LR = 0.001, 
                         batch_size = 256,
                         hidden_dim_drug = 128,
                         cnn_drug_filters = [32,64,96],
                         cnn_drug_kernels = [4,6,8],
                         cnn_target_filters = [32,64,96],
                         cnn_target_kernels = [4,8,12]
                        )

# %%
# Model initialization
model = models.model_initialize(**config)
model

# %%
# Model training
model.train(train, val, test)

# Model saving
model.save_model('./pretrained_model/CNN_CNN_BindingDB_IC50_disordered/')
# Out:
# Let's use 1 GPU!
# --- Data Preparation ---
# --- Go for Training ---
# Training at Epoch 1 iteration 0 with loss 41.8660. Total time 0.00138 hours
# Training at Epoch 1 iteration 100 with loss 2.08208. Total time 0.02472 hours
# Training at Epoch 1 iteration 200 with loss 2.36703. Total time 0.04777 hours
# Training at Epoch 1 iteration 300 with loss 2.00739. Total time 0.07083 hours
# Training at Epoch 1 iteration 400 with loss 1.72471. Total time 0.09388 hours
# Training at Epoch 1 iteration 500 with loss 1.62938. Total time 0.11694 hours
# Training at Epoch 1 iteration 600 with loss 1.62440. Total time 0.14 hours
# Training at Epoch 1 iteration 700 with loss 1.54067. Total time 0.16333 hours
# Training at Epoch 1 iteration 800 with loss 1.68368. Total time 0.18638 hours
# Training at Epoch 1 iteration 900 with loss 1.43215. Total time 0.20944 hours
# Training at Epoch 1 iteration 1000 with loss 1.49578. Total time 0.23222 hours
# Training at Epoch 1 iteration 1100 with loss 1.61263. Total time 0.255 hours
# Training at Epoch 1 iteration 1200 with loss 1.34576. Total time 0.27777 hours
# Training at Epoch 1 iteration 1300 with loss 1.53680. Total time 0.30027 hours
# Training at Epoch 1 iteration 1400 with loss 1.69422. Total time 0.32305 hours
# Training at Epoch 1 iteration 1500 with loss 1.69180. Total time 0.34583 hours
# Training at Epoch 1 iteration 1600 with loss 1.38478. Total time 0.36833 hours
# Training at Epoch 1 iteration 1700 with loss 1.28503. Total time 0.39083 hours
# Training at Epoch 1 iteration 1800 with loss 1.35108. Total time 0.41361 hours
# Training at Epoch 1 iteration 1900 with loss 1.54719. Total time 0.43611 hours
# Training at Epoch 1 iteration 2000 with loss 1.27914. Total time 0.45916 hours
# Training at Epoch 1 iteration 2100 with loss 1.45640. Total time 0.48222 hours
# Training at Epoch 1 iteration 2200 with loss 1.54934. Total time 0.50527 hours
# Training at Epoch 1 iteration 2300 with loss 1.44596. Total time 0.52861 hours
# Training at Epoch 1 iteration 2400 with loss 1.37630. Total time 0.55138 hours
# Training at Epoch 1 iteration 2500 with loss 1.33579. Total time 0.57444 hours
# Training at Epoch 1 iteration 2600 with loss 1.36558. Total time 0.5975 hours
# Training at Epoch 1 iteration 2700 with loss 1.22777. Total time 0.62055 hours
# Training at Epoch 1 iteration 2800 with loss 1.25912. Total time 0.64333 hours
# Training at Epoch 1 iteration 2900 with loss 1.24257. Total time 0.66638 hours
# Training at Epoch 1 iteration 3000 with loss 1.82361. Total time 0.68888 hours
# Training at Epoch 1 iteration 3100 with loss 1.22686. Total time 0.70916 hours
# Training at Epoch 1 iteration 3200 with loss 1.26200. Total time 0.72805 hours
# Training at Epoch 1 iteration 3300 with loss 1.36199. Total time 0.74694 hours
# Training at Epoch 1 iteration 3400 with loss 1.42189. Total time 0.76555 hours
# Training at Epoch 1 iteration 3500 with loss 1.16860. Total time 0.78444 hours
# Training at Epoch 1 iteration 3600 with loss 1.33238. Total time 0.80305 hours
# Training at Epoch 1 iteration 3700 with loss 1.22237. Total time 0.82194 hours
# Training at Epoch 1 iteration 3800 with loss 1.14957. Total time 0.84083 hours
# Training at Epoch 1 iteration 3900 with loss 1.20036. Total time 0.85972 hours
# Training at Epoch 1 iteration 4000 with loss 1.38775. Total time 0.87888 hours
# Training at Epoch 1 iteration 4100 with loss 1.07718. Total time 0.89777 hours
# Training at Epoch 1 iteration 4200 with loss 1.11884. Total time 0.91666 hours
# Training at Epoch 1 iteration 4300 with loss 1.44422. Total time 0.93555 hours
# Validation at Epoch 1 with loss:0.65480, MSE: 1.20765 , Pearson Correlation: 0.67373 with p-value: 0.00E+00 , Concordance Index: 0.74255
# Training at Epoch 2 iteration 0 with loss 1.27283. Total time 1.04861 hours
# Training at Epoch 2 iteration 100 with loss 1.15096. Total time 1.0675 hours
# Training at Epoch 2 iteration 200 with loss 1.25604. Total time 1.08638 hours
# Training at Epoch 2 iteration 300 with loss 1.35974. Total time 1.105 hours
# Training at Epoch 2 iteration 400 with loss 1.23934. Total time 1.12388 hours
# Training at Epoch 2 iteration 500 with loss 1.71502. Total time 1.1425 hours
# Training at Epoch 2 iteration 600 with loss 1.29209. Total time 1.16138 hours
# Training at Epoch 2 iteration 700 with loss 1.35737. Total time 1.18027 hours
# Training at Epoch 2 iteration 800 with loss 1.21352. Total time 1.19888 hours
# Training at Epoch 2 iteration 900 with loss 1.08522. Total time 1.21777 hours
# Training at Epoch 2 iteration 1000 with loss 0.98915. Total time 1.23638 hours
# Training at Epoch 2 iteration 1100 with loss 1.33711. Total time 1.25527 hours
# Training at Epoch 2 iteration 1200 with loss 1.16456. Total time 1.27416 hours
# Training at Epoch 2 iteration 1300 with loss 1.14300. Total time 1.29277 hours
# Training at Epoch 2 iteration 1400 with loss 1.37882. Total time 1.31138 hours
# Training at Epoch 2 iteration 1500 with loss 1.01785. Total time 1.33 hours
# Training at Epoch 2 iteration 1600 with loss 2.02783. Total time 1.34861 hours
# Training at Epoch 2 iteration 1700 with loss 1.27227. Total time 1.36722 hours
# Training at Epoch 2 iteration 1800 with loss 1.07023. Total time 1.38583 hours
# Training at Epoch 2 iteration 1900 with loss 1.30219. Total time 1.40416 hours
# Training at Epoch 2 iteration 2000 with loss 1.14897. Total time 1.42277 hours
# Training at Epoch 2 iteration 2100 with loss 1.33727. Total time 1.44138 hours
# Training at Epoch 2 iteration 2200 with loss 1.19691. Total time 1.46 hours
# Training at Epoch 2 iteration 2300 with loss 0.94842. Total time 1.47861 hours
# Training at Epoch 2 iteration 2400 with loss 1.17306. Total time 1.49722 hours
# Training at Epoch 2 iteration 2500 with loss 0.97199. Total time 1.51583 hours
# Training at Epoch 2 iteration 2600 with loss 1.11509. Total time 1.53444 hours
# Training at Epoch 2 iteration 2700 with loss 0.89337. Total time 1.55277 hours
# Training at Epoch 2 iteration 2800 with loss 1.23065. Total time 1.57138 hours
# Training at Epoch 2 iteration 2900 with loss 1.15223. Total time 1.59 hours
# Training at Epoch 2 iteration 3000 with loss 1.26047. Total time 1.60861 hours
# Training at Epoch 2 iteration 3100 with loss 1.31198. Total time 1.62722 hours
# Training at Epoch 2 iteration 3200 with loss 1.25904. Total time 1.64583 hours
# Training at Epoch 2 iteration 3300 with loss 1.01134. Total time 1.66444 hours
# Training at Epoch 2 iteration 3400 with loss 1.34611. Total time 1.68277 hours
# Training at Epoch 2 iteration 3500 with loss 0.98235. Total time 1.70138 hours
# Training at Epoch 2 iteration 3600 with loss 1.34134. Total time 1.72 hours
# Training at Epoch 2 iteration 3700 with loss 1.13688. Total time 1.73861 hours
# Training at Epoch 2 iteration 3800 with loss 1.11104. Total time 1.75722 hours
# Training at Epoch 2 iteration 3900 with loss 1.08194. Total time 1.77583 hours
# Training at Epoch 2 iteration 4000 with loss 1.06638. Total time 1.79444 hours
# Training at Epoch 2 iteration 4100 with loss 1.10615. Total time 1.81305 hours
# Training at Epoch 2 iteration 4200 with loss 1.05904. Total time 1.83138 hours
# Training at Epoch 2 iteration 4300 with loss 0.95592. Total time 1.85 hours
# Validation at Epoch 2 with loss:1.63775, MSE: 1.10727 , Pearson Correlation: 0.70957 with p-value: 0.00E+00 , Concordance Index: 0.75958
# Training at Epoch 3 iteration 0 with loss 1.15232. Total time 1.96333 hours
# Training at Epoch 3 iteration 100 with loss 1.00431. Total time 1.98194 hours
# Training at Epoch 3 iteration 200 with loss 1.04869. Total time 2.00027 hours
# Training at Epoch 3 iteration 300 with loss 0.97050. Total time 2.01861 hours
# Training at Epoch 3 iteration 400 with loss 1.02048. Total time 2.03722 hours
# Training at Epoch 3 iteration 500 with loss 1.00150. Total time 2.05583 hours
# Training at Epoch 3 iteration 600 with loss 1.08122. Total time 2.07444 hours
# Training at Epoch 3 iteration 700 with loss 1.02498. Total time 2.09305 hours
# Training at Epoch 3 iteration 800 with loss 0.96704. Total time 2.11166 hours
# Training at Epoch 3 iteration 900 with loss 1.21173. Total time 2.13027 hours
# Training at Epoch 3 iteration 1000 with loss 1.13006. Total time 2.14888 hours
# Training at Epoch 3 iteration 1100 with loss 1.01201. Total time 2.1675 hours
# Training at Epoch 3 iteration 1200 with loss 0.99692. Total time 2.18611 hours
# Training at Epoch 3 iteration 1300 with loss 1.12124. Total time 2.20472 hours
# Training at Epoch 3 iteration 1400 with loss 1.10073. Total time 2.22333 hours
# Training at Epoch 3 iteration 1500 with loss 1.12312. Total time 2.24194 hours
# Training at Epoch 3 iteration 1600 with loss 1.16865. Total time 2.26055 hours
# Training at Epoch 3 iteration 1700 with loss 1.06949. Total time 2.27888 hours
# Training at Epoch 3 iteration 1800 with loss 1.14828. Total time 2.2975 hours
# Training at Epoch 3 iteration 1900 with loss 1.14005. Total time 2.31611 hours
# Training at Epoch 3 iteration 2000 with loss 1.02629. Total time 2.33472 hours
# Training at Epoch 3 iteration 2100 with loss 1.02560. Total time 2.35333 hours
# Training at Epoch 3 iteration 2200 with loss 1.02786. Total time 2.37194 hours
# Training at Epoch 3 iteration 2300 with loss 1.07602. Total time 2.39055 hours
# Training at Epoch 3 iteration 2400 with loss 1.47564. Total time 2.40916 hours
# Training at Epoch 3 iteration 2500 with loss 1.07274. Total time 2.42805 hours
# Training at Epoch 3 iteration 2600 with loss 1.03283. Total time 2.44666 hours
# Training at Epoch 3 iteration 2700 with loss 1.05997. Total time 2.46555 hours
# Training at Epoch 3 iteration 2800 with loss 1.05032. Total time 2.48444 hours
# Training at Epoch 3 iteration 2900 with loss 1.11597. Total time 2.50361 hours
# Training at Epoch 3 iteration 3000 with loss 0.96285. Total time 2.5225 hours
# Training at Epoch 3 iteration 3100 with loss 1.26963. Total time 2.54138 hours
# Training at Epoch 3 iteration 3200 with loss 0.89343. Total time 2.56027 hours
# Training at Epoch 3 iteration 3300 with loss 1.13239. Total time 2.57888 hours
# Training at Epoch 3 iteration 3400 with loss 1.11667. Total time 2.59777 hours
# Training at Epoch 3 iteration 3500 with loss 1.21844. Total time 2.61638 hours
# Training at Epoch 3 iteration 3600 with loss 1.24374. Total time 2.63527 hours
# Training at Epoch 3 iteration 3700 with loss 1.07731. Total time 2.65416 hours
# Training at Epoch 3 iteration 3800 with loss 0.95455. Total time 2.67277 hours
# Training at Epoch 3 iteration 3900 with loss 1.22888. Total time 2.69166 hours
# Training at Epoch 3 iteration 4000 with loss 0.96890. Total time 2.71055 hours
# Training at Epoch 3 iteration 4100 with loss 0.88401. Total time 2.72916 hours
# Training at Epoch 3 iteration 4200 with loss 1.13052. Total time 2.74805 hours
# Training at Epoch 3 iteration 4300 with loss 0.94058. Total time 2.76666 hours
# Validation at Epoch 3 with loss:1.30945, MSE: 1.03355 , Pearson Correlation: 0.72984 with p-value: 0.00E+00 , Concordance Index: 0.76926
# Training at Epoch 4 iteration 0 with loss 0.97743. Total time 2.88 hours
# Training at Epoch 4 iteration 100 with loss 0.81507. Total time 2.89888 hours
# Training at Epoch 4 iteration 200 with loss 1.28145. Total time 2.9175 hours
# Training at Epoch 4 iteration 300 with loss 1.19121. Total time 2.93611 hours
# Training at Epoch 4 iteration 400 with loss 0.99782. Total time 2.955 hours
# Training at Epoch 4 iteration 500 with loss 1.65572. Total time 2.97361 hours
# Training at Epoch 4 iteration 600 with loss 0.94305. Total time 2.99277 hours
# Training at Epoch 4 iteration 700 with loss 0.98019. Total time 3.01138 hours
# Training at Epoch 4 iteration 800 with loss 0.91710. Total time 3.03 hours
# Training at Epoch 4 iteration 900 with loss 1.16314. Total time 3.04888 hours
# Training at Epoch 4 iteration 1000 with loss 1.17152. Total time 3.0675 hours
# Training at Epoch 4 iteration 1100 with loss 0.92659. Total time 3.08611 hours
# Training at Epoch 4 iteration 1200 with loss 1.02205. Total time 3.10472 hours
# Training at Epoch 4 iteration 1300 with loss 0.93060. Total time 3.12333 hours
# Training at Epoch 4 iteration 1400 with loss 0.89492. Total time 3.14194 hours
# Training at Epoch 4 iteration 1500 with loss 1.10105. Total time 3.16055 hours
# Training at Epoch 4 iteration 1600 with loss 0.89517. Total time 3.17916 hours
# Training at Epoch 4 iteration 1700 with loss 1.07749. Total time 3.19777 hours
# Training at Epoch 4 iteration 1800 with loss 0.88237. Total time 3.21638 hours
# Training at Epoch 4 iteration 1900 with loss 1.06733. Total time 3.235 hours
# Training at Epoch 4 iteration 2000 with loss 0.97043. Total time 3.25361 hours
# Training at Epoch 4 iteration 2100 with loss 0.98188. Total time 3.27222 hours
# Training at Epoch 4 iteration 2200 with loss 1.00866. Total time 3.29111 hours
# Training at Epoch 4 iteration 2300 with loss 0.86272. Total time 3.31 hours
# Training at Epoch 4 iteration 2400 with loss 1.01898. Total time 3.32861 hours
# Training at Epoch 4 iteration 2500 with loss 0.91924. Total time 3.34888 hours
# Training at Epoch 4 iteration 2600 with loss 0.86158. Total time 3.3725 hours
# Training at Epoch 4 iteration 2700 with loss 0.99414. Total time 3.39611 hours
# Training at Epoch 4 iteration 2800 with loss 0.98740. Total time 3.41972 hours
# Training at Epoch 4 iteration 2900 with loss 0.87986. Total time 3.44305 hours
# Training at Epoch 4 iteration 3000 with loss 1.01139. Total time 3.46638 hours
# Training at Epoch 4 iteration 3100 with loss 1.00304. Total time 3.49083 hours
# Training at Epoch 4 iteration 3200 with loss 1.08161. Total time 3.51555 hours
# Training at Epoch 4 iteration 3300 with loss 1.12703. Total time 3.54055 hours
# Training at Epoch 4 iteration 3400 with loss 0.97486. Total time 3.565 hours
# Training at Epoch 4 iteration 3500 with loss 1.03072. Total time 3.58916 hours
# Training at Epoch 4 iteration 3600 with loss 0.92348. Total time 3.61361 hours
# Training at Epoch 4 iteration 3700 with loss 0.92875. Total time 3.63777 hours
# Training at Epoch 4 iteration 3800 with loss 1.00911. Total time 3.66194 hours
# Training at Epoch 4 iteration 3900 with loss 0.93258. Total time 3.68611 hours
# Training at Epoch 4 iteration 4000 with loss 1.17342. Total time 3.71027 hours
# Training at Epoch 4 iteration 4100 with loss 1.10489. Total time 3.73416 hours
# Training at Epoch 4 iteration 4200 with loss 1.01248. Total time 3.7575 hours
# Training at Epoch 4 iteration 4300 with loss 1.16879. Total time 3.78083 hours
# Validation at Epoch 4 with loss:0.94378, MSE: 0.98798 , Pearson Correlation: 0.74313 with p-value: 0.00E+00 , Concordance Index: 0.77498
# Training at Epoch 5 iteration 0 with loss 0.82049. Total time 3.91083 hours
# Training at Epoch 5 iteration 100 with loss 0.94343. Total time 3.935 hours
# Training at Epoch 5 iteration 200 with loss 0.85819. Total time 3.95916 hours
# Training at Epoch 5 iteration 300 with loss 0.87382. Total time 3.98333 hours
# Training at Epoch 5 iteration 400 with loss 1.04220. Total time 4.0075 hours
# Training at Epoch 5 iteration 500 with loss 0.94700. Total time 4.03166 hours
# Training at Epoch 5 iteration 600 with loss 1.04608. Total time 4.05555 hours
# Training at Epoch 5 iteration 700 with loss 1.05525. Total time 4.07916 hours
# Training at Epoch 5 iteration 800 with loss 1.10300. Total time 4.1025 hours
# Training at Epoch 5 iteration 900 with loss 1.05480. Total time 4.12583 hours
# Training at Epoch 5 iteration 1000 with loss 1.15572. Total time 4.14916 hours
# Training at Epoch 5 iteration 1100 with loss 0.83450. Total time 4.1725 hours
# Training at Epoch 5 iteration 1200 with loss 1.10241. Total time 4.19583 hours
# Training at Epoch 5 iteration 1300 with loss 0.94589. Total time 4.21916 hours
# Training at Epoch 5 iteration 1400 with loss 0.97875. Total time 4.2425 hours
# Training at Epoch 5 iteration 1500 with loss 1.18031. Total time 4.26583 hours
# Training at Epoch 5 iteration 1600 with loss 0.98855. Total time 4.28888 hours
# Training at Epoch 5 iteration 1700 with loss 1.26029. Total time 4.31222 hours
# Training at Epoch 5 iteration 1800 with loss 1.00873. Total time 4.33555 hours
# Training at Epoch 5 iteration 1900 with loss 1.59761. Total time 4.35861 hours
# Training at Epoch 5 iteration 2000 with loss 0.96233. Total time 4.38138 hours
# Training at Epoch 5 iteration 2100 with loss 1.21661. Total time 4.40194 hours
# Training at Epoch 5 iteration 2200 with loss 1.08724. Total time 4.42083 hours
# Training at Epoch 5 iteration 2300 with loss 0.99693. Total time 4.43972 hours
# Training at Epoch 5 iteration 2400 with loss 0.95588. Total time 4.45861 hours
# Training at Epoch 5 iteration 2500 with loss 1.05572. Total time 4.47777 hours
# Training at Epoch 5 iteration 2600 with loss 1.00630. Total time 4.49666 hours
# Training at Epoch 5 iteration 2700 with loss 1.14237. Total time 4.51583 hours
# Training at Epoch 5 iteration 2800 with loss 0.99708. Total time 4.53444 hours
# Training at Epoch 5 iteration 2900 with loss 0.84525. Total time 4.55333 hours
# Training at Epoch 5 iteration 3000 with loss 0.86166. Total time 4.57222 hours
# Training at Epoch 5 iteration 3100 with loss 0.95563. Total time 4.59083 hours
# Training at Epoch 5 iteration 3200 with loss 0.78353. Total time 4.60972 hours
# Training at Epoch 5 iteration 3300 with loss 0.91380. Total time 4.62833 hours
# Training at Epoch 5 iteration 3400 with loss 0.90002. Total time 4.64722 hours
# Training at Epoch 5 iteration 3500 with loss 1.03977. Total time 4.66611 hours
# Training at Epoch 5 iteration 3600 with loss 0.89374. Total time 4.685 hours
# Training at Epoch 5 iteration 3700 with loss 1.13678. Total time 4.70416 hours
# Training at Epoch 5 iteration 3800 with loss 1.07020. Total time 4.72305 hours
# Training at Epoch 5 iteration 3900 with loss 1.01251. Total time 4.74194 hours
# Training at Epoch 5 iteration 4000 with loss 0.82699. Total time 4.76055 hours
# Training at Epoch 5 iteration 4100 with loss 0.95076. Total time 4.77944 hours
# Training at Epoch 5 iteration 4200 with loss 0.77917. Total time 4.79833 hours
# Training at Epoch 5 iteration 4300 with loss 0.85273. Total time 4.81722 hours
# Validation at Epoch 5 with loss:1.67952, MSE: 0.96784 , Pearson Correlation: 0.75376 with p-value: 0.00E+00 , Concordance Index: 0.78132
# Training at Epoch 6 iteration 0 with loss 0.81073. Total time 4.93194 hours
# Training at Epoch 6 iteration 100 with loss 0.86688. Total time 4.95111 hours
# Training at Epoch 6 iteration 200 with loss 1.06790. Total time 4.97 hours
# Training at Epoch 6 iteration 300 with loss 1.08716. Total time 4.98944 hours
# Training at Epoch 6 iteration 400 with loss 1.07091. Total time 5.00888 hours
# Training at Epoch 6 iteration 500 with loss 0.85020. Total time 5.02805 hours
# Training at Epoch 6 iteration 600 with loss 1.08325. Total time 5.04666 hours
# Training at Epoch 6 iteration 700 with loss 1.03310. Total time 5.06611 hours
# Training at Epoch 6 iteration 800 with loss 1.08930. Total time 5.08527 hours
# Training at Epoch 6 iteration 900 with loss 1.06365. Total time 5.10416 hours
# Training at Epoch 6 iteration 1000 with loss 0.85270. Total time 5.12333 hours
# Training at Epoch 6 iteration 1100 with loss 0.98669. Total time 5.1425 hours
# Training at Epoch 6 iteration 1200 with loss 1.01372. Total time 5.16138 hours
# Training at Epoch 6 iteration 1300 with loss 1.05297. Total time 5.18055 hours
# Training at Epoch 6 iteration 1400 with loss 0.98766. Total time 5.19944 hours
# Training at Epoch 6 iteration 1500 with loss 1.08680. Total time 5.21833 hours
# Training at Epoch 6 iteration 1600 with loss 0.91122. Total time 5.23694 hours
# Training at Epoch 6 iteration 1700 with loss 0.86439. Total time 5.25583 hours
# Training at Epoch 6 iteration 1800 with loss 0.83377. Total time 5.27444 hours
# Training at Epoch 6 iteration 1900 with loss 0.91808. Total time 5.29333 hours
# Training at Epoch 6 iteration 2000 with loss 0.76973. Total time 5.31222 hours
# Training at Epoch 6 iteration 2100 with loss 0.73417. Total time 5.33083 hours
# Training at Epoch 6 iteration 2200 with loss 0.82596. Total time 5.34972 hours
# Training at Epoch 6 iteration 2300 with loss 1.15180. Total time 5.36861 hours
# Training at Epoch 6 iteration 2400 with loss 1.07985. Total time 5.38722 hours
# Training at Epoch 6 iteration 2500 with loss 1.00357. Total time 5.40583 hours
# Training at Epoch 6 iteration 2600 with loss 1.00017. Total time 5.42444 hours
# Training at Epoch 6 iteration 2700 with loss 1.13664. Total time 5.44277 hours
# Training at Epoch 6 iteration 2800 with loss 0.98096. Total time 5.46166 hours
# Training at Epoch 6 iteration 2900 with loss 0.92133. Total time 5.48055 hours
# Training at Epoch 6 iteration 3000 with loss 1.04725. Total time 5.49944 hours
# Training at Epoch 6 iteration 3100 with loss 1.03301. Total time 5.51861 hours
# Training at Epoch 6 iteration 3200 with loss 0.82794. Total time 5.53722 hours
# Training at Epoch 6 iteration 3300 with loss 0.90568. Total time 5.55583 hours
# Training at Epoch 6 iteration 3400 with loss 1.03056. Total time 5.57472 hours
# Training at Epoch 6 iteration 3500 with loss 0.78250. Total time 5.59333 hours
# Training at Epoch 6 iteration 3600 with loss 1.05201. Total time 5.61166 hours
# Training at Epoch 6 iteration 3700 with loss 0.95376. Total time 5.63083 hours
# Training at Epoch 6 iteration 3800 with loss 0.95394. Total time 5.65416 hours
# Training at Epoch 6 iteration 3900 with loss 1.03421. Total time 5.6775 hours
# Training at Epoch 6 iteration 4000 with loss 0.83556. Total time 5.70083 hours
# Training at Epoch 6 iteration 4100 with loss 1.04523. Total time 5.72416 hours
# Training at Epoch 6 iteration 4200 with loss 1.01775. Total time 5.7475 hours
# Training at Epoch 6 iteration 4300 with loss 0.88071. Total time 5.77083 hours
# Validation at Epoch 6 with loss:1.05543, MSE: 0.96067 , Pearson Correlation: 0.76122 with p-value: 0.00E+00 , Concordance Index: 0.78486
# Training at Epoch 7 iteration 0 with loss 0.79709. Total time 5.90222 hours
# Training at Epoch 7 iteration 100 with loss 0.97357. Total time 5.92527 hours
# Training at Epoch 7 iteration 200 with loss 0.97474. Total time 5.94833 hours
# Training at Epoch 7 iteration 300 with loss 0.97491. Total time 5.97111 hours
# Training at Epoch 7 iteration 400 with loss 0.90043. Total time 5.99416 hours
# Training at Epoch 7 iteration 500 with loss 0.77246. Total time 6.01722 hours
# Training at Epoch 7 iteration 600 with loss 0.86257. Total time 6.04 hours
# Training at Epoch 7 iteration 700 with loss 1.07036. Total time 6.06305 hours
# Training at Epoch 7 iteration 800 with loss 1.11487. Total time 6.08583 hours
# Training at Epoch 7 iteration 900 with loss 1.03736. Total time 6.10888 hours
# Training at Epoch 7 iteration 1000 with loss 0.77032. Total time 6.13166 hours
# Training at Epoch 7 iteration 1100 with loss 0.80608. Total time 6.15444 hours
# Training at Epoch 7 iteration 1200 with loss 0.94841. Total time 6.17722 hours
# Training at Epoch 7 iteration 1300 with loss 0.93608. Total time 6.2 hours
# Training at Epoch 7 iteration 1400 with loss 1.01102. Total time 6.22277 hours
# Training at Epoch 7 iteration 1500 with loss 0.99733. Total time 6.24555 hours
# Training at Epoch 7 iteration 1600 with loss 0.86511. Total time 6.26861 hours
# Training at Epoch 7 iteration 1700 with loss 1.01743. Total time 6.29111 hours
# Training at Epoch 7 iteration 1800 with loss 0.99471. Total time 6.31388 hours
# Training at Epoch 7 iteration 1900 with loss 0.99466. Total time 6.33638 hours
# Training at Epoch 7 iteration 2000 with loss 0.95800. Total time 6.35944 hours
# Training at Epoch 7 iteration 2100 with loss 0.97390. Total time 6.38277 hours
# Training at Epoch 7 iteration 2200 with loss 1.01688. Total time 6.40583 hours
# Training at Epoch 7 iteration 2300 with loss 0.88551. Total time 6.42888 hours
# Training at Epoch 7 iteration 2400 with loss 0.97833. Total time 6.45194 hours
# Training at Epoch 7 iteration 2500 with loss 1.02375. Total time 6.47472 hours
# Training at Epoch 7 iteration 2600 with loss 1.05361. Total time 6.4975 hours
# Training at Epoch 7 iteration 2700 with loss 0.96432. Total time 6.52 hours
# Training at Epoch 7 iteration 2800 with loss 0.87782. Total time 6.54305 hours
# Training at Epoch 7 iteration 2900 with loss 0.72269. Total time 6.56583 hours
# Training at Epoch 7 iteration 3000 with loss 0.93907. Total time 6.58833 hours
# Training at Epoch 7 iteration 3100 with loss 0.91593. Total time 6.61055 hours
# Training at Epoch 7 iteration 3200 with loss 1.07391. Total time 6.63305 hours
# Training at Epoch 7 iteration 3300 with loss 1.03021. Total time 6.65555 hours
# Training at Epoch 7 iteration 3400 with loss 0.85787. Total time 6.67777 hours
# Training at Epoch 7 iteration 3500 with loss 0.90414. Total time 6.69777 hours
# Training at Epoch 7 iteration 3600 with loss 0.88774. Total time 6.71638 hours
# Training at Epoch 7 iteration 3700 with loss 0.80818. Total time 6.735 hours
# Training at Epoch 7 iteration 3800 with loss 0.64511. Total time 6.75333 hours
# Training at Epoch 7 iteration 3900 with loss 0.82619. Total time 6.77194 hours
# Training at Epoch 7 iteration 4000 with loss 0.70090. Total time 6.79055 hours
# Training at Epoch 7 iteration 4100 with loss 0.93871. Total time 6.80888 hours
# Training at Epoch 7 iteration 4200 with loss 0.79095. Total time 6.8275 hours
# Training at Epoch 7 iteration 4300 with loss 0.81959. Total time 6.84583 hours
# Validation at Epoch 7 with loss:1.04605, MSE: 0.97056 , Pearson Correlation: 0.76510 with p-value: 0.00E+00 , Concordance Index: 0.78708
# Training at Epoch 8 iteration 0 with loss 1.00817. Total time 6.96027 hours
# Training at Epoch 8 iteration 100 with loss 0.90026. Total time 6.97861 hours
# Training at Epoch 8 iteration 200 with loss 0.85186. Total time 6.99694 hours
# Training at Epoch 8 iteration 300 with loss 0.82282. Total time 7.01527 hours
# Training at Epoch 8 iteration 400 with loss 0.95614. Total time 7.03361 hours
# Training at Epoch 8 iteration 500 with loss 0.99716. Total time 7.05222 hours
# Training at Epoch 8 iteration 600 with loss 0.85061. Total time 7.07055 hours
# Training at Epoch 8 iteration 700 with loss 0.92019. Total time 7.08916 hours
# Training at Epoch 8 iteration 800 with loss 0.93576. Total time 7.1075 hours
# Training at Epoch 8 iteration 900 with loss 0.87853. Total time 7.12611 hours
# Training at Epoch 8 iteration 1000 with loss 0.92326. Total time 7.14444 hours
# Training at Epoch 8 iteration 1100 with loss 1.01157. Total time 7.16305 hours
# Training at Epoch 8 iteration 1200 with loss 0.78690. Total time 7.18166 hours
# Training at Epoch 8 iteration 1300 with loss 1.11877. Total time 7.20027 hours
# Training at Epoch 8 iteration 1400 with loss 0.99317. Total time 7.21888 hours
# Training at Epoch 8 iteration 1500 with loss 0.86270. Total time 7.2375 hours
# Training at Epoch 8 iteration 1600 with loss 0.91023. Total time 7.25583 hours
# Training at Epoch 8 iteration 1700 with loss 0.77461. Total time 7.27444 hours
# Training at Epoch 8 iteration 1800 with loss 0.95755. Total time 7.29305 hours
# Training at Epoch 8 iteration 1900 with loss 0.84570. Total time 7.31166 hours
# Training at Epoch 8 iteration 2000 with loss 0.91883. Total time 7.33027 hours
# Training at Epoch 8 iteration 2100 with loss 0.76178. Total time 7.34861 hours
# Training at Epoch 8 iteration 2200 with loss 0.88371. Total time 7.36722 hours
# Training at Epoch 8 iteration 2300 with loss 1.02131. Total time 7.38583 hours
# Training at Epoch 8 iteration 2400 with loss 0.68106. Total time 7.40444 hours
# Training at Epoch 8 iteration 2500 with loss 0.84215. Total time 7.42305 hours
# Training at Epoch 8 iteration 2600 with loss 1.20525. Total time 7.44138 hours
# Training at Epoch 8 iteration 2700 with loss 1.00583. Total time 7.46 hours
# Training at Epoch 8 iteration 2800 with loss 0.85210. Total time 7.47861 hours
# Training at Epoch 8 iteration 2900 with loss 0.88767. Total time 7.49722 hours
# Training at Epoch 8 iteration 3000 with loss 0.80803. Total time 7.51583 hours
# Training at Epoch 8 iteration 3100 with loss 0.85558. Total time 7.53444 hours
# Training at Epoch 8 iteration 3200 with loss 0.92048. Total time 7.55277 hours
# Training at Epoch 8 iteration 3300 with loss 0.98200. Total time 7.57138 hours
# Training at Epoch 8 iteration 3400 with loss 0.75989. Total time 7.59 hours
# Training at Epoch 8 iteration 3500 with loss 0.70500. Total time 7.60833 hours
# Training at Epoch 8 iteration 3600 with loss 0.77222. Total time 7.62694 hours
# Training at Epoch 8 iteration 3700 with loss 0.83463. Total time 7.64527 hours
# Training at Epoch 8 iteration 3800 with loss 0.79900. Total time 7.66388 hours
# Training at Epoch 8 iteration 3900 with loss 1.06262. Total time 7.6825 hours
# Training at Epoch 8 iteration 4000 with loss 0.95049. Total time 7.70138 hours
# Training at Epoch 8 iteration 4100 with loss 0.82717. Total time 7.72055 hours
# Training at Epoch 8 iteration 4200 with loss 0.83249. Total time 7.73944 hours
# Training at Epoch 8 iteration 4300 with loss 0.94242. Total time 7.75833 hours
# Validation at Epoch 8 with loss:0.66266, MSE: 0.89695 , Pearson Correlation: 0.77073 with p-value: 0.00E+00 , Concordance Index: 0.78974
# Training at Epoch 9 iteration 0 with loss 0.88383. Total time 7.87222 hours
# Training at Epoch 9 iteration 100 with loss 1.0649. Total time 7.89083 hours
# Training at Epoch 9 iteration 200 with loss 0.93168. Total time 7.90916 hours
# Training at Epoch 9 iteration 300 with loss 1.00590. Total time 7.92777 hours
# Training at Epoch 9 iteration 400 with loss 0.81473. Total time 7.94666 hours
# Training at Epoch 9 iteration 500 with loss 1.05256. Total time 7.96555 hours
# Training at Epoch 9 iteration 600 with loss 0.93915. Total time 7.98472 hours
# Training at Epoch 9 iteration 700 with loss 0.81935. Total time 8.00388 hours
# Training at Epoch 9 iteration 800 with loss 0.70127. Total time 8.02277 hours
# Training at Epoch 9 iteration 900 with loss 0.95835. Total time 8.04194 hours
# Training at Epoch 9 iteration 1000 with loss 0.92896. Total time 8.06083 hours
# Training at Epoch 9 iteration 1100 with loss 0.88522. Total time 8.08 hours
# Training at Epoch 9 iteration 1200 with loss 0.96131. Total time 8.09888 hours
# Training at Epoch 9 iteration 1300 with loss 0.94641. Total time 8.11805 hours
# Training at Epoch 9 iteration 1400 with loss 0.96383. Total time 8.13694 hours
# Training at Epoch 9 iteration 1500 with loss 0.91234. Total time 8.15555 hours
# Training at Epoch 9 iteration 1600 with loss 0.88544. Total time 8.17444 hours
# Training at Epoch 9 iteration 1700 with loss 0.86322. Total time 8.19305 hours
# Training at Epoch 9 iteration 1800 with loss 0.85878. Total time 8.21194 hours
# Training at Epoch 9 iteration 1900 with loss 0.92709. Total time 8.23055 hours
# Training at Epoch 9 iteration 2000 with loss 0.66664. Total time 8.24916 hours
# Training at Epoch 9 iteration 2100 with loss 0.76143. Total time 8.26777 hours
# Training at Epoch 9 iteration 2200 with loss 0.91513. Total time 8.28611 hours
# Training at Epoch 9 iteration 2300 with loss 0.94822. Total time 8.30472 hours
# Training at Epoch 9 iteration 2400 with loss 0.80592. Total time 8.32305 hours
# Training at Epoch 9 iteration 2500 with loss 0.72151. Total time 8.34166 hours
# Training at Epoch 9 iteration 2600 with loss 0.64282. Total time 8.36027 hours
# Training at Epoch 9 iteration 2700 with loss 1.10047. Total time 8.37861 hours
# Training at Epoch 9 iteration 2800 with loss 0.71152. Total time 8.39694 hours
# Training at Epoch 9 iteration 2900 with loss 0.77765. Total time 8.41555 hours
# Training at Epoch 9 iteration 3000 with loss 0.73806. Total time 8.43416 hours
# Training at Epoch 9 iteration 3100 with loss 0.87758. Total time 8.45277 hours
# Training at Epoch 9 iteration 3200 with loss 0.89430. Total time 8.47138 hours
# Training at Epoch 9 iteration 3300 with loss 1.06194. Total time 8.48972 hours
# Training at Epoch 9 iteration 3400 with loss 1.06384. Total time 8.50833 hours
# Training at Epoch 9 iteration 3500 with loss 0.86833. Total time 8.52694 hours
# Training at Epoch 9 iteration 3600 with loss 0.82077. Total time 8.54555 hours
# Training at Epoch 9 iteration 3700 with loss 0.76675. Total time 8.56416 hours
# Training at Epoch 9 iteration 3800 with loss 0.88082. Total time 8.5825 hours
# Training at Epoch 9 iteration 3900 with loss 0.82177. Total time 8.60111 hours
# Training at Epoch 9 iteration 4000 with loss 0.84146. Total time 8.61972 hours
# Training at Epoch 9 iteration 4100 with loss 0.73882. Total time 8.63833 hours
# Training at Epoch 9 iteration 4200 with loss 0.81395. Total time 8.65694 hours
# Training at Epoch 9 iteration 4300 with loss 0.87566. Total time 8.67555 hours
# Validation at Epoch 9 with loss:1.16093, MSE: 0.89186 , Pearson Correlation: 0.77306 with p-value: 0.00E+00 , Concordance Index: 0.79090
# Training at Epoch 10 iteration 0 with loss 0.75741. Total time 8.7875 hours
# Training at Epoch 10 iteration 100 with loss 0.79023. Total time 8.80583 hours
# Training at Epoch 10 iteration 200 with loss 0.83268. Total time 8.82444 hours
# Training at Epoch 10 iteration 300 with loss 0.93855. Total time 8.84277 hours
# Training at Epoch 10 iteration 400 with loss 0.95041. Total time 8.86111 hours
# Training at Epoch 10 iteration 500 with loss 1.01058. Total time 8.87944 hours
# Training at Epoch 10 iteration 600 with loss 0.88427. Total time 8.89777 hours
# Training at Epoch 10 iteration 700 with loss 0.87792. Total time 8.91638 hours
# Training at Epoch 10 iteration 800 with loss 0.82066. Total time 8.93472 hours
# Training at Epoch 10 iteration 900 with loss 0.71870. Total time 8.95333 hours
# Training at Epoch 10 iteration 1000 with loss 1.03767. Total time 8.97222 hours
# Training at Epoch 10 iteration 1100 with loss 1.01270. Total time 8.99138 hours
# Training at Epoch 10 iteration 1200 with loss 0.73192. Total time 9.01527 hours
# Training at Epoch 10 iteration 1300 with loss 0.87669. Total time 9.04027 hours
# Training at Epoch 10 iteration 1400 with loss 0.80041. Total time 9.065 hours
# Training at Epoch 10 iteration 1500 with loss 0.76094. Total time 9.08972 hours
# Training at Epoch 10 iteration 1600 with loss 0.76315. Total time 9.11416 hours
# Training at Epoch 10 iteration 1700 with loss 0.71207. Total time 9.13861 hours
# Training at Epoch 10 iteration 1800 with loss 1.17829. Total time 9.16305 hours
# Training at Epoch 10 iteration 1900 with loss 0.76021. Total time 9.1875 hours
# Training at Epoch 10 iteration 2000 with loss 0.80805. Total time 9.21166 hours
# Training at Epoch 10 iteration 2100 with loss 0.72993. Total time 9.23611 hours
# Training at Epoch 10 iteration 2200 with loss 0.83514. Total time 9.26055 hours
# Training at Epoch 10 iteration 2300 with loss 1.06331. Total time 9.285 hours
# Training at Epoch 10 iteration 2400 with loss 0.79797. Total time 9.30944 hours
# Training at Epoch 10 iteration 2500 with loss 0.76555. Total time 9.33361 hours
# Training at Epoch 10 iteration 2600 with loss 0.87521. Total time 9.35777 hours
# Training at Epoch 10 iteration 2700 with loss 0.90042. Total time 9.38222 hours
# Training at Epoch 10 iteration 2800 with loss 0.75098. Total time 9.40638 hours
# Training at Epoch 10 iteration 2900 with loss 0.88406. Total time 9.43055 hours
# Training at Epoch 10 iteration 3000 with loss 0.73551. Total time 9.455 hours
# Training at Epoch 10 iteration 3100 with loss 0.77791. Total time 9.47944 hours
# Training at Epoch 10 iteration 3200 with loss 0.83079. Total time 9.50472 hours
# Training at Epoch 10 iteration 3300 with loss 0.77742. Total time 9.52916 hours
# Training at Epoch 10 iteration 3400 with loss 0.96382. Total time 9.55388 hours
# Training at Epoch 10 iteration 3500 with loss 0.95928. Total time 9.57833 hours
# Training at Epoch 10 iteration 3600 with loss 0.88388. Total time 9.60333 hours
# Training at Epoch 10 iteration 3700 with loss 0.76190. Total time 9.62777 hours
# Training at Epoch 10 iteration 3800 with loss 1.00174. Total time 9.65138 hours
# Training at Epoch 10 iteration 3900 with loss 1.04461. Total time 9.67444 hours
# Training at Epoch 10 iteration 4000 with loss 0.98761. Total time 9.69777 hours
# Training at Epoch 10 iteration 4100 with loss 0.77029. Total time 9.72111 hours
# Training at Epoch 10 iteration 4200 with loss 0.80180. Total time 9.74416 hours
# Training at Epoch 10 iteration 4300 with loss 1.09083. Total time 9.76722 hours
# Validation at Epoch 10 with loss:0.59260, MSE: 0.87413 , Pearson Correlation: 0.77791 with p-value: 0.00E+00 , Concordance Index: 0.79369
# Training at Epoch 11 iteration 0 with loss 0.88409. Total time 9.89444 hours
# Training at Epoch 11 iteration 100 with loss 0.71981. Total time 9.91722 hours
# Training at Epoch 11 iteration 200 with loss 0.83695. Total time 9.93972 hours
# Training at Epoch 11 iteration 300 with loss 0.87569. Total time 9.96194 hours
# Training at Epoch 11 iteration 400 with loss 0.90958. Total time 9.98444 hours
# Training at Epoch 11 iteration 500 with loss 0.97635. Total time 10.0066 hours
# Training at Epoch 11 iteration 600 with loss 0.99085. Total time 10.0288 hours
# Training at Epoch 11 iteration 700 with loss 0.88795. Total time 10.0491 hours
# Training at Epoch 11 iteration 800 with loss 0.78543. Total time 10.0677 hours
# Training at Epoch 11 iteration 900 with loss 0.76360. Total time 10.0863 hours
# Training at Epoch 11 iteration 1000 with loss 0.89962. Total time 10.105 hours
# Training at Epoch 11 iteration 1100 with loss 0.76994. Total time 10.1233 hours
# Training at Epoch 11 iteration 1200 with loss 0.83501. Total time 10.1416 hours
# Training at Epoch 11 iteration 1300 with loss 0.83735. Total time 10.1597 hours
# Training at Epoch 11 iteration 1400 with loss 0.93049. Total time 10.1780 hours
# Training at Epoch 11 iteration 1500 with loss 0.84503. Total time 10.1961 hours
# Training at Epoch 11 iteration 1600 with loss 0.99850. Total time 10.2144 hours
# Training at Epoch 11 iteration 1700 with loss 0.73815. Total time 10.2327 hours
# Training at Epoch 11 iteration 1800 with loss 0.88554. Total time 10.2511 hours
# Training at Epoch 11 iteration 1900 with loss 0.91819. Total time 10.2694 hours
# Training at Epoch 11 iteration 2000 with loss 0.82020. Total time 10.2877 hours
# Training at Epoch 11 iteration 2100 with loss 0.87141. Total time 10.3063 hours
# Training at Epoch 11 iteration 2200 with loss 0.74382. Total time 10.3247 hours
# Training at Epoch 11 iteration 2300 with loss 0.82948. Total time 10.3430 hours
# Training at Epoch 11 iteration 2400 with loss 0.90677. Total time 10.3613 hours
# Training at Epoch 11 iteration 2500 with loss 0.71689. Total time 10.3797 hours
# Training at Epoch 11 iteration 2600 with loss 1.34044. Total time 10.3980 hours
# Training at Epoch 11 iteration 2700 with loss 0.93194. Total time 10.4163 hours
# Training at Epoch 11 iteration 2800 with loss 0.74416. Total time 10.4347 hours
# Training at Epoch 11 iteration 2900 with loss 0.70104. Total time 10.4530 hours
# Training at Epoch 11 iteration 3000 with loss 0.71572. Total time 10.4713 hours
# Training at Epoch 11 iteration 3100 with loss 0.79906. Total time 10.4897 hours
# Training at Epoch 11 iteration 3200 with loss 0.71442. Total time 10.5080 hours
# Training at Epoch 11 iteration 3300 with loss 0.74195. Total time 10.5263 hours
# Training at Epoch 11 iteration 3400 with loss 0.80671. Total time 10.5447 hours
# Training at Epoch 11 iteration 3500 with loss 0.79184. Total time 10.5630 hours
# Training at Epoch 11 iteration 3600 with loss 0.91805. Total time 10.5813 hours
# Training at Epoch 11 iteration 3700 with loss 0.82537. Total time 10.5997 hours
# Training at Epoch 11 iteration 3800 with loss 0.82592. Total time 10.6180 hours
# Training at Epoch 11 iteration 3900 with loss 0.81654. Total time 10.6363 hours
# Training at Epoch 11 iteration 4000 with loss 0.80556. Total time 10.6547 hours
# Training at Epoch 11 iteration 4100 with loss 0.86535. Total time 10.6730 hours
# Training at Epoch 11 iteration 4200 with loss 0.73719. Total time 10.6913 hours
# Training at Epoch 11 iteration 4300 with loss 0.95188. Total time 10.7097 hours
# Validation at Epoch 11 with loss:0.86603, MSE: 0.87511 , Pearson Correlation: 0.77813 with p-value: 0.00E+00 , Concordance Index: 0.79435
# Training at Epoch 12 iteration 0 with loss 0.83887. Total time 10.8225 hours
# Training at Epoch 12 iteration 100 with loss 0.78923. Total time 10.8408 hours
# Training at Epoch 12 iteration 200 with loss 0.74193. Total time 10.8588 hours
# Training at Epoch 12 iteration 300 with loss 0.73680. Total time 10.8772 hours
# Training at Epoch 12 iteration 400 with loss 0.74179. Total time 10.8955 hours
# Training at Epoch 12 iteration 500 with loss 0.86695. Total time 10.9138 hours
# Training at Epoch 12 iteration 600 with loss 0.73214. Total time 10.9322 hours
# Training at Epoch 12 iteration 700 with loss 0.86015. Total time 10.9505 hours
# Training at Epoch 12 iteration 800 with loss 0.65544. Total time 10.9688 hours
# Training at Epoch 12 iteration 900 with loss 0.68500. Total time 10.9872 hours
# Training at Epoch 12 iteration 1000 with loss 0.75882. Total time 11.0055 hours
# Training at Epoch 12 iteration 1100 with loss 0.79350. Total time 11.0238 hours
# Training at Epoch 12 iteration 1200 with loss 1.45012. Total time 11.0422 hours
# Training at Epoch 12 iteration 1300 with loss 1.02793. Total time 11.0605 hours
# Training at Epoch 12 iteration 1400 with loss 0.81152. Total time 11.0788 hours
# Training at Epoch 12 iteration 1500 with loss 0.84016. Total time 11.0975 hours
# Training at Epoch 12 iteration 1600 with loss 0.71799. Total time 11.1158 hours
# Training at Epoch 12 iteration 1700 with loss 0.90909. Total time 11.1341 hours
# Training at Epoch 12 iteration 1800 with loss 0.82411. Total time 11.1525 hours
# Training at Epoch 12 iteration 1900 with loss 0.80465. Total time 11.1708 hours
# Training at Epoch 12 iteration 2000 with loss 0.72008. Total time 11.1891 hours
# Training at Epoch 12 iteration 2100 with loss 0.92230. Total time 11.2075 hours
# Training at Epoch 12 iteration 2200 with loss 0.85402. Total time 11.2258 hours
# Training at Epoch 12 iteration 2300 with loss 0.82385. Total time 11.2441 hours
# Training at Epoch 12 iteration 2400 with loss 0.92509. Total time 11.2625 hours
# Training at Epoch 12 iteration 2500 with loss 1.45513. Total time 11.2808 hours
# Training at Epoch 12 iteration 2600 with loss 0.92304. Total time 11.2991 hours
# Training at Epoch 12 iteration 2700 with loss 0.87266. Total time 11.3175 hours
# Training at Epoch 12 iteration 2800 with loss 0.80863. Total time 11.3358 hours
# Training at Epoch 12 iteration 2900 with loss 0.65351. Total time 11.3541 hours
# Training at Epoch 12 iteration 3000 with loss 0.90905. Total time 11.3725 hours
# Training at Epoch 12 iteration 3100 with loss 0.76431. Total time 11.3908 hours
# Training at Epoch 12 iteration 3200 with loss 0.78104. Total time 11.4091 hours
# Training at Epoch 12 iteration 3300 with loss 0.85687. Total time 11.4277 hours
# Training at Epoch 12 iteration 3400 with loss 0.94169. Total time 11.4461 hours
# Training at Epoch 12 iteration 3500 with loss 0.91758. Total time 11.4644 hours
# Training at Epoch 12 iteration 3600 with loss 0.84451. Total time 11.4827 hours
# Training at Epoch 12 iteration 3700 with loss 1.30878. Total time 11.5011 hours
# Training at Epoch 12 iteration 3800 with loss 0.76135. Total time 11.5194 hours
# Training at Epoch 12 iteration 3900 with loss 0.75848. Total time 11.5377 hours
# Training at Epoch 12 iteration 4000 with loss 0.99821. Total time 11.5561 hours
# Training at Epoch 12 iteration 4100 with loss 0.70401. Total time 11.5744 hours
# Training at Epoch 12 iteration 4200 with loss 0.89233. Total time 11.5927 hours
# Training at Epoch 12 iteration 4300 with loss 0.87538. Total time 11.6111 hours
# Validation at Epoch 12 with loss:1.10918, MSE: 0.85952 , Pearson Correlation: 0.78323 with p-value: 0.00E+00 , Concordance Index: 0.79640
# Training at Epoch 13 iteration 0 with loss 0.81460. Total time 11.7247 hours
# Training at Epoch 13 iteration 100 with loss 0.78635. Total time 11.7430 hours
# Training at Epoch 13 iteration 200 with loss 0.85569. Total time 11.7611 hours
# Training at Epoch 13 iteration 300 with loss 0.82455. Total time 11.7794 hours
# Training at Epoch 13 iteration 400 with loss 0.80191. Total time 11.7977 hours
# Training at Epoch 13 iteration 500 with loss 0.78464. Total time 11.8161 hours
# Training at Epoch 13 iteration 600 with loss 0.73559. Total time 11.8344 hours
# Training at Epoch 13 iteration 700 with loss 0.91458. Total time 11.8527 hours
# Training at Epoch 13 iteration 800 with loss 0.79908. Total time 11.8711 hours
# Training at Epoch 13 iteration 900 with loss 0.83572. Total time 11.8894 hours
# Training at Epoch 13 iteration 1000 with loss 0.80791. Total time 11.9077 hours
# Training at Epoch 13 iteration 1100 with loss 0.80579. Total time 11.9261 hours
# Training at Epoch 13 iteration 1200 with loss 0.70099. Total time 11.9444 hours
# Training at Epoch 13 iteration 1300 with loss 0.71242. Total time 11.9627 hours
# Training at Epoch 13 iteration 1400 with loss 0.82529. Total time 11.9811 hours
# Training at Epoch 13 iteration 1500 with loss 0.76163. Total time 11.9994 hours
# Training at Epoch 13 iteration 1600 with loss 0.90525. Total time 12.0177 hours
# Training at Epoch 13 iteration 1700 with loss 0.84379. Total time 12.0361 hours
# Training at Epoch 13 iteration 1800 with loss 0.78566. Total time 12.0544 hours
# Training at Epoch 13 iteration 1900 with loss 0.71835. Total time 12.0727 hours
# Training at Epoch 13 iteration 2000 with loss 0.81011. Total time 12.0911 hours
# Training at Epoch 13 iteration 2100 with loss 0.83827. Total time 12.1094 hours
# Training at Epoch 13 iteration 2200 with loss 0.89162. Total time 12.1277 hours
# Training at Epoch 13 iteration 2300 with loss 0.79260. Total time 12.1461 hours
# Training at Epoch 13 iteration 2400 with loss 0.97643. Total time 12.1644 hours
# Training at Epoch 13 iteration 2500 with loss 0.76846. Total time 12.1827 hours
# Training at Epoch 13 iteration 2600 with loss 0.75580. Total time 12.2011 hours
# Training at Epoch 13 iteration 2700 with loss 0.69684. Total time 12.2194 hours
# Training at Epoch 13 iteration 2800 with loss 0.65821. Total time 12.2377 hours
# Training at Epoch 13 iteration 2900 with loss 0.68728. Total time 12.2561 hours
# Training at Epoch 13 iteration 3000 with loss 0.66228. Total time 12.2744 hours
# Training at Epoch 13 iteration 3100 with loss 0.84978. Total time 12.2927 hours
# Training at Epoch 13 iteration 3200 with loss 0.90792. Total time 12.3111 hours
# Training at Epoch 13 iteration 3300 with loss 0.71914. Total time 12.3294 hours
# Training at Epoch 13 iteration 3400 with loss 0.82603. Total time 12.3477 hours
# Training at Epoch 13 iteration 3500 with loss 0.80906. Total time 12.3661 hours
# Training at Epoch 13 iteration 3600 with loss 0.73848. Total time 12.3844 hours
# Training at Epoch 13 iteration 3700 with loss 0.69085. Total time 12.4027 hours
# Training at Epoch 13 iteration 3800 with loss 0.85905. Total time 12.4211 hours
# Training at Epoch 13 iteration 3900 with loss 0.70760. Total time 12.4397 hours
# Training at Epoch 13 iteration 4000 with loss 0.83947. Total time 12.4580 hours
# Training at Epoch 13 iteration 4100 with loss 0.84851. Total time 12.4763 hours
# Training at Epoch 13 iteration 4200 with loss 0.69125. Total time 12.4947 hours
# Training at Epoch 13 iteration 4300 with loss 0.74306. Total time 12.5130 hours
# Validation at Epoch 13 with loss:0.73678, MSE: 0.84019 , Pearson Correlation: 0.78731 with p-value: 0.00E+00 , Concordance Index: 0.79860
# Training at Epoch 14 iteration 0 with loss 0.73395. Total time 12.625 hours
# Training at Epoch 14 iteration 100 with loss 0.69994. Total time 12.6433 hours
# Training at Epoch 14 iteration 200 with loss 0.74718. Total time 12.6613 hours
# Training at Epoch 14 iteration 300 with loss 0.90161. Total time 12.6797 hours
# Training at Epoch 14 iteration 400 with loss 0.77473. Total time 12.6980 hours
# Training at Epoch 14 iteration 500 with loss 0.70314. Total time 12.7163 hours
# Training at Epoch 14 iteration 600 with loss 0.73326. Total time 12.7347 hours
# Training at Epoch 14 iteration 700 with loss 0.93866. Total time 12.7530 hours
# Training at Epoch 14 iteration 800 with loss 0.86070. Total time 12.7713 hours
# Training at Epoch 14 iteration 900 with loss 0.98438. Total time 12.7897 hours
# Training at Epoch 14 iteration 1000 with loss 0.71982. Total time 12.8080 hours
# Training at Epoch 14 iteration 1100 with loss 0.86145. Total time 12.8263 hours
# Training at Epoch 14 iteration 1200 with loss 0.76237. Total time 12.8447 hours
# ...
# Training at Epoch 46 iteration 3100 with loss 0.66196. Total time 42.2036 hours
# Training at Epoch 46 iteration 3200 with loss 0.78597. Total time 42.2222 hours
# Training at Epoch 46 iteration 3300 with loss 0.74848. Total time 42.2408 hours
# Training at Epoch 46 iteration 3400 with loss 0.68616. Total time 42.2591 hours
# Training at Epoch 46 iteration 3500 with loss 0.70964. Total time 42.2777 hours
# Training at Epoch 46 iteration 3600 with loss 0.61056. Total time 42.2963 hours
# Training at Epoch 46 iteration 3700 with loss 0.55603. Total time 42.315 hours
# Training at Epoch 46 iteration 3800 with loss 0.69488. Total time 42.3333 hours
# Training at Epoch 46 iteration 3900 with loss 0.68569. Total time 42.3519 hours
# Training at Epoch 46 iteration 4000 with loss 0.63970. Total time 42.3705 hours
# Training at Epoch 46 iteration 4100 with loss 0.61565. Total time 42.3888 hours
# Training at Epoch 46 iteration 4200 with loss 0.67298. Total time 42.4075 hours
# Training at Epoch 46 iteration 4300 with loss 0.70814. Total time 42.4261 hours
# Validation at Epoch 46 with loss:0.66948, MSE: 0.75055 , Pearson Correlation: 0.81317 with p-value: 0.00E+00 , Concordance Index: 0.81264
# Training at Epoch 47 iteration 0 with loss 0.65568. Total time 42.5377 hours
# Training at Epoch 47 iteration 100 with loss 0.55603. Total time 42.5563 hours
# Training at Epoch 47 iteration 200 with loss 0.66145. Total time 42.5747 hours
# Training at Epoch 47 iteration 300 with loss 0.56707. Total time 42.5933 hours
# Training at Epoch 47 iteration 400 with loss 0.64974. Total time 42.6116 hours
# Training at Epoch 47 iteration 500 with loss 0.61079. Total time 42.6302 hours
# Training at Epoch 47 iteration 600 with loss 0.64538. Total time 42.6488 hours
# Training at Epoch 47 iteration 700 with loss 0.56110. Total time 42.6675 hours
# Training at Epoch 47 iteration 800 with loss 0.56686. Total time 42.6858 hours
# Training at Epoch 47 iteration 900 with loss 0.70377. Total time 42.7044 hours
# Training at Epoch 47 iteration 1000 with loss 0.64302. Total time 42.7230 hours
# Training at Epoch 47 iteration 1100 with loss 0.69906. Total time 42.7416 hours
# Training at Epoch 47 iteration 1200 with loss 0.66947. Total time 42.76 hours
# Training at Epoch 47 iteration 1300 with loss 0.73573. Total time 42.7786 hours
# Training at Epoch 47 iteration 1400 with loss 0.50271. Total time 42.7972 hours
# Training at Epoch 47 iteration 1500 with loss 0.65093. Total time 42.8158 hours
# Training at Epoch 47 iteration 1600 with loss 0.71350. Total time 42.8341 hours
# Training at Epoch 47 iteration 1700 with loss 0.57874. Total time 42.8527 hours
# Training at Epoch 47 iteration 1800 with loss 0.66382. Total time 42.8713 hours
# Training at Epoch 47 iteration 1900 with loss 0.64623. Total time 42.89 hours
# Training at Epoch 47 iteration 2000 with loss 0.55761. Total time 42.9083 hours
# Training at Epoch 47 iteration 2100 with loss 0.64274. Total time 42.9269 hours
# Training at Epoch 47 iteration 2200 with loss 0.63168. Total time 42.9455 hours
# Training at Epoch 47 iteration 2300 with loss 0.82854. Total time 42.9641 hours
# Training at Epoch 47 iteration 2400 with loss 0.52976. Total time 42.9825 hours
# Training at Epoch 47 iteration 2500 with loss 0.61924. Total time 43.0011 hours
# Training at Epoch 47 iteration 2600 with loss 0.73153. Total time 43.0197 hours
# Training at Epoch 47 iteration 2700 with loss 0.71474. Total time 43.0383 hours
# Training at Epoch 47 iteration 2800 with loss 0.61828. Total time 43.0566 hours
# Training at Epoch 47 iteration 2900 with loss 0.61882. Total time 43.0752 hours
# Training at Epoch 47 iteration 3000 with loss 0.71605. Total time 43.0938 hours
# Training at Epoch 47 iteration 3100 with loss 0.67965. Total time 43.1122 hours
# Training at Epoch 47 iteration 3200 with loss 0.69011. Total time 43.1308 hours
# Training at Epoch 47 iteration 3300 with loss 0.73773. Total time 43.1494 hours
# Training at Epoch 47 iteration 3400 with loss 0.59112. Total time 43.1680 hours
# Training at Epoch 47 iteration 3500 with loss 0.63559. Total time 43.1863 hours
# Training at Epoch 47 iteration 3600 with loss 0.57831. Total time 43.205 hours
# Training at Epoch 47 iteration 3700 with loss 0.67083. Total time 43.2236 hours
# Training at Epoch 47 iteration 3800 with loss 0.59838. Total time 43.2422 hours
# Training at Epoch 47 iteration 3900 with loss 0.64536. Total time 43.2605 hours
# Training at Epoch 47 iteration 4000 with loss 0.70913. Total time 43.2791 hours
# Training at Epoch 47 iteration 4100 with loss 0.67952. Total time 43.2977 hours
# Training at Epoch 47 iteration 4200 with loss 0.69891. Total time 43.3163 hours
# Training at Epoch 47 iteration 4300 with loss 0.52583. Total time 43.3347 hours
# Validation at Epoch 47 with loss:0.67177, MSE: 0.75358 , Pearson Correlation: 0.81160 with p-value: 0.00E+00 , Concordance Index: 0.81212
# Training at Epoch 48 iteration 0 with loss 0.72224. Total time 43.4480 hours
# Training at Epoch 48 iteration 100 with loss 0.68774. Total time 43.4666 hours
# Training at Epoch 48 iteration 200 with loss 0.72541. Total time 43.485 hours
# Training at Epoch 48 iteration 300 with loss 0.61786. Total time 43.5036 hours
# Training at Epoch 48 iteration 400 with loss 0.81357. Total time 43.5219 hours
# Training at Epoch 48 iteration 500 with loss 0.66050. Total time 43.5405 hours
# Training at Epoch 48 iteration 600 with loss 0.64593. Total time 43.5591 hours
# Training at Epoch 48 iteration 700 with loss 0.78265. Total time 43.5777 hours
# Training at Epoch 48 iteration 800 with loss 0.70850. Total time 43.5961 hours
# Training at Epoch 48 iteration 900 with loss 0.58772. Total time 43.6147 hours
# Training at Epoch 48 iteration 1000 with loss 0.68509. Total time 43.6333 hours
# Training at Epoch 48 iteration 1100 with loss 0.69859. Total time 43.6519 hours
# Training at Epoch 48 iteration 1200 with loss 0.70093. Total time 43.6702 hours
# Training at Epoch 48 iteration 1300 with loss 0.70805. Total time 43.6888 hours
# Training at Epoch 48 iteration 1400 with loss 0.61896. Total time 43.7075 hours
# Training at Epoch 48 iteration 1500 with loss 0.53768. Total time 43.7258 hours
# Training at Epoch 48 iteration 1600 with loss 0.68204. Total time 43.7444 hours
# Training at Epoch 48 iteration 1700 with loss 0.64242. Total time 43.7630 hours
# Training at Epoch 48 iteration 1800 with loss 0.64152. Total time 43.7816 hours
# Training at Epoch 48 iteration 1900 with loss 0.54674. Total time 43.8 hours
# Training at Epoch 48 iteration 2000 with loss 0.81053. Total time 43.8186 hours
# Training at Epoch 48 iteration 2100 with loss 0.66972. Total time 43.8372 hours
# Training at Epoch 48 iteration 2200 with loss 0.63996. Total time 43.8558 hours
# Training at Epoch 48 iteration 2300 with loss 0.56040. Total time 43.8741 hours
# Training at Epoch 48 iteration 2400 with loss 0.64898. Total time 43.8927 hours
# Training at Epoch 48 iteration 2500 with loss 0.75653. Total time 43.9113 hours
# Training at Epoch 48 iteration 2600 with loss 0.76657. Total time 43.93 hours
# Training at Epoch 48 iteration 2700 with loss 0.88693. Total time 43.9483 hours
# Training at Epoch 48 iteration 2800 with loss 0.90344. Total time 43.9669 hours
# Training at Epoch 48 iteration 2900 with loss 0.68324. Total time 43.9855 hours
# Training at Epoch 48 iteration 3000 with loss 0.69107. Total time 44.0038 hours
# Training at Epoch 48 iteration 3100 with loss 0.53147. Total time 44.0225 hours
# Training at Epoch 48 iteration 3200 with loss 0.67840. Total time 44.0411 hours
# Training at Epoch 48 iteration 3300 with loss 0.72062. Total time 44.0597 hours
# Training at Epoch 48 iteration 3400 with loss 0.66441. Total time 44.0780 hours
# Training at Epoch 48 iteration 3500 with loss 0.69904. Total time 44.0966 hours
# Training at Epoch 48 iteration 3600 with loss 0.52264. Total time 44.1152 hours
# Training at Epoch 48 iteration 3700 with loss 0.63168. Total time 44.1336 hours
# Training at Epoch 48 iteration 3800 with loss 0.69724. Total time 44.1522 hours
# Training at Epoch 48 iteration 3900 with loss 0.76142. Total time 44.1708 hours
# Training at Epoch 48 iteration 4000 with loss 0.54613. Total time 44.1894 hours
# Training at Epoch 48 iteration 4100 with loss 0.63653. Total time 44.2077 hours
# Training at Epoch 48 iteration 4200 with loss 0.64632. Total time 44.2263 hours
# Training at Epoch 48 iteration 4300 with loss 0.62631. Total time 44.245 hours
# Validation at Epoch 48 with loss:0.81758, MSE: 0.75896 , Pearson Correlation: 0.81204 with p-value: 0.00E+00 , Concordance Index: 0.81268
# Training at Epoch 49 iteration 0 with loss 0.55628. Total time 44.3566 hours
# Training at Epoch 49 iteration 100 with loss 0.64708. Total time 44.3752 hours
# Training at Epoch 49 iteration 200 with loss 0.76692. Total time 44.3936 hours
# Training at Epoch 49 iteration 300 with loss 0.64705. Total time 44.4119 hours
# Training at Epoch 49 iteration 400 with loss 0.76283. Total time 44.4305 hours
# Training at Epoch 49 iteration 500 with loss 0.59938. Total time 44.4491 hours
# Training at Epoch 49 iteration 600 with loss 0.54235. Total time 44.4677 hours
# Training at Epoch 49 iteration 700 with loss 0.72617. Total time 44.4861 hours
# Training at Epoch 49 iteration 800 with loss 0.71882. Total time 44.5047 hours
# Training at Epoch 49 iteration 900 with loss 0.71162. Total time 44.5233 hours
# Training at Epoch 49 iteration 1000 with loss 0.71848. Total time 44.5416 hours
# Training at Epoch 49 iteration 1100 with loss 0.67902. Total time 44.5602 hours
# Training at Epoch 49 iteration 1200 with loss 0.67036. Total time 44.5788 hours
# Training at Epoch 49 iteration 1300 with loss 0.77993. Total time 44.5975 hours
# Training at Epoch 49 iteration 1400 with loss 0.65573. Total time 44.6158 hours
# Training at Epoch 49 iteration 1500 with loss 0.74648. Total time 44.6344 hours
# Training at Epoch 49 iteration 1600 with loss 0.57340. Total time 44.6530 hours
# Training at Epoch 49 iteration 1700 with loss 0.76858. Total time 44.6713 hours
# Training at Epoch 49 iteration 1800 with loss 0.58808. Total time 44.69 hours
# Training at Epoch 49 iteration 1900 with loss 0.63604. Total time 44.7086 hours
# Training at Epoch 49 iteration 2000 with loss 0.82893. Total time 44.7272 hours
# Training at Epoch 49 iteration 2100 with loss 0.62689. Total time 44.7455 hours
# Training at Epoch 49 iteration 2200 with loss 0.62923. Total time 44.7641 hours
# Training at Epoch 49 iteration 2300 with loss 0.67914. Total time 44.7827 hours
# Training at Epoch 49 iteration 2400 with loss 0.65620. Total time 44.8013 hours
# Training at Epoch 49 iteration 2500 with loss 0.62344. Total time 44.8197 hours
# Training at Epoch 49 iteration 2600 with loss 0.68122. Total time 44.8383 hours
# Training at Epoch 49 iteration 2700 with loss 0.57500. Total time 44.8569 hours
# Training at Epoch 49 iteration 2800 with loss 0.61413. Total time 44.8752 hours
# Training at Epoch 49 iteration 2900 with loss 0.69427. Total time 44.8938 hours
# Training at Epoch 49 iteration 3000 with loss 0.55132. Total time 44.9125 hours
# Training at Epoch 49 iteration 3100 with loss 0.55036. Total time 44.9311 hours
# Training at Epoch 49 iteration 3200 with loss 0.81601. Total time 44.9494 hours
# Training at Epoch 49 iteration 3300 with loss 0.65884. Total time 44.9680 hours
# Training at Epoch 49 iteration 3400 with loss 0.53459. Total time 44.9866 hours
# Training at Epoch 49 iteration 3500 with loss 0.74543. Total time 45.005 hours
# Training at Epoch 49 iteration 3600 with loss 0.65954. Total time 45.0236 hours
# Training at Epoch 49 iteration 3700 with loss 0.60622. Total time 45.0422 hours
# Training at Epoch 49 iteration 3800 with loss 0.68914. Total time 45.0608 hours
# Training at Epoch 49 iteration 3900 with loss 0.77783. Total time 45.0791 hours
# Training at Epoch 49 iteration 4000 with loss 0.57028. Total time 45.0977 hours
# Training at Epoch 49 iteration 4100 with loss 0.73927. Total time 45.1163 hours
# Training at Epoch 49 iteration 4200 with loss 0.63017. Total time 45.135 hours
# Training at Epoch 49 iteration 4300 with loss 0.72168. Total time 45.1533 hours
# Validation at Epoch 49 with loss:0.75691, MSE: 0.75707 , Pearson Correlation: 0.81172 with p-value: 0.00E+00 , Concordance Index: 0.81254
# Training at Epoch 50 iteration 0 with loss 0.64399. Total time 45.2663 hours
# Training at Epoch 50 iteration 100 with loss 0.79198. Total time 45.285 hours
# Training at Epoch 50 iteration 200 with loss 0.69711. Total time 45.3033 hours
# Training at Epoch 50 iteration 300 with loss 0.66399. Total time 45.3219 hours
# Training at Epoch 50 iteration 400 with loss 0.71822. Total time 45.3402 hours
# Training at Epoch 50 iteration 500 with loss 0.61872. Total time 45.3588 hours
# Training at Epoch 50 iteration 600 with loss 0.66482. Total time 45.3775 hours
# Training at Epoch 50 iteration 700 with loss 0.66766. Total time 45.3958 hours
# Training at Epoch 50 iteration 800 with loss 0.61790. Total time 45.4144 hours
# Training at Epoch 50 iteration 900 with loss 0.61774. Total time 45.4330 hours
# Training at Epoch 50 iteration 1000 with loss 0.71328. Total time 45.4516 hours
# Training at Epoch 50 iteration 1100 with loss 0.69065. Total time 45.47 hours
# Training at Epoch 50 iteration 1200 with loss 0.66589. Total time 45.4886 hours
# Training at Epoch 50 iteration 1300 with loss 0.66160. Total time 45.5072 hours
# Training at Epoch 50 iteration 1400 with loss 0.59875. Total time 45.5258 hours
# Training at Epoch 50 iteration 1500 with loss 0.65194. Total time 45.5441 hours
# Training at Epoch 50 iteration 1600 with loss 0.71147. Total time 45.5627 hours
# Training at Epoch 50 iteration 1700 with loss 0.74433. Total time 45.5813 hours
# Training at Epoch 50 iteration 1800 with loss 0.62078. Total time 45.5997 hours
# Training at Epoch 50 iteration 1900 with loss 0.69064. Total time 45.6183 hours
# Training at Epoch 50 iteration 2000 with loss 0.63216. Total time 45.6369 hours
# Training at Epoch 50 iteration 2100 with loss 0.62759. Total time 45.6555 hours
# Training at Epoch 50 iteration 2200 with loss 0.54231. Total time 45.6738 hours
# Training at Epoch 50 iteration 2300 with loss 0.68680. Total time 45.6925 hours
# Training at Epoch 50 iteration 2400 with loss 0.62432. Total time 45.7111 hours
# Training at Epoch 50 iteration 2500 with loss 0.78871. Total time 45.7294 hours
# Training at Epoch 50 iteration 2600 with loss 0.66589. Total time 45.7480 hours
# Training at Epoch 50 iteration 2700 with loss 0.68980. Total time 45.7666 hours
# Training at Epoch 50 iteration 2800 with loss 0.60714. Total time 45.7852 hours
# Training at Epoch 50 iteration 2900 with loss 0.79287. Total time 45.8036 hours
# Training at Epoch 50 iteration 3000 with loss 0.63969. Total time 45.8222 hours
# Training at Epoch 50 iteration 3100 with loss 0.84199. Total time 45.8408 hours
# Training at Epoch 50 iteration 3200 with loss 0.81751. Total time 45.8591 hours
# Training at Epoch 50 iteration 3300 with loss 0.71567. Total time 45.8777 hours
# Training at Epoch 50 iteration 3400 with loss 0.54633. Total time 45.8963 hours
# Training at Epoch 50 iteration 3500 with loss 0.66018. Total time 45.915 hours
# Training at Epoch 50 iteration 3600 with loss 0.54685. Total time 45.9333 hours
# Training at Epoch 50 iteration 3700 with loss 0.66020. Total time 45.9519 hours
# Training at Epoch 50 iteration 3800 with loss 0.68818. Total time 45.9705 hours
# Training at Epoch 50 iteration 3900 with loss 0.62050. Total time 45.9891 hours
# Training at Epoch 50 iteration 4000 with loss 0.68038. Total time 46.0075 hours
# Training at Epoch 50 iteration 4100 with loss 0.58280. Total time 46.0261 hours
# Training at Epoch 50 iteration 4200 with loss 0.60276. Total time 46.0447 hours
# Training at Epoch 50 iteration 4300 with loss 0.70581. Total time 46.0630 hours
# Validation at Epoch 50 with loss:0.77456, MSE: 0.74823 , Pearson Correlation: 0.81520 with p-value: 0.00E+00 , Concordance Index: 0.81418
# --- Go for Testing ---
# Testing MSE: 0.743496459238672 , Pearson Correlation: 0.8138890203609498 with p-value: 0.00E+00 , Concordance Index: 0.8131653683550444
# --- Training Finished ---
